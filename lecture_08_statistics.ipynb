# %% [markdown]
# <a href="https://colab.research.google.com/github/fbeilstein/machine_learning/blob/master/lecture_08_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Statistics

# %% [markdown]
# ##What is statistics?

# %% [markdown]
# ---
# Statistics does
# * collection,
# * organization,
# * displaying,
# * analysis,
# * interpretation and
# * presentation
#
# of data.
#
# ---

# %% [markdown]
# **Statistics** is the discipline that concerns the collection, organization, displaying, analysis, interpretation and presentation of data. In applying statistics to a scientific, industrial, or social problem, it is conventional to begin with a statistical population or a statistical model to be studied. Populations can be diverse groups of people or objects such as "all people living in a country" or "every atom composing a crystal". Statistics deals with every aspect of data, including the planning of data collection in terms of the design of surveys and experiments.
#
# When census data cannot be collected, statisticians collect data by developing specific experiment designs and survey samples. Representative sampling assures that inferences and conclusions can reasonably extend from the sample to the population as a whole. An experimental study involves taking measurements of the system under study, manipulating the system, and then taking additional measurements using the same procedure to determine if the manipulation has modified the values of the measurements. In contrast, an observational study does not involve experimental manipulation.
#
# Two main statistical methods are used in data analysis: **descriptive statistics**, which summarize data from a sample using indexes such as the mean or standard deviation, and **inferential statistics**, which draw conclusions from data that are subject to random variation (e.g., observational errors, sampling variation). Descriptive statistics are most often concerned with two sets of properties of a distribution (sample or population): central tendency (or location) seeks to characterize the distribution's central or typical value, while dispersion (or variability) characterizes the extent to which members of the distribution depart from its center and each other. Inferences on mathematical statistics are made under the framework of probability theory, which deals with the analysis of random phenomena.

# %% [markdown]
# #Population and sample (генеральна сукупність та вибірка)

# %% [markdown]
# ---
# **is it possible to collect ALL data?**
#
# * YES $\rightarrow$ **population** -- all items of interest are accessible
# * NO $\rightarrow$ **sample** -- we only use these data we can lay our hands on
#
# **why do we need data?**
#
# * summarize (squeeze, compress) a plethora of parameters into manageable number of values/statements that grasp essential features of data $\rightarrow$ **descriptive statistics**
#
# * prognose (estimate, guess) properties of unseen datapoints $\rightarrow$ **inferential statistics**
#
# ---

# %% [markdown]
# The key concept of statistics are the concepts of population and sample.
#
# In statistics, a *population* is a set of similar items or events which is of interest for some question or experiment. A statistical population can be a group of existing objects (e.g. the set of all stars within the Milky Way galaxy) or a hypothetical and potentially infinite group of objects conceived as a generalization from experience (e.g. the set of all possible hands in a game of poker). A common aim of statistical analysis is to produce information about some chosen population.
#
# A data *sample* is a set of data collected from a statistical population by a defined procedure.
#
# *Sampling* is the selection of a subset (a statistical sample) of individuals from within a statistical population to estimate characteristics of the whole population. Here is only one picture to illustrate typical difficulties that sampling encounters.

# %%
#@title Population vs samples
# %%html

<img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/population_vs_sample.svg'>
</img>
# Out:
# <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/population_vs_sample.svg'>
# </img>

# %% [markdown]
# ---
# **If a sample is needed for prediction**
#
# * sample can significantly differ from population
# * we may have no clue how sample differs from population
#    - simplest assumption: sample is just small population and has the same properties (obviously not always true)
#    - **representable sample** -- we are lucky, simplest assumption is true
#    - **unrepresentable sample** -- we're out of luck
#
# ---

# %% [markdown]
# ##Picking objects with and without replacement

# %% [markdown]
# Suppose we have a sack with $N$ balls: $K$ red balls and $N-K$ blue balls. The probability to pick red ball is $p=K/N$ and probability to pick blue ball is $1-p=(N-K)/N$.  We pick a a ball, remember its color and either return it to the sack or not.
# If we don't return balls to the sack the probability to pick red ball in the second trial changes!
# We can fix number of draws $n$ and wonder what is the probability to get $k$ red balls (get $k$ successes).
# We can fix number $r$ of blue balls (failures) and ask ourselves what is the probability that it would take $n$ draws to get $r$ failures in total.

# %%
#@title Picking with/without replacement
# %%html

<img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/picking_from_sack.svg'>
</img>
# Out:
# <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/picking_from_sack.svg'>
# </img>

# %% [markdown]
# With replacements	No replacements
#  of successes in constant  of draws	binomial distribution	hypergeometric distribution
#  of successes in constant  of failures	negative binomial distribution	negative hypergeometric distribution

# %% [markdown]
# ---
# **Discrete distributions summary**
#
# Replacement | $1$ trial | $n$ trials | try until $r$ failures
# ---|---|---|---
# YES | Bernoulli | Binomial | Hypergeometric
# NO | Bernoulli | Negative Binomial | Negative Hypergeometric
# | | |
# **Probability to get** | $0$ or $1$ | $k$ zeros<br> $n-k$ ones | $k$ ones<br> $r$ zeros, the last trial is zero!<br>
#
# ---

# %% [markdown]
# #Types of data

# %% [markdown]
# ---
# **What kind of data can we get from sample?**
#
# * Categorical
#    - Nominal
#    - Ordinal
# * Numerical
#    - Interval
#    - Ratio
#
# ---

# %% [markdown]
# Datatypes are an important concept because statistical methods can only be used with certain data types. You have to analyze continuous data differently than categorical data otherwise it would result in a wrong analysis. Therefore knowing the types of data you are dealing with, enables you to choose the correct method of analysis.

# %%
#@title Data types

# %%html
<link rel="stylesheet" href="https://fbeilstein.github.io/machine_learning/js_common/styles.css"/>
<script src="https://fbeilstein.github.io/machine_learning/js_common/script.js"></script>
<script>
load_slides_from(
[
  `
  <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/data_types_level_0.svg' width=800>
  </img>
`
,
`
  <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/data_types_level_1.svg' width=800>
  </img>
`
,
`
  <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/data_types_level_2.svg' width=800>
  </img>
`
  ]
)
</script>
# Out:
# <link rel="stylesheet" href="https://fbeilstein.github.io/machine_learning/js_common/styles.css"/>
# <script src="https://fbeilstein.github.io/machine_learning/js_common/script.js"></script>
# <script>
# load_slides_from(
# [
#   `
#   <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/data_types_level_0.svg' width=800>
#   </img>
# `
# ,
# `
#   <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/data_types_level_1.svg' width=800>
#   </img>
# `
# ,
# `
#   <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/data_types_level_2.svg' width=800>
#   </img>
# `
#   ]
# )
# </script>

# %% [markdown]
# **Categorical(qualitative) Data**
#
# Categorical data represents characteristics. Therefore it can represent things like a person's gender, language etc. Categorical data can also take on numerical values (Example: $1$ for female and $0$ for male). Note that those numbers don't have mathematical meaning.
#
# **Nominal(unordered) Data**
#
# Nominal values represent discrete units and are used to label variables, that have no quantitative value. Just think of them as „labels“. Note that nominal data that has no order. Therefore if you would change the order of its values, the meaning would not change. Examples of values that might be represented in a Nominal variable:
#
# * The blood type of a person: $A$, $B$, $AB$ or $O$.
# * The state that a person lives in.
# * The political party that a voter might vote for, e. g. in a European country Christian Democrat, Social Democrat, Green Party, etc.
# * The type of a rock: igneous, sedimentary or metamorphic.
#
# **Ordinal(ordered) Data**
#
# Ordinal data represents characteristics that do have some kind of implicit or natural order, such as "Short, Medium, or Tall."  Another example is a survey question that asks us to rate an item on a $1$ to $10$ scale, with $10$ being the best. This implies that $10$ is better than $9$, which is better than $8$, and so on.
# In the social sciences, particularly psychology, common examples are the Likert response scale and $1-10$ rating scales in which a person selects the number which is considered to reflect the perceived quality of a product.
#
# Advanced note: The best way to determine central tendency on a set of ordinal data is to use the mode or median; a purist will tell you that the mean cannot be defined from an ordinal set.
#
# **Numerical(quantitative) Data**
# Numerical data can be discrete or continuous.
#
# **Interval Data**
#
# Interval scales are numeric scales in which we know both the order and the exact differences between the values.  The classic example of an interval scale is Celsius temperature because the difference between each value is the same.  For example, the difference between $60$ and $50$ degrees is a measurable $10$ degrees, as is the difference between $80$ and $70$ degrees.
#
# Interval scales are nice because the realm of statistical analysis on these data sets opens up.  For example, central tendency can be measured by mode, median, or mean; standard deviation can also be calculated.
#
# Like the others, you can remember the key points of an “interval scale” pretty easily. “Interval” itself means “space in-between,” which is the important thing to remember–interval scales not only tell us about order, but also about the value between each item.
#
# Here's the problem with interval scales: they don't have a “true zero.”  For example, there is no such thing as “no temperature,” at least not with Celsius.  In the case of interval scales, zero doesn't mean the absence of value, but is actually another number used on the scale, like $0$ degrees Celsius.  Negative numbers also have meaning.  Without a true zero, it is impossible to compute ratios.  With interval data, we can add and subtract, but cannot multiply or divide.
#
#
# **Ratio Data**
#
# Ratio values are also ordered units that have the same difference. Ratio values are the same as interval values, with the difference that they do have an absolute zero. Good examples are height, weight, length, absolute temperature etc.

# %% [markdown]
# ---
# **Ok,we have data, what to do now?**
#
# | | Nominal | Ordinal | Interval | Ratio
# |---|---|---|---|---
# Example| Name,<br> Gender,<br> Language | Tall-Medium-Small,<br> Large-Small, etc. | $~^\circ$C, $~^\circ$F,<br> points of affine space | $~^\circ$K,<br> mass
# "Counts" | $\checkmark$ | $\checkmark$ | $\checkmark$ | $\checkmark$
# Mode |  $\checkmark$ | $\checkmark$ | $\checkmark$ | $\checkmark$
# Order is known | | $\checkmark$ | $\checkmark$ | $\checkmark$
# Median | | $\checkmark$ | $\checkmark$ | $\checkmark$
# Differences have meaning | | | $\checkmark$ | $\checkmark$
# Mean | | | $\checkmark$ | $\checkmark$
# Have "true" zero | | | | $\checkmark$
# Scalings are meaningful | | | | $\checkmark$
#
# ---

# %% [markdown]
# We see that ratio data allow all range of operations that's why the allow many methods for analysis.
# We will primarily deal with ratio data.

# %% [markdown]
# #Two main problems in statistics

# %% [markdown]
# Two main tasks for statistics are
# * Estimation of parameters
#    - numerical unknown(s)
#    - aim at an estimate that is close to the true but unknown value
# * Hypothesis testing
#    - unknown takes one of a few possible values (is it an airplane or a bird)
#    - aim at a small probability of incorrect decision

# %% [markdown]
# #What is hypothesis testing?

# %% [markdown]
# Suppose we have $100$ ill people and we have a drug that supposedly helps (this is our hypothesis). We want to test our hypothesis. We give our cure to ill people and $10$ of them recover. Did they recover thanks to a drag or by pure chance? In other words is our result statistically significant.
# * We adopt alternative hypothesis (so called $H_0$) that our drug is useless. $H_0$ is always conservative, it assumes that nothing happens.
# * We calculate probability $10$ people recovers by pure chance.
# * We compare probability with the threshold value we agreed on beforehand. This threshold is called the $p$ value.
# * If our probability is less than $p$ it means that our $H_0$ was wrong and the drug works.
#
# Choosing of $p$ is arbitrary, but the popular choice is $\frac{1}{20}=5\%$.
# How can we calculate probability of recovery by pure chance? We need to have a control group that doesn't get any treatment (or rather get a placebo).
# In fact we need to use **triple blind method**:
# * patient should not know whether he gets placebo or drug;
# * doctors who give the drug (placebo) should not know which is which
# * doctors who diagnoses recovery should not know whether the patient was given a drug or not.

# %% [markdown]
# #Estimation of parameters

# %% [markdown]
# ---
# **Returning to our data, what do we want to do?**
#
# * Say something about available sample/population = calculate some fairly arbitrary function (called **statistics**), bonus if that function is meaningful
# * Estimate something about population, when sample is available = calculate **estimator**
#
# **Without any assumptions on sampling process we are unarmed, what to do?**
#
# We assume, sampling is
# * **I**ndependent and
# * **I**dentically distributed
#
# ---

# %% [markdown]
# ---
# **Why do we need probability here?**
#
# $$
# \boxed{\text{Law of The Universe}}
# \xrightarrow{\text{random process A}}
# \boxed{\text{population}}
# \xrightarrow{\text{random process B}}
# \boxed{\text{sample}}
# $$
#
# In any case our datapoints are realizations of random variables.
#
# ---

# %% [markdown]
# ##Iid - sampling probability distribution

# %% [markdown]
# There is another way to look at population and sampling that generalizes our previous setup for the infinite populations. Suppose we have a random variable with some probability distribution. Suppose we we get $n$ realizations of this random variable - we sample it $n$ times.
# For example, you measure some physical quantity say voltage $n$ times to get an accurate result free of random error.
# You can look at it as if you have a collection of $n$ random variables that are independent and identically distributed. That means that each random variable has the same probability distribution as the others and all are mutually independent. This property is usually abbreviated as i.i.d. or iid or IID (**I**ndependent and **I**dentically **D**istributed).
# The following are examples or applications of i.i.d. random variables:
# * A sequence of outcomes of spins of a fair or unfair roulette wheel is i.i.d. One implication of this is that if the roulette ball lands on "red", for example, $20$ times in a row, the next spin is no more or less likely to be "black" than on any other spin (see the Gambler's fallacy).
# * A sequence of fair or loaded dice rolls is i.i.d.
# * A sequence of fair or unfair coin flips is i.i.d.

# %% [markdown]
# ##Statistics and estimators

# %% [markdown]
# Statistic is any function of a sample.
#
# $$
# Statistics = f(\{\cdot\})
# $$
#
# Say if you have a sample $\{2,6,3\}$ and you add these numbers up you get a statistic ("sum" function).
# Statistics are use for two things
# * quantify some property of the sample (for example its range or central tendency). That's useful if you want to get a quick grasp of the sample expressed in just a few numbers. Such statistics are frequently called measures;
# * estimate parameters of the population or distribution we sample (for example $\sigma$ and $\mu$ in Gaussian distribution). These are called estimators.
#
# So, estimators are special statistics that approximate the parameters and characteristics of our population (or parameters of distribution in the iid setup). In our example "sum"-statistic is not a useful estimator: if you get larger sample (with $10$ entries) the sum will probably be larger. On the contrary if you divide the sum by the number of entries in the sample you do obtain meaningful estimator that characterizes central tendency of the population (sample mean).
#
# Estimators may have the same name as parameters and characteristics
#
# $$
# \begin{align}
# Mean (characteristic \, of \, r.v.) \quad &{\bf{\&}} \quad Sample \,  mean (estimator \, for \, the \, mean) \\
# Variance (characteristic \, of \, r.v.) \quad &{\bf{\&}} \quad Sample \,  variance (estimator \, for \, the \, variance) \\
# &etc.
# \end{align}
# $$
#
# So
# $$
# Estimator=statistic\,\, used\,\, to\,\, estimate\,\,parameters \,\,of \,\,population(random \, variable)
# $$
#
# One important thing to understand about statistics and estimators is that they are random variables. Different samples render different realizations of the statistics. Like every random variable statistics and estimators have probability distribution. For example

# %% [markdown]
# ---
# * Statistics and Estimators on samples are randomly distributed
#    - Creating a sample is a random process
#    - If we estimate certain property its estimator may have different distribution than this property's distribution in population.
# * Statistics are sometimes estimators, but NOT ALWAYS.
# * Estimators have often the same name as "corresponding" population parameters, sometimes "sample" is added to emphasize that we work with estimator.
#
# ---

# %%
#@title Explore the distribution of means
# %%html
<iframe title="Demo"
        src="https://fbeilstein.github.io/machine_learning/lecture_08_statistics/demo_sample_mean.html"
        width="800" height="600"
        marginwidth="0" marginheight="0" frameborder="0"
        scrolling="no">
Your browser does not support IFrames.
</iframe>
# Out:
# <iframe title="Demo"
#         src="https://fbeilstein.github.io/machine_learning/lecture_08_statistics/demo_sample_mean.html"
#         width="800" height="600"
#         marginwidth="0" marginheight="0" frameborder="0"
#         scrolling="no">
# Your browser does not support IFrames.
# </iframe>

# %% [markdown]
# These distributions have their maxima, standard deviation, etc. Some estimators have extremely narrow distribution. Note that width of distribution for sample mean narrows down as the size of the sample increases.

# %% [markdown]
# This suggests to choose estimators whose mean value coincides with the estimated parameter (such estimators are called **unbiased**) and estimators with the least spread possible (**MVUE**: minimum-variance unbiased estimator).
#
#
# Also consider another idea. You may have a guess about what estimated parameter may be beforehand. More generally you may have a probability distribution for the estimated parameter (it may be uniform). Realization of the estimator obtained from the sample adds new information and adjusts your parameter probability distribution.
# This is called **Bayesian estimation**.

# %% [markdown]
# ---
# Estimator gives us some number basing on the given sample only.
# It would be very good if we can be sure that our estimator gives for a "mean sample" result close to corresponding statistics for population.
# But can we be sure?
# * sometimes yes (mean, mode, IQR)
# * sometimes no, but we can fix the situation (variance biased $\rightarrow$ unbiased)
# * sometimes no and we cannot fix anything (std, no fixes if distribution is unknown)
#
# ---

# %% [markdown]
# ##Central tendency estimators

# %% [markdown]
# If we could get the entire population we could draw its histogram and describe its parameters. Unfortunately, we have only a small sample. Or in the case of the random variable we can sample it finitely many times.
# That's why we have only *estimators* for population parameters. One of the most important is the central tendency.
#
# * sample mean - the sum of all measurements divided by the number of observations in the data set.
#
# $$
# \langle x \rangle=\bar{x}=\frac{\sum_{i=1}^Nx_i}{N}.
# $$
#
# Be cautious: mean is strongly affected by the outliers!
# * sample median - the middle value that separates the higher half from the lower half of the data set. Median is less susceptible to outliers than sample mean (statisticians call this quality **robustness**).
# * sample mode - the most frequent value in the data set. This is the only central tendency measure that can be used with nominal data, which have purely qualitative category assignments. The median and the mode are the only measures of central tendency that can be used for ordinal data, in which values are ranked relative to each other but are not measured absolutely.
# For example, if we are dealing with presidential elections results it's the mode that we need.

# %% [markdown]
# **There are functions defined for random variable $X$ that mirror central tendency estimators**
# * expected value $\mathbb{E}{[X]}$;
#
# $$
# \begin{align}
# continuous\,distr: \qquad &\mathbb{E}{[X]}=\int p(x) \, x \, dx \\
# discrete \,distr: \qquad &\mathbb{E}{[X]}=\sum p_i(x_i) \, x_i
# \end{align}
# $$

# %%
#@title Expected value (mean)
# %%html

<img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/expected_value.svg'>
</img>
# Out:
# <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/expected_value.svg'>
# </img>

# %% [markdown]
# * median $\mathbb{M}{[X]}$;
#
# $$
# \begin{align}
# continuous\,distr: \qquad &\int_{-\infty}^{\mathbb{M}{[X]}} p(x) \, x \, dx=0.5 \\
# discrete \,distr: \qquad &\mathbb{M}{[X]}=\frac{x_{\lceil {N \div 2} \rceil}+x_{\lfloor {N \div 2} \rfloor}}{2}, \\
# & \text{where } x_i \text{ are ordered and } N=\text{number of } x_i
# \end{align}
# $$

# %%
#@title Median
# %%html

<img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/median.svg'>
</img>
# Out:
# <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/median.svg'>
# </img>

# %%
#@title Median
# %%html

<img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/median_histogram.svg'>
</img>
# Out:
# <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/median_histogram.svg'>
# </img>

# %% [markdown]
# * mode $\mathbb{Mode}{[X]}=\text{argmax value of the distribution (value that appears most often)}$;

# %%
#@title Mode
# %%html

<img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/mode.svg'>
</img>
# Out:
# <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/mode.svg'>
# </img>

# %% [markdown]
# * variance $\mathbb{Var}[X]$;
#
# $$
# \begin{align}
# continuous\,distr: \qquad & \mathbb{Var}[X]=\int p(x) (x-\mathbb{E}{[X]})^2 dx \\
# discrete \,distr: \qquad &\mathbb{Var}{[X]}=\sum p_i(x_i) (x_i-\mathbb{E}{[X]})^2.
# \end{align}
# $$
#
# * standard deviation $\sigma[X]$;
#
# $$
# \sigma[X]=\sqrt{\mathbb{Var}[X]}
# $$
#
#
# * moments $\mu_n[X]$;
#
# $$
# \begin{align}
# continuous\,distr: \qquad & \mu_n[X]=\int p(x) \, x^n \, dx \\
# discrete \,distr: \qquad &\mu_n[X]=\sum p_i(x_i) \, x_i^n.
# \end{align}
# $$
#
# * skewness;
#
# $$
# skewness[X]=complicated \, formula
# $$
#
# This is a measure of the asymmetry of the probability distribution.
# Distribution could be symmetric, right-skewed or left-skewed.

# %%
#@title Skewness

# %%html
<link rel="stylesheet" href="https://fbeilstein.github.io/machine_learning/js_common/styles.css"/>
<script src="https://fbeilstein.github.io/machine_learning/js_common/script.js"></script>
<script>
load_slides_from(
[
  `
  <center>
  <font face="helvetica" color="black" size="6">
    Skewed left
    <br>
  </font>
  </center>
  <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/skewed_left.svg'>
  </img>
`
,
`
  <center>
  <font face="helvetica" color="black" size="6">
    Normally distributed
    <br>
  </font>
  </center>
  <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/no_skew.svg'>
  </img>
`
,
`
  <center>
  <font face="helvetica" color="black" size="6">
    Skewed right
    <br>
  </font>
  </center>
  <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/skewed_right.svg'>
  </img>
`
  ]
)
</script>
# Out:
# <link rel="stylesheet" href="https://fbeilstein.github.io/machine_learning/js_common/styles.css"/>
# <script src="https://fbeilstein.github.io/machine_learning/js_common/script.js"></script>
# <script>
# load_slides_from(
# [
#   `
#   <center>
#   <font face="helvetica" color="black" size="6">
#     Skewed left
#     <br>
#   </font>
#   </center>
#   <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/skewed_left.svg'>
#   </img>
# `
# ,
# `
#   <center>
#   <font face="helvetica" color="black" size="6">
#     Normally distributed
#     <br>
#   </font>
#   </center>
#   <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/no_skew.svg'>
#   </img>
# `
# ,
# `
#   <center>
#   <font face="helvetica" color="black" size="6">
#     Skewed right
#     <br>
#   </font>
#   </center>
#   <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/skewed_right.svg'>
#   </img>
# `
#   ]
# )
# </script>

# %% [markdown]
# * kurtosis;
#
# $$
# kurtosis[X]=complicated \, formula
# $$
#
# This is a measure of the "tailedness" of the probability distribution.
# There can be short-tailed, heavy-tailed, fat-tailed, long-tailed distributions, etc.
#
# * etc.
#
#
# **Physical interpretation:** mean is the center of mass of pdf if it was made out of material, variance is the moment of inertia with respect to the center of mass.
#
# <img src="https://raw.githubusercontent.com/fbeilstein/machine_learning/master/lecture_08_statistics/moment_of_inertia_distribution.png" width="450px" />
#
# All these numbers ($\mathbb{E}{[X]}$, $\mathbb{Var}{[X]}$, $\sigma[X]$, etc) could be called characteristics of the distribution in order to not confuse them with parameters on which distributions directly depend on (like $\mu$ and $\sigma$ in normal distribution).
#
# Characteristics and parameters of the distribution may not be known to us, but they are constant, they are not random.
#
# You can look up characteristics of all popular distributions in Wikipedia.
#
# ![](https://raw.githubusercontent.com/fbeilstein/machine_learning/master/lecture_08_statistics/distribution_properties_example.png)

# %%
sample = [1,1,1,3,4,5,6,8]
print("sample mean = ", statistics.mean(sample))
print("sample median = ", statistics.median(sample))
print("sample mode = ", statistics.mode(sample))
# Out:
# sample mean =  3.625
# sample median =  3.5
# sample mode =  1

# %% [markdown]
# ##Variability (range) statistics (estimators)

# %% [markdown]
# It's useful to measure how spread out are the numbers in the sample.
# Here are common variability measures:
# * range;
# * interquartile range (IQR);
# * sample variance;
# * sample std.

# %% [markdown]
# ###Range

# %% [markdown]
# The simplest statistics that measures spread of the data is the range.
# The range of a set of data is the difference between the largest and smallest values.

# %%
sample = [2, 3, 4, 2, 7, 1, 34]
print("Range = ", max(sample) - min(sample))
# Out:
# Range =  33

# %% [markdown]
# Range belongs to L-statistic is a statistic (function of a data set) that is a linear combination of order statistics; the "L" is for "linear".
# The $k$-th order statistic of a statistical sample is equal to its $k$th-smallest value.
# $Min$ is $1$-st order statistics and $max$ is the $n$-th order statistics. Median is order statistics only for samples with odd number of elements.

# %% [markdown]
# ###Percentiles and interquartile range (IQR)

# %% [markdown]
# A percentile (or a centile) is a measure used in statistics indicating the value below which a given percentage of observations in a group of observations falls. For example, the $25$th percentile (called quantile) is the value (or score) below which $25\%$ of the observations may be found.

# %%
sample = [20, 2, 7, 1, 34]
print("50th percentile = ", np.percentile(sample, 50))
print("25th percentile = ", np.percentile(sample, 25))
print("75th percentile = ", np.percentile(sample, 75))
# Out:
# 50th percentile :  7.0
# 25th percentile :  2.0
# 75th percentile :  20.0

# %% [markdown]
# Quantile are useful cause they help us to deal with the outliers. Empirically, if the data being analyzed are not actually distributed according to an assumed distribution, or if there are other potential sources for outliers that are far removed from the mean, then quantiles may be more useful descriptive statistics than means and other moment-related statistics.
# The interquartile range ($IQR$), also called the midspread or middle $50\%$, or technically H-spread, is a measure of statistical dispersion, being equal to the difference between $75$th and $25$th percentiles, or between upper and lower quartiles, $IQR = Q3 −  Q1$.

# %%
sample = [2,3,4, 2, 7, 1, 34]
print("IQR = ", np.percentile(sample, 75) - np.percentile(sample, 25))
# Out:
# IQR =  3.5

# %% [markdown]
# $IQR$ is the robust measures of scale while range is not. That reminds situation with mean and median.
#
# Boxplot is an alternative to the histogram of the sample. They show median, $1$st and $3$rd quartiles, and have lines extending vertically from the boxes (whiskers) indicating variability outside the upper and lower quartiles, hence the terms box-and-whisker plot and box-and-whisker diagram. Outliers are plotted as individual points.

# %%
sample = [1, 2, 3, 4, 5, 6, 15]
fig1, ax1 = plt.subplots();
ax1.boxplot(sample);

# %%
#@title Skewness

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

NUM_SAMPLES = 100000

def randn_skew_fast(N, alpha=0.0, loc=0.0, scale=1.0):
    sigma = alpha / np.sqrt(1.0 + alpha**2)
    u0 = np.random.randn(N)
    v = np.random.randn(N)
    u1 = (sigma*u0 + np.sqrt(1.0 - sigma**2)*v) * scale
    u1[u0 < 0] *= -1
    u1 = u1 + loc
    return u1

def skew_norm_pdf(x, location=0, scale=1, alpha_skew=0):
    t = (x - location) / scale
    return 2.0 / scale * stats.norm.pdf(t) * stats.norm.cdf(alpha_skew * t)

location = 3.0
scale = 3.0

def plot_box(location, scale, skew):
  fig, axs = plt.subplots(nrows=1,ncols=2,figsize=(12,4))
  plt.axes(axs[0])
  s = randn_skew_fast(NUM_SAMPLES, skew, location, scale)
  plt.hist(s, density=True, bins=50)
  x = np.linspace(np.min(s), np.max(s), num=100)
  p = skew_norm_pdf(x, location, scale, skew)
  plt.plot(x,p)

  plt.axes(axs[1])
  plt.boxplot(s, showmeans=True, notch=False);


from google.colab import widgets
tb = widgets.TabBar(['skewed left', 'not skewed', 'skewed right'], location='top')
with tb.output_to(0):
  plot_box(3.0, 3.0, -5.0)
with tb.output_to(1):
  plot_box(0.0, 3.0, 0.0)
with tb.output_to(2):
  plot_box(-3.0, 3.0, 5.0)
# Out:
# <link rel=stylesheet type=text/css href='/nbextensions/google.colab/tabbar.css'></link>
# <script src='/nbextensions/google.colab/tabbar_main.min.js'></script>
# <div id="id7"></div>

# %% [markdown]
# Sometimes we want our distribution to look nomal-like (e.g. errors should have normal distribution for linear regression). To make the distribution less skewed we may use different transformations, e.g.
# * Box–Cox transformation
# * Yeo–Johnson transformation
# See [Wikipedia](https://en.wikipedia.org/wiki/Power_transform) for more information.

# %% [markdown]
# ###Variance estimators

# %% [markdown]
# ---
# We love **variance** because
# * $\mathbb{Var}[cX] = c^2 \mathbb{Var}[X]$
# * $\mathbb{Var}[X + Y] = \mathbb{Var}[X] + \mathbb{Var}[Y]$ for uncorrelated $X$ and $Y$ (often a stronger condition of independency is available, but uncorrelated is ok)
# * $\mathbb{Var}[aX \pm bY] = a^2\mathbb{Var}[X] + b^2\mathbb{Var}[Y] \pm 2ab~\text{Cov}(X,Y)$
#
# Compare to mean
# * $\mathbb{E}[cX] = c \mathbb{E}[X]$
# * $\mathbb{E}[X + Y] = \mathbb{E}[X] + \mathbb{E}[Y]$
#
# Note two different estimators for population and for sample
#
# ---

# %% [markdown]
# We have seen how variance is defined for the entire population.
# There is a function ```pvariance``` in ```Statistics``` package to calculate it.
#
#
# The formula for the population variance is
# $$
# \mathbb{Var}[X]=\frac{\sum_{i=1}^N(x_i-\bar{x})^2}{N}
# $$
#
# The formula for the sample variance is a little bit different though
# $$
# V=\frac{\sum_{i=1}^N(x_i-\bar{x})^2}{N-1}
# $$
#
#
# Note $N-1$ in the denominator and not $N$. Here are a handful of popular videos on youtube that try to explain it.
#
# ![](https://raw.githubusercontent.com/fbeilstein/machine_learning/master/lecture_08_statistics/sample_variance_youtube.png)
#
# Actually there are two versions of sample variances: biased (uncorrected) and unbiased (corrected)
#
# $$
# V_{b}=\frac{\sum_{i=1}^N(x_i-\bar{x})^2}{N}
# $$
# and the corrected (unbiased) one that we denoted as $v$.
# We see that that
# $$
# V=V_{b} \, \underbrace{\frac{N}{N-1}}_{\text{Bessel's} \\ \text{correction}}
# $$.
#
# In statistics, the bias (or bias function) of an estimator is the difference between this estimator's expected value and the true value of the parameter being estimated. An estimator or decision rule with zero bias is called unbiased.

# %% [markdown]
# ---
# In case of variance correction is needed due to mean value present in its definition --- mean for a sample is NOT a well-defined number, but a realization of random variable and has its own variance equal to population variance divided by size of the sample.
#
# ---

# %%
import statistics
import numpy as np

sample = [1,1,1,3,4,5,6,8]

print(" -- with statistics module -- ")
print("biased sample variance = ", statistics.pvariance(sample))
print("unbiased sample variance = ", statistics.variance(sample))
print("sample standard deviation = ", statistics.stdev(sample))
print(" -- with numpy module -- ")
print("biased sample variance = ", np.var(sample, axis=0, ddof=0))
print("unbiased sample variance = ", np.var(sample, axis=0, ddof=1))
print("sample standard deviation = ", np.sqrt(np.var(sample, axis=0, ddof=1)))
# Out:
#  -- with statistics module --
# biased sample variance =  5.984375
# unbiased sample variance =  6.839285714285714
# sample standard deviation =  2.615202805574687
#  -- with numpy module --
# biased sample variance =  5.984375
# unbiased sample variance =  6.839285714285714
# sample standard deviation =  2.615202805574687

# %% [markdown]
# If we average unbiased variances for samples of any size we get the variance of entire population.

# %% [markdown]
# ---
# Following plots show biased/unbiased variances for
# * finite population
# * infinite population
#
# ---

# %%
import itertools
import statistics
import matplotlib.pyplot as plt

N = 5
population = [1,3,4,5,6,8]
print("Population: ", population)
P = len(population)
samples = list(itertools.product(population,repeat=N))
variances = list(map(statistics.variance, samples))
mean_unbiased_variance=statistics.mean(variances)
print("mean of unbiased variances = ", mean_unbiased_variance)
biased_variances = [i *(N-1)/(N) for i in variances]
mean_biased_variance=statistics.mean(biased_variances)
print("mean of biased variances = ", mean_biased_variance)
print("population variance = ", statistics.pvariance(population))
# Out:
# Population:  [1, 3, 4, 5, 6, 8]
# mean of unbiased variances =  4.916666666666667
# mean of biased variances =  3.933333333333333
# population variance =  4.916666666666667

# %%
#@title Biased vs Unbiased Variances
# %%html
<iframe title="Demo"
        src="https://fbeilstein.github.io/machine_learning/lecture_08_statistics/demo_sample_variance.html"
        width="900" height="650"
        marginwidth="0" marginheight="0" frameborder="0"
        scrolling="no">
Your browser does not support IFrames.
</iframe>
# Out:
# <iframe title="Demo"
#         src="https://fbeilstein.github.io/machine_learning/lecture_08_statistics/demo_sample_variance.html"
#         width="900" height="650"
#         marginwidth="0" marginheight="0" frameborder="0"
#         scrolling="no">
# Your browser does not support IFrames.
# </iframe>

# %% [markdown]
# ###Standard deviation estimators

# %% [markdown]
# ---
# * no general correction for std (square root intermingles)
# * additional information on the family of underlying population distributions can help (e.g. correction $1.5$ for normal distribution)
#
# ---

# %% [markdown]
# We have considered unbiased estimator for variance. But if we take square root of it we would not get the unbiased estimator for std. That's because when we calculate sample std we take square root of sample average.
#
# $$
# \mathbb{E}[f(sample)]\neq f(\mathbb{E[sample]})
# $$
#
# when $f$ is nonlinear.
# Here $f$ is applied for each entry in the sample ($f=\sqrt{\cdot}$ for std).
# In fact it is not possible to find an estimate of the standard deviation which is unbiased for all population distributions, as the bias depends on the particular distribution.
# In fact there three formulas for sample stds
#
# $$
# \sigma=\sqrt{\frac{\sum(x_i-\bar{x})^2}{N-d}}.
# $$
#
# where $d$ can be $-1,0,1.5$.
#
# Most often, the standard deviation is estimated using the corrected sample standard deviation (using $N − 1$), and this is often referred to as the "sample standard deviation", without qualifiers. However, other estimators are better in other respects: the uncorrected estimator (using $N$) yields lower mean squared error, while using $N − 1.5$ (for the normal distribution) almost completely eliminates bias.

# %%
#@title Corrected Standard Deviation
# %%html
<iframe title="Demo"
        src="https://fbeilstein.github.io/machine_learning/lecture_08_statistics/demo_sample_std.html"
        width="900" height="650"
        marginwidth="0" marginheight="0" frameborder="0"
        scrolling="no">
Your browser does not support IFrames.
</iframe>
# Out:
# <iframe title="Demo"
#         src="https://fbeilstein.github.io/machine_learning/lecture_08_statistics/demo_sample_std.html"
#         width="900" height="650"
#         marginwidth="0" marginheight="0" frameborder="0"
#         scrolling="no">
# Your browser does not support IFrames.
# </iframe>

# %% [markdown]
# ##Maximum likelihood estimation

# %% [markdown]
# ---
# * We cannot obtain the exact distribution behind the population data by sampling it
# * We can choose a family of distributions that may be suitable to describe the population (human mind is needed)
# * We can estimate parameters of the distribution, e.g. pick one from the assumed family of distributions with programming
# * MLE -- method to guess the most probable parameters of the distribution
#
# ---

# %% [markdown]
# How did people come up with these estimators?
# There are few methods to get estimators and one of them is the likelihood estimation method.
# Suppose we sample random variable with known probability distribution but unknown parameter $\theta$.
# We begin by calculating the probability to obtain our sample $L_n(\theta;\mathbf{x})=f_n(\mathbf{x};\theta)$
# which is called the likelihood function. For independent and identically distributed random variables, $f_{n}(\mathbf {x} ;\theta )$ will be the product of univariate density functions.
#
# $$
# f_{n}(\mathbf {x} ;\theta)=f(x_1 ;\theta)\times \cdots \times f(x_n ;\theta)
# $$
#
# Now we try to maximize $L_n(\theta;\mathbf{x})$ function with respect to $\theta$.
# The specific value $ {\hat {\theta }}={\hat {\theta }}_{n}(\mathbf {y} )$ that maximizes the likelihood function $L_n(\theta;\mathbf{x})$ is called the maximum likelihood estimate (sometimes denoted as $\theta_{MLE}$).
#
# $$
# \hat {\theta }=argmax_\theta \, L_n(\theta;\mathbf{x})
# $$
#
# Sometimes it's convenient to to take logarithm of likelihood function. As logarithm is monotonic it achieves its maximum at the cam $\theta$ as its argument. For iid
#
# $$
# l_n(\theta; \mathbf{x})=\ln{L_n(\theta; \mathbf{x})}=\sum_{i=1}^n \ln{f(x_i ;\theta)}
# $$
#
# **Example: Bernoulli distribution**
#
# Suppose we have iid's with
#
# $$
# f(k)=
# \begin{cases}
# 1-p \quad & \text{if} \quad k=0,\\
# p \quad &{\text{if}} \quad k=1.\\
# \end{cases}
# $$
#
# and we have sample $\mathbf{k}={k_1,\cdots,k_n}$. $k_i$ may be either $0$ or $1$.
# Number of success is
#
# $$
# k=k_1+\cdots+k_n.
# $$
#
# We aim to caculate $p_{MLE}$.
#
# $$
# l_n(p; \mathbf{k})=\log{\left(p^k(1-p)^{n-k}\right)}=k\log{p}+(n-k)\log{(1-p)}
# $$
#
# $$
# \frac{\partial l_n(p; \mathbf{x})}{\partial p}=\frac{k}{p}+\frac{n-k}{1-p}
# $$
#
# $$
# \frac{k}{p_{MLE}}+\frac{n-k}{1-p_{MLE}}=0
# $$
#
# $$
# k-kp_{MLE}+(n-k)p_{MLE}=0
# $$
#
# $$
# p_{MLE}=\frac{k}{n}.
# $$
#
# That what we have expected as it coincides with the empirical frequency. But is it actually good?
#
# Suppose that you have small sample and by accident we for $k=0$. If we use empirical frequency we get $p=0$. Is it a reasonable estimate?
#
# Lets me tell you about Cromwell's rule in statistics: *Don't assign zero probabilities to an event unless it is EXTEMRELY unlikely.*
#
# As Lindley puts it, assigning a probability should "leave a little probability for the moon being made of green cheese; it can be as small as $1$ in a million, but have it there since otherwise an army of astronauts returning with samples of the said cheese will leave you unmoved."
#
# That's why statisticians often use so called pseudocounts
#
# $$
# p_{smoothed}=\frac{k+\alpha}{n+2\alpha}.
# $$
#
# Parameter $\alpha>0$ is called pseudocount. $p_{smoothed}$ is called smoothed version of the estimator.
#
# The simplest approach is to add one to each observed number of events including the zero-count possibilities. This is sometimes called Laplace's Rule of Succession.
#
# $$
# p_{Laplace}=\frac{k+1}{n+2}.
# $$
#
# There is an interpretation of $1$ in the numerator and $2$ in the denominator. If we know that a trial may fail or be successful it means that we have done at least two trials beforehand and one of them was successful and the other was a failure. That makes sense! Pseudocounts are also used in estimation of parameters of Multinomial distribution.
#
# **Example: Poisson distribution**
#
# Suppose we have iid's with $f(k)=\frac{\lambda^k}{k!}e^{-\lambda}$ and we have sample $\mathbf{k}={k_1,\cdots,k_n}$. We aim to calculate $\lambda_{MLE}$.
#
# $$
# l_n(\theta; \mathbf{x})=\sum_{i=1}^n \ln\left({\frac{\lambda^{k_i}}{k_i!}e^{-\lambda}}\right)
# $$
#
# $$
# \frac{\partial l_n(\theta; \mathbf{x})}{\partial \theta}=\sum_{i=1}^n \left(\frac{k_i!}{\lambda^{k_i}e^{-\lambda}}\right)\left(\frac{k_i\lambda^{k_i-1}}{k!}e^{-\lambda}-\frac{\lambda^{k_i}}{k!}e^{-\lambda}\right)=\sum_{i=1}^n \left(\frac{k_i}{\lambda} -1\right)=\frac{\sum k_i}{\lambda}-n
# $$
#
# Setting $\frac{\partial l_n(\theta; \mathbf{x})}{\partial \theta}$ to $0$ gives
#
# $$
# \frac{\sum k_i}{\lambda_{MLE}}-n=0
# $$
#
# $$
# \frac{\sum k_i}{\lambda_{MLE}}=n
# $$
#
# $$
# \lambda_{MLE}=\frac{\sum k_i}{n}=\bar{k}
# $$
#
# You can write down MLE estimators for parameters of all popular distributions.

# %%
#@title Maximum Likelihood Estimation for Gaussian Distribution
# %%html
<iframe title="Demo"
        src="https://fbeilstein.github.io/machine_learning/lecture_08_statistics/demo_mle.html"
        width="1200" height="650"
        marginwidth="0" marginheight="0" frameborder="0"
        scrolling="no">
Your browser does not support IFrames.
</iframe>
# Out:
# <iframe title="Demo"
#         src="https://fbeilstein.github.io/machine_learning/lecture_08_statistics/demo_mle.html"
#         width="1200" height="650"
#         marginwidth="0" marginheight="0" frameborder="0"
#         scrolling="no">
# Your browser does not support IFrames.
# </iframe>

# %% [markdown]
# ##Interval estimators

# %% [markdown]
# Estimators we have seen so far were so called point estimators. There are also interval estimators when we give an interval into which the estimated parameter should fall.
# Interval estimation is the use of sample data to calculate an interval of plausible values of an unknown population parameter; this is in contrast to point estimation, which gives a single value. There are two main methods
# * confidence intervals (frequentist method);
# * credible intervals (a Bayesian method).

# %% [markdown]
# #Statistical models

# %% [markdown]
# When we have real world data we aim to analyze we adopt statistical model that describes them or to put in differently we make statistical assumptions.
# Typical assumption are
# * random variable $X$ has distribution $f$ that depends on unknown parameter $\theta$ (used everywhere);
# * random variables $X$ and $Y$ are independent (used in Naive Bayes classification);
# * random variables $\{X_1,\cdots,X_n\}$ are iids (used in sampling);
# * two variables have a linear dependence (used in regression).
#
# It's important to realize that our model is never $100\%$ accurate - it's only our try to grasp the essence of the phenomenon under consideration.
#
# **"All models are wrong"** is a common aphorism in statistics; it is often expanded as "All models are wrong, but some are useful". It is usually considered to be applicable to not only statistical models, but to scientific models generally.
# Here is the question about this aphorism asked at Stack Exchange:
#
# <br>
#
# ![](https://raw.githubusercontent.com/fbeilstein/machine_learning/master/lecture_08_statistics/all_models_are_wrong_question.jpg)
#
# And here is the best answer:
#
# ![](https://raw.githubusercontent.com/fbeilstein/machine_learning/master/lecture_08_statistics/all_models_are_wrong_answer.jpg)

# %% [markdown]
# #Covariance and correlation

# %% [markdown]
# Suppose you have two samples drawn from two populations (random variables).
# Covariance is a measure of the relationship between these samples. The metric evaluates how much – to what extent – the variables change together.
#
# $$
# \begin{aligned}
# unbiased:\qquad &\sigma(x,y)=\frac{1}{N-1}\sum_{i=1}^N(x_i-\bar{x})(y_i-\bar{y}), \\
# biased:\qquad &\sigma(x,y)=\frac{1}{N}\sum_{i=1}^N(x_i-\bar{x})(y_i-\bar{y}).
# \end{aligned}
# $$

# %%
#@title Covariance
# %%html

<img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/covariance.svg'>
</img>
# Out:
# <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/covariance.svg'>
# </img>

# %% [markdown]
# Note that
#
# $$
# \rho(x,x)=\sigma_x^2
# $$
#
# Correlation also measures the strength of the relationship between samples. Correlation is the scaled measure of covariance. It is dimensionless. In other words, the correlation coefficient is always a pure value and not measured in any units.
#
# $$
# \rho(x,y)=\frac{\sigma(x,y)}{\sigma_x \sigma_y}.
# $$
#
# Note also that unlike covariation correlation coefficient is scale invariant, that means that if
#
# $$
# x^{\prime}_i=\alpha \, x_i, \\
# y^{\prime}_i=\beta \, y_i.
# $$
#
# we have
#
# $$
# \sigma(x^{\prime}, y^{\prime}) \neq \sigma(x, y),
# $$
#
# while
#
# $$
# \rho(x^{\prime}, y^{\prime}) = \rho(x, y).
# $$
#
# That means that correlation captures inherent linear relation between variables that is not dependent on the choice of scale.
#
# Correlation coefficient is also known as Pearson correlation coefficient (PCC).
# Informally you can think about $\rho(x,y)$ as a cosine of angle between two ''vectors''
#
#
# $$
# \cos{\alpha}=\frac{\bar{x}\bar{y}}{|\bar{x}||\bar{y}|}.
# $$
#
# Note that
#
# $$
# \rho(x,x)=\frac{\sigma_x^2}{\sigma_x \sigma_x}=1.
# $$
#
# Function ```corrcoef``` from  ```numpy``` gives matrix
#
# $$
# \begin{pmatrix}
# \rho(x,x)=1 & \rho(x,y) \\
# \rho(y,x) & \rho(y,y)=1
# \end{pmatrix}
# $$

# %%
x = [-2.1, -1,  4.3]
y = [3,  1.1,  0.12]
np.corrcoef(x, y)
# Out:
# array([[ 1.        , -0.85535781],
#        [-0.85535781,  1.        ]])

# %% [markdown]
# Here are several sets of $(x, y)$ points, with the Pearson correlation coefficient of $x$ and $y$ for each set. The correlation reflects the noisiness and direction of a linear relationship (top row), but not the slope of that relationship (middle), nor many aspects of nonlinear relationships (bottom). N.B.: the figure in the center has a slope of $0$ but in that case the correlation coefficient is undefined because the variance of $y$ is zero.
#
# <img src="https://raw.githubusercontent.com/fbeilstein/machine_learning/master/lecture_08_statistics/correlation_1.jpg" width="700px" />

# %%
#@title Correlation for a point cloud with adjustable parameters
# %%html
<iframe title="Demo"
        src="https://fbeilstein.github.io/machine_learning/lecture_08_statistics/demo_correlation.html"
        width="600" height="650"
        marginwidth="0" marginheight="0" frameborder="0"
        scrolling="no">
Your browser does not support IFrames.
</iframe>
# Out:
# <iframe title="Demo"
#         src="https://fbeilstein.github.io/machine_learning/lecture_08_statistics/demo_correlation.html"
#         width="600" height="650"
#         marginwidth="0" marginheight="0" frameborder="0"
#         scrolling="no">
# Your browser does not support IFrames.
# </iframe>

# %%
#@title Correlation of 2D points
# %%html
<iframe title="Demo"
        src="https://fbeilstein.github.io/machine_learning/lecture_08_statistics/demo_correlation_2d.html"
        width="800" height="650"
        marginwidth="0" marginheight="0" frameborder="0"
        scrolling="no">
Your browser does not support IFrames.
</iframe>
# Out:
# <iframe title="Demo"
#         src="https://fbeilstein.github.io/machine_learning/lecture_08_statistics/demo_correlation_2d.html"
#         width="800" height="650"
#         marginwidth="0" marginheight="0" frameborder="0"
#         scrolling="no">
# Your browser does not support IFrames.
# </iframe>

# %% [markdown]
# Correlations are useful because they can indicate a predictive relationship that can be exploited in practice. For example, an electrical utility may produce less power on a mild day based on the correlation between electricity demand and weather. In this example, there is a causal relationship, because extreme weather causes people to use more electricity for heating or cooling. However, in general, the presence of a correlation is not sufficient to infer the presence of a causal relationship (i.e., correlation does not imply causation).
#
# The phrase **"correlation does not imply causation"** refers to the inability to legitimately deduce a cause-and-effect relationship between two variables solely on the basis of an observed association or correlation between them.
# For any two correlated events, $A$ and $B$, the different possible relationships include:
# * $A$ causes $B$ (direct causation);
# * $B$ causes $A$ (reverse causation);
# * $A$ and $B$ are consequences of a common cause, but do not cause each other;
# * $A$ and $B$ both cause $C$, which is (explicitly or implicitly) conditioned on;
# * $A$ causes $B$ and $B$ causes $A$ (bidirectional or cyclic causation);
# * $A$ causes $C$ which causes $B$ (indirect causation);
# * There is no connection between $A$ and $B$; the correlation is a coincidence.
#
# Correlation is a valuable type of scientific evidence in fields such as medicine, psychology, and sociology. But first correlations must be confirmed as real, and then every possible causative relationship must be systematically explored. In the end correlation alone cannot be used as evidence for a cause-and-effect relationship between a treatment and benefit, a risk factor and a disease, or a social or economic factor and various outcomes. It is one of the most abused types of evidence, because it is easy and even tempting to come to premature conclusions based upon the preliminary appearance of a correlation.

# %% [markdown]
# #Anscombe's quartet

# %% [markdown]
# How useful are estimators for central tendency and spread? How different can be samples that have equal statistics?
# Take a look at [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet).
#
# Anscombe's quartet comprises four data sets that have nearly identical simple descriptive statistics, yet have very different distributions and appear very different when graphed. Each dataset consists of eleven $(x,y)$ points. They were constructed in 1973 by the statistician Francis Anscombe to demonstrate both the importance of graphing data before analyzing it and the effect of outliers and other influential observations on statistical properties. He described the article as being intended to counter the impression among statisticians that "numerical calculations are exact, but graphs are rough."
# All datasets have the same
# * mean of $x$
# * mean of $y$
# * sample variance of $x$
# * sample variance of $y$
# * correlation between $x$ and $y$
# * linear regression line
# * coefficient of determination

# %%
#@title Anscombe's quartet
# %%html

<img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/anscombes_quartet.svg'>
</img>
# Out:
# <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/anscombes_quartet.svg'>
# </img>

# %% [markdown]
# Anscombe's quartet teaches us that
# * statistical measures are not sufficient to describe the sample fully;
# * it's important to look at a set of data graphically before starting to analyze according to a particular type of relationship.
#
# If you want to study even more surprising example of desceptive data take a look at this [article](https://www.autodeskresearch.com/publications/samestats).

# %% [markdown]
# # Statistics, Probabiliy, and Machine Learning -- the bias-variance decomposition

# %% [markdown]
# **The nature of error -- bias-variance decomposition**
#
# * There exists a "law of nature" $f(\vec{x})$ we want to be able to predict
# * We can collect a dataset $D$ and train a model
# * trained on dataset $D$, the model $G$ yields a hypothesis $g_{D}(\vec{x})$ that should approximate $f(\vec{x})$
# * If we had known $f(\vec{x})$ somehow, we would have calculated the error
# $\text{err}_{D} = (f(\vec{x}) - g_{D}(\vec{x}))^2$ we get after training on $D$
# * If we want to avoid the dependence on $D$, we can calculate mean over all possible datasets
# $$
# \text{err} = \mathbb{E}_{\vec{x}} [\mathbb{E}_\mathcal{D}[(f(\vec{x}) - g_\mathcal{D}(\vec{x}))^2]]
# $$
# * We introduce the notion of "mean hypothesis"
# $$
# \bar{g}(\vec{x}) = \mathbb{E}_\mathcal{D}[g_\mathcal{D}(\vec{x}))]
# $$
# * We aim to show that
# $$
# \mathbb{E}_{\vec{x}} [\mathbb{E}_\mathcal{D}[(f(\vec{x}) - g_\mathcal{D}(\vec{x}))^2] ] =
#     \underbrace{\mathbb{E}_{\vec{x}} [(f(\vec{x}) - \bar{g}(\vec{x}))^2]}_{\mathbb{B}ias^2[f]} +
#     \underbrace{\mathbb{E}_{\vec{x}} [\mathbb{E}_\mathcal{D}[(\bar{g}(\vec{x}) - g_\mathcal{D}(\vec{x}))^2] ]}_{\mathbb{V}ar[f]}
# $$

# %% [markdown]
# **Why important?**
#
# * better understanding of mathematical backstages
# * bias-variance tradeoff
#    - may apply to all forms of supervised learning: classification, regression (function fitting), and structured output learning
#    - it does not apply in all learning algorithms!! the bias-variance tradeoff is not universal!!
#    - decomposition does not imply a bias-variance tradeoff and is still valid without it
#    - We can influence variance by changing the complexity of the model

# %%
#@title Bias/variance
# %%html

<img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/bias_variance.svg'>
</img>
# Out:
# <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/bias_variance.svg'>
# </img>

# %%
#@title ##High-bias and high-variance models

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

rng = np.random.RandomState(1)
x = 10 * rng.rand(20)
y = 5 - (5-x)**2 + rng.randn(20)*1.5
xv = 10 * rng.rand(20)
yv = 5 - (5-xv)**2 + rng.randn(20)*1.5
plt.figure(figsize=(15,12))
plt.subplot(2, 2, 1)
plt.title("Original data", fontdict={'size':20})
plt.scatter(x, y, c='b', label='train');
plt.scatter(xv, yv, c='r', label='validation');
plt.legend(loc='best')


from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

model = LinearRegression(fit_intercept=True)
model.fit(x[:, np.newaxis], y)
xfit = np.linspace(0, 10, 1000)
yfit = model.predict(xfit[:, np.newaxis])

plt.subplot(2, 2, 3)
plt.title("High-bias model; Underfits the data", fontdict={'size':20})
plt.scatter(x, y, c='b', label='train');
plt.scatter(xv, yv, c='r', label='validation');
plt.legend(loc='best')
plt.plot(xfit, yfit);

model = make_pipeline(PolynomialFeatures(2), LinearRegression())
model.fit(x[:, np.newaxis], y)
yfit = model.predict(xfit[:, np.newaxis])

plt.subplot(2, 2, 2)
plt.title("Desired result; Fits ok", fontdict={'size':20})
plt.scatter(x, y, c='b', label='train');
plt.scatter(xv, yv, c='r', label='validation');
plt.legend(loc='best')
plt.plot(xfit, yfit);

P = np.polyfit(x, y, 50, full=True)
yfit = np.polyval(P[0], xfit)

plt.subplot(2, 2, 4)
plt.title("High-variance model; Overfits the data", fontdict={'size':20})
plt.scatter(x, y, c='b', label='train');
plt.scatter(xv, yv, c='r', label='validation');
plt.legend(loc='best')
plt.ylim(-25, 10)
plt.plot(xfit, yfit);

# %% [markdown]
# **observation**
# * For high-bias models, the performance of the model on the validation set is similar to the performance on the training set.
# * For high-variance models, the performance of the model on the validation set is far worse than the performance on the training set.

# %%
#@title Bias-Variance decomposition proof

# %%html
<link rel="stylesheet" href="https://fbeilstein.github.io/machine_learning/js_common/styles.css"/>
<script src="https://fbeilstein.github.io/machine_learning/js_common/script.js"></script>
<script>
load_slides_from(
[
`
Suppose, our data is generated by some process \\(f(\\vec{x})\\).
Our model, when trained on dataset \\(D\\), yields \\(g_D(\\vec{x})\\).
What we will prove is
$$
\\mathbb{E}_{\\vec{x}} [\\mathbb{E}_\\mathcal{D}[(f(\\vec{x}) - g_\\mathcal{D}(\\vec{x}))^2] ] =
    \\underbrace{\\mathbb{E}_{\\vec{x}} [(f(\\vec{x}) - \\bar{g}(\\vec{x}))^2]}_{\\mathbb{B}ias^2[f]} +
    \\underbrace{\\mathbb{E}_{\\vec{x}} [\\mathbb{E}_\\mathcal{D}[(\\bar{g}(\\vec{x}) - g_\\mathcal{D}(\\vec{x}))^2] ]}_{\\mathbb{V}ar[f]}
$$
where
$$
\\bar{g}(\\vec{x}) = \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})]
$$
`,`
We expand the square of difference
$$
\\begin{aligned}
\\mathbb{E}_\\mathcal{D}[(f(\\vec{x}) - g_\\mathcal{D}(\\vec{x}))^2] &=
\\mathbb{E}_\\mathcal{D}[f^2(\\vec{x}) - 2 f(\\vec{x}) g_\\mathcal{D}(\\vec{x}) + g_\\mathcal{D}^2(\\vec{x})]
\\end{aligned}
$$
`,`
We use the property \\(\\mathbb{E}[X + Y] = \\mathbb{E}[X] +\\mathbb{E}[Y]\\)
$$
\\begin{aligned}
\\mathbb{E}_\\mathcal{D}[(f(\\vec{x}) - g_\\mathcal{D}(\\vec{x}))^2] &=
\\mathbb{E}_\\mathcal{D}[f^2(\\vec{x}) - 2 f(\\vec{x}) g_\\mathcal{D}(\\vec{x}) + g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
\\mathbb{E}_\\mathcal{D}[f^2(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[- 2 f(\\vec{x}) g_\\mathcal{D}(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})]
\\end{aligned}
$$
`,`
We use that \\(f\\) and constants are independent from dataset \\(\\mathcal{D}\\)
$$
\\begin{aligned}
\\mathbb{E}_\\mathcal{D}[(f(\\vec{x}) - g_\\mathcal{D}(\\vec{x}))^2] &=
\\mathbb{E}_\\mathcal{D}[f^2(\\vec{x}) - 2 f(\\vec{x}) g_\\mathcal{D}(\\vec{x}) + g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
\\mathbb{E}_\\mathcal{D}[f^2(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[- 2 f(\\vec{x}) g_\\mathcal{D}(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
f^2(\\vec{x}) - 2 f(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})]
\\end{aligned}
$$
`,`
Add and subtract the same quantity
$$
\\begin{aligned}
\\mathbb{E}_\\mathcal{D}[(f(\\vec{x}) - g_\\mathcal{D}(\\vec{x}))^2] &=
\\mathbb{E}_\\mathcal{D}[f^2(\\vec{x}) - 2 f(\\vec{x}) g_\\mathcal{D}(\\vec{x}) + g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
\\mathbb{E}_\\mathcal{D}[f^2(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[- 2 f(x) g_\\mathcal{D}(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
f^2(\\vec{x}) - 2 f(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
f^2(\\vec{x}) - 2 f(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})] + \\underbrace{\\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})] - \\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})]}_{= 0} + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})]
\\end{aligned}
$$
`,`
And collect everything
$$
\\begin{aligned}
\\mathbb{E}_\\mathcal{D}[(f(\\vec{x}) - g_\\mathcal{D}(\\vec{x}))^2] &=
\\mathbb{E}_\\mathcal{D}[f^2(\\vec{x}) - 2 f(\\vec{x}) g_\\mathcal{D}(\\vec{x}) + g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
\\mathbb{E}_\\mathcal{D}[f^2(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[- 2 f(x) g_\\mathcal{D}(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
f^2(\\vec{x}) - 2 f(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
f^2(\\vec{x}) - 2 f(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})] + \\underbrace{\\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})] - \\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})]}_{= 0} + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
(f(\\vec{x}) - \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})])^2 + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] - \\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})]
\\end{aligned}
$$
`,`
Complicated move (watch my hands!)
$$
\\begin{aligned}
\\mathbb{E}_\\mathcal{D}[(f(\\vec{x}) - g_\\mathcal{D}(\\vec{x}))^2] &=
\\mathbb{E}_\\mathcal{D}[f^2(\\vec{x}) - 2 f(\\vec{x}) g_\\mathcal{D}(\\vec{x}) + g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
\\mathbb{E}_\\mathcal{D}[f^2(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[- 2 f(x) g_\\mathcal{D}(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
f^2(\\vec{x}) - 2 f(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
f^2(\\vec{x}) - 2 f(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})] + \\underbrace{\\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})] - \\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})]}_{= 0} + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
(f(\\vec{x}) - \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})])^2 + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] - \\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})] =\\\\&=
(f(\\vec{x}) - \\bar{g}(\\vec{x}))^2 +
{\\color{blue}{\\mathbb{E}_\\mathcal{D}}}[g_\\mathcal{D}^2(\\vec{x})] -
2 {\\color{blue}{\\mathbb{E}_\\mathcal{D}}}{\\color{red}[}g_\\mathcal{D}(\\vec{x}){\\color{red}]} \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})] +
\\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})]
\\end{aligned}
$$
`,`
Complicated move (watch my hands!) Gobble coefficients
$$
\\begin{aligned}
\\mathbb{E}_\\mathcal{D}[(f(\\vec{x}) - g_\\mathcal{D}(\\vec{x}))^2] &=
\\mathbb{E}_\\mathcal{D}[f^2(\\vec{x}) - 2 f(\\vec{x}) g_\\mathcal{D}(\\vec{x}) + g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
\\mathbb{E}_\\mathcal{D}[f^2(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[- 2 f(x) g_\\mathcal{D}(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
f^2(\\vec{x}) - 2 f(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
f^2(\\vec{x}) - 2 f(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})] + \\underbrace{\\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})] - \\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})]}_{= 0} + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
(f(\\vec{x}) - \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})])^2 + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] - \\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})] =\\\\&=
(f(\\vec{x}) - \\bar{g}(\\vec{x}))^2 +
{\\color{blue}{\\mathbb{E}_\\mathcal{D}}}[g_\\mathcal{D}^2(\\vec{x})] -
2 {\\color{blue}{\\mathbb{E}_\\mathcal{D}}}{\\color{red}[}g_\\mathcal{D}(\\vec{x}){\\color{red}]} \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})] +
\\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})] =\\\\&=
(f(\\vec{x}) - \\bar{g}(\\vec{x}))^2 +
{\\color{blue}{\\mathbb{E}_\\mathcal{D}}}[g_\\mathcal{D}^2(\\vec{x})] +
{\\color{blue}{\\mathbb{E}_\\mathcal{D}}}{\\color{red}[}- 2 g_\\mathcal{D}(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})]{\\color{red}]} +
\\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})]
\\end{aligned}
$$
`,`
Complicated move (watch my hands!) Merge means
$$
\\begin{aligned}
\\mathbb{E}_\\mathcal{D}[(f(\\vec{x}) - g_\\mathcal{D}(\\vec{x}))^2] &=
\\mathbb{E}_\\mathcal{D}[f^2(\\vec{x}) - 2 f(\\vec{x}) g_\\mathcal{D}(\\vec{x}) + g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
\\mathbb{E}_\\mathcal{D}[f^2(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[- 2 f(x) g_\\mathcal{D}(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
f^2(\\vec{x}) - 2 f(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
f^2(\\vec{x}) - 2 f(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})] + \\underbrace{\\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})] - \\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})]}_{= 0} + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
(f(\\vec{x}) - \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})])^2 + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] - \\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})] =\\\\&=
(f(\\vec{x}) - \\bar{g}(\\vec{x}))^2 +
{\\color{blue}{\\mathbb{E}_\\mathcal{D}}}[g_\\mathcal{D}^2(\\vec{x})] -
2 {\\color{blue}{\\mathbb{E}_\\mathcal{D}}}{\\color{red}[}g_\\mathcal{D}(\\vec{x}){\\color{red}]} \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})] +
\\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})] =\\\\&=
(f(\\vec{x}) - \\bar{g}(\\vec{x}))^2 +
{\\color{blue}{\\mathbb{E}_\\mathcal{D}}}[g_\\mathcal{D}^2(\\vec{x})] +
{\\color{blue}{\\mathbb{E}_\\mathcal{D}}}{\\color{red}[}- 2 g_\\mathcal{D}(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})]{\\color{red}]} +
\\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})] =\\\\&=
(f(\\vec{x}) - \\bar{g}(\\vec{x}))^2 +
{\\color{blue}{\\mathbb{E}_\\mathcal{D}}}{\\color{red}[}g_\\mathcal{D}^2(\\vec{x}) - 2 g_\\mathcal{D}(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})]{\\color{red}]} +
\\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})]]
\\end{aligned}
$$
`,`
Complicated move (watch my hands!) Gobble constant
$$
\\begin{aligned}
\\mathbb{E}_\\mathcal{D}[(f(\\vec{x}) - g_\\mathcal{D}(\\vec{x}))^2] &=
\\mathbb{E}_\\mathcal{D}[f^2(\\vec{x}) - 2 f(\\vec{x}) g_\\mathcal{D}(\\vec{x}) + g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
\\mathbb{E}_\\mathcal{D}[f^2(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[- 2 f(x) g_\\mathcal{D}(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
f^2(\\vec{x}) - 2 f(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
f^2(\\vec{x}) - 2 f(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})] + \\underbrace{\\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})] - \\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})]}_{= 0} + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
(f(\\vec{x}) - \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})])^2 + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] - \\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})] =\\\\&=
(f(\\vec{x}) - \\bar{g}(\\vec{x}))^2 +
{\\color{blue}{\\mathbb{E}_\\mathcal{D}}}[g_\\mathcal{D}^2(\\vec{x})] -
2 {\\color{blue}{\\mathbb{E}_\\mathcal{D}}}{\\color{red}[}g_\\mathcal{D}(\\vec{x}){\\color{red}]} \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})] +
\\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})] =\\\\&=
(f(\\vec{x}) - \\bar{g}(\\vec{x}))^2 +
{\\color{blue}{\\mathbb{E}_\\mathcal{D}}}[g_\\mathcal{D}^2(\\vec{x})] +
{\\color{blue}{\\mathbb{E}_\\mathcal{D}}}{\\color{red}[}- 2 g_\\mathcal{D}(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})]{\\color{red}]} +
\\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})] =\\\\&=
(f(\\vec{x}) - \\bar{g}(\\vec{x}))^2 +
{\\color{blue}{\\mathbb{E}_\\mathcal{D}}}{\\color{red}[}g_\\mathcal{D}^2(\\vec{x}) - 2 g_\\mathcal{D}(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})]{\\color{red}]} +
\\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})] =\\\\&=
(f(\\vec{x}) - \\bar{g}(\\vec{x}))^2 +
{\\color{blue}{\\mathbb{E}_\\mathcal{D}}}{\\color{red}[}
        g_\\mathcal{D}^2(\\vec{x})
    - 2 g_\\mathcal{D}(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})]
    + \\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})]
{\\color{red}]}
\\end{aligned}
$$
`,`
Complicated move (watch my hands!) Simplify
$$
\\begin{aligned}
\\mathbb{E}_\\mathcal{D}[(f(\\vec{x}) - g_\\mathcal{D}(\\vec{x}))^2] &=
\\mathbb{E}_\\mathcal{D}[f^2(\\vec{x}) - 2 f(\\vec{x}) g_\\mathcal{D}(\\vec{x}) + g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
\\mathbb{E}_\\mathcal{D}[f^2(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[- 2 f(x) g_\\mathcal{D}(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
f^2(\\vec{x}) - 2 f(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
f^2(\\vec{x}) - 2 f(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})] + \\underbrace{\\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})] - \\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})]}_{= 0} + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
(f(\\vec{x}) - \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})])^2 + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] - \\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})] =\\\\&=
(f(\\vec{x}) - \\bar{g}(\\vec{x}))^2 +
{\\color{blue}{\\mathbb{E}_\\mathcal{D}}}[g_\\mathcal{D}^2(\\vec{x})] -
2 {\\color{blue}{\\mathbb{E}_\\mathcal{D}}}{\\color{red}[}g_\\mathcal{D}(\\vec{x}){\\color{red}]} \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})] +
\\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})] =\\\\&=
(f(\\vec{x}) - \\bar{g}(\\vec{x}))^2 +
{\\color{blue}{\\mathbb{E}_\\mathcal{D}}}[g_\\mathcal{D}^2(\\vec{x})] +
{\\color{blue}{\\mathbb{E}_\\mathcal{D}}}{\\color{red}[}- 2 g_\\mathcal{D}(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})]{\\color{red}]} +
\\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})] =\\\\&=
(f(\\vec{x}) - \\bar{g}(\\vec{x}))^2 +
{\\color{blue}{\\mathbb{E}_\\mathcal{D}}}{\\color{red}[}g_\\mathcal{D}^2(\\vec{x}) - 2 g_\\mathcal{D}(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})]{\\color{red}]} +
\\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})] =\\\\&=
(f(\\vec{x}) - \\bar{g}(\\vec{x}))^2 +
{\\color{blue}{\\mathbb{E}_\\mathcal{D}}}{\\color{red}[}
        g_\\mathcal{D}^2(\\vec{x})
    - 2 g_\\mathcal{D}(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})]
    + \\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})]
{\\color{red}]} =\\\\&=
(f(\\vec{x}) - \\bar{g}(\\vec{x}))^2 +
\\mathbb{E}_\\mathcal{D}[(g_\\mathcal{D}(\\vec{x}) - \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})])^2]
\\end{aligned}
$$
`,`
That is exactly the result we aimed
$$
\\begin{aligned}
\\mathbb{E}_\\mathcal{D}[(f(\\vec{x}) - g_\\mathcal{D}(\\vec{x}))^2] &=
\\mathbb{E}_\\mathcal{D}[f^2(\\vec{x}) - 2 f(\\vec{x}) g_\\mathcal{D}(\\vec{x}) + g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
\\mathbb{E}_\\mathcal{D}[f^2(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[- 2 f(x) g_\\mathcal{D}(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
f^2(\\vec{x}) - 2 f(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})] + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
f^2(\\vec{x}) - 2 f(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})] + \\underbrace{\\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})] - \\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})]}_{= 0} + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] =\\\\&=
(f(\\vec{x}) - \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})])^2 + \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}^2(\\vec{x})] - \\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})] =\\\\&=
(f(\\vec{x}) - \\bar{g}(\\vec{x}))^2 +
{\\color{blue}{\\mathbb{E}_\\mathcal{D}}}[g_\\mathcal{D}^2(\\vec{x})] -
2 {\\color{blue}{\\mathbb{E}_\\mathcal{D}}}{\\color{red}[}g_\\mathcal{D}(\\vec{x}){\\color{red}]} \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})] +
\\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})] =\\\\&=
(f(\\vec{x}) - \\bar{g}(\\vec{x}))^2 +
{\\color{blue}{\\mathbb{E}_\\mathcal{D}}}[g_\\mathcal{D}^2(\\vec{x})] +
{\\color{blue}{\\mathbb{E}_\\mathcal{D}}}{\\color{red}[}- 2 g_\\mathcal{D}(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})]{\\color{red}]} +
\\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})] =\\\\&=
(f(\\vec{x}) - \\bar{g}(\\vec{x}))^2 +
{\\color{blue}{\\mathbb{E}_\\mathcal{D}}}{\\color{red}[}g_\\mathcal{D}^2(\\vec{x}) - 2 g_\\mathcal{D}(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})]{\\color{red}]} +
\\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})] =\\\\&=
(f(\\vec{x}) - \\bar{g}(\\vec{x}))^2 +
{\\color{blue}{\\mathbb{E}_\\mathcal{D}}}{\\color{red}[}
        g_\\mathcal{D}^2(\\vec{x})
    - 2 g_\\mathcal{D}(\\vec{x}) \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})]
    + \\mathbb{E}_\\mathcal{D}^2[g_\\mathcal{D}(\\vec{x})]
{\\color{red}]} =\\\\&=
(f(\\vec{x}) - \\bar{g}(\\vec{x}))^2 +
\\mathbb{E}_\\mathcal{D}[(g_\\mathcal{D}(\\vec{x}) - \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})])^2] =\\\\&=
(f(\\vec{x}) - \\bar{g}(\\vec{x}))^2 +
\\mathbb{E}_\\mathcal{D}[(g_\\mathcal{D}(\\vec{x}) - \\bar{g}(\\vec{x}))^2]
\\end{aligned}
$$
<b>QED</b>
`
  ]
)
</script>
# Out:
# <link rel="stylesheet" href="https://fbeilstein.github.io/machine_learning/js_common/styles.css"/>
# <script src="https://fbeilstein.github.io/machine_learning/js_common/script.js"></script>
# <script>
# load_slides_from(
# [
# `
# Suppose, our data is generated by some process \\(f(\\vec{x})\\).
# Our model, when trained on dataset \\(D\\), yields \\(g_D(\\vec{x})\\).
# What we will prove is
# $$
# \\mathbb{E}_{\\vec{x}} [\\mathbb{E}_\\mathcal{D}[(f(\\vec{x}) - g_\\mathcal{D}(\\vec{x}))^2] ] =
#     \\underbrace{\\mathbb{E}_{\\vec{x}} [(f(\\vec{x}) - \\bar{g}(\\vec{x}))^2]}_{\\mathbb{B}ias^2[f]} +
#     \\underbrace{\\mathbb{E}_{\\vec{x}} [\\mathbb{E}_\\mathcal{D}[(\\bar{g}(\\vec{x}) - g_\\mathcal{D}(\\vec{x}))^2] ]}_{\\mathbb{V}ar[f]}
# $$
# where
# $$
# \\bar{g}(\\vec{x}) = \\mathbb{E}_\\mathcal{D}[g_\\mathcal{D}(\\vec{x})]
# $$
# `,`
# We expand the square of difference
# $$
# \\begin{aligned}
# \\mathbb{E}_\\mathcal{D}[(f(\\vec{x}) - g_\\mathcal{D}(\\vec{x}))^2] &=
# ...

# %%
#@title bias and variance
# %%html

<img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/bias_variance_function_space.svg'>
</img>
# Out:
# <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/bias_variance_function_space.svg'>
# </img>

# %% [markdown]
# **What does this look like in practice?**
#
# * The training score is everywhere higher than the validation score. This is generally the case: the model will be a better fit to data it has seen than to data it has not seen.
# * For very low model complexity (a high-bias model), the training data is underfit, which means that the model is a poor predictor both for the training data and for any previously unseen data.
# * For very high model complexity (a high-variance model), the training data is
# overfit, which means that the model predicts the training data very well, but fails
# for any previously unseen data.
# * For some intermediate value, the validation curve has a maximum. This level of
# complexity indicates a suitable trade-off between bias and variance.

# %%
#@title Validation Schematics
# %%html

<img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/validation_curve_schematics.svg'>
</img>
# Out:
# <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/validation_curve_schematics.svg'>
# </img>

# %%
#@title ##Example: Different approximations and validation

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline

def PolynomialRegression(degree=2, **kwargs):
  return make_pipeline(PolynomialFeatures(degree), LinearRegression(**kwargs))

import numpy as np

def make_data(N, err=1.0, rseed=1):
  # randomly sample the data
  rng = np.random.RandomState(rseed)
  X = rng.rand(N, 1) ** 2
  y = 10 - 1. / (X.ravel() + 0.1)
  if err > 0:
    y += err * rng.randn(N)
  return X, y

X, y = make_data(40)

import matplotlib.pyplot as plt
import seaborn; seaborn.set() # plot formatting

X_test = np.linspace(-0.1, 1.1, 500)[:, None]
plt.figure(figsize=(15,9))
plt.subplot(2,2,1)
plt.title("Approximation with polynomials\n of different degrees", fontdict={'size':20})
plt.scatter(X.ravel(), y, color='black')
axis = plt.axis()

for degree in [1, 3, 5]:
  y_test = PolynomialRegression(degree).fit(X, y).predict(X_test)
  plt.plot(X_test.ravel(), y_test, label='degree={0}'.format(degree))

plt.xlim(-0.1, 1.0)
plt.ylim(-2, 12)
plt.legend(loc='best');
#plt.show()


from sklearn.model_selection import validation_curve

degree = np.arange(0, 21)
train_score, val_score = validation_curve(PolynomialRegression(), X, y, 'polynomialfeatures__degree', degree, cv=7)
plt.subplot(2,2,2)
plt.title("Validation curve", fontdict={'size':20})
plt.plot(degree, np.median(train_score, 1), color='blue', label='training score')
plt.plot(degree, np.median(val_score, 1), color='red', label='validation score')
plt.xticks(degree)
plt.legend(loc='best')
plt.ylim(0, 1)
plt.xlabel('degree')
plt.ylabel('score');


plt.subplot(2,2,3)
plt.title("Best approximation", fontdict={'size':20})
plt.scatter(X.ravel(), y)
lim = plt.axis()
y_test = PolynomialRegression(3).fit(X, y).predict(X_test)
plt.plot(X_test.ravel(), y_test);
plt.axis(lim);

# %% [markdown]
# **dependence on the dataset size**
# * A model of a given complexity will overfit a small dataset: this means the training
# score will be relatively high, while the validation score will be relatively low.
# * A model of a given complexity will underfit a large dataset: this means that the
# training score will decrease, but the validation score will increase.
# * A model will never, except by chance, give a better score to the validation set than
# the training set: this means the curves should keep getting closer together but
# never cross.

# %%
#@title Learning
# %%html

<img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/learning_curve_schematics.svg'>
</img>
# Out:
# <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/learning_curve_schematics.svg'>
# </img>

# %% [markdown]
# ##Small counter-intuitive example

# %% [markdown]
# **The problem**
#
# * There exists certain unknown to you "law of nature" $f(x)$
# * Datapoints contain one feature that is a real number from $0$ to $1$
# * Class is a real number
# * You are given a dataset that contains exactly $2$ datapoints
# * You have two hypothesis sets $H_1$ -- constants $g(x) = a$ and $H_2$ -- arbitrary lines $g(x) = a x + b$
# * **Which one is better?**

# %%
#@title Problem setup
# %%html

<img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/example_problem_setup.svg'>
</img>
# Out:
# <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/example_problem_setup.svg'>
# </img>

# %%
#@title Bias-Variance decomposition proof

# %%html
<link rel="stylesheet" href="https://fbeilstein.github.io/machine_learning/js_common/styles.css"/>
<script src="https://fbeilstein.github.io/machine_learning/js_common/script.js"></script>
<script>
load_slides_from(
[
`
<list>
<li> Constant model
</list>
<br>
Given the dataset, i.e. \\((x_1;y_1)\\) and \\((x_2;y_2)\\) the best possible fit is
$$
    g_1(x) = \\frac{y_1 + y_2}{2}
$$
that leads to an error
$$
    e_1 = \\frac{(y_1 - y_2)^2}{2}
$$
<img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/example_constant_model.svg'>
</img>
`,`
Let \\(g(x) = a\\).
Datapoints have coordinates \\((x_1;y_1)\\) and \\((x_2;y_2)\\).
Designate \\(s_1(a) = a - y_1\\), \\(s_2(a) = y_2 - a\\), and \\(s = y_2 - y1\\).
<br>
<br>
<img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/example_constant_model_errors.svg'>
</img>
<br>
<br>
Taking into account that \\(s_1(a) + s_2(a) = s\\), we need to minimize
$$
\\begin{aligned}
\\min_{a}(s_1^2(a) + s_2^2(a)) &= \\phantom{=
\\min_{a}(s_1^2(a) + (s - s_1(a))^2) =
\\min_{a}(s_1^2(a) + s^2 - 2 s s_1(a) + s_1^2(a)) =} \\\\ & \\phantom{=
2\\min_{a}(s_1^2(a) - s s_1(a))}
\\end{aligned}
$$
`,`
Substitute \\(s_2(a) = s - s_1(a)\\) and simplify
$$
\\begin{aligned}
\\min_{a}(s_1^2(a) + s_2^2(a)) & =
\\min_{a}(s_1^2(a) + (s - s_1(a))^2) =
\\min_{a}(s_1^2(a) + s^2 - 2 s s_1(a) + s_1^2(a)) = \\\\ & =
2\\min_{a}(s_1^2(a) - s s_1(a))
\\end{aligned}
$$
`,`
Suppose \\(\\min_{a}(s_1^2(a) - s s_1(a))\\) is achieved at \\(a = \\hat{a}\\).
Recall \\(s_1(a) = a - y_1\\) and \\(s = y_2 - y1\\).
Use standard calculus technique
$$
0 =
\\left.\\frac{d}{da}(s_1^2(a) - s s_1(a))\\right|_{a = \\hat{a}} =
\\left.(2 s_1(a) - s)\\right|_{a = \\hat{a}} =
2 \\hat{a} - y_1 - y_2 \\Rightarrow
\\hat{a} = \\frac{y_1 + y_2}{2}.
$$
`,`
Substitution to \\(\\min\\) yields the result
$$
    e_1 = \\frac{(y_1 - y_2)^2}{2}
$$
`
  ]
)
</script>
# Out:
# <link rel="stylesheet" href="https://fbeilstein.github.io/machine_learning/js_common/styles.css"/>
# <script src="https://fbeilstein.github.io/machine_learning/js_common/script.js"></script>
# <script>
# load_slides_from(
# [
# `
# <list>
# <li> Constant model
# </list>
# <br>
# Given the dataset, i.e. \\((x_1;y_1)\\) and \\((x_2;y_2)\\) the best possible fit is
# $$
#     g_1(x) = \\frac{y_1 + y_2}{2}
# $$
# that leads to an error
# $$
#     e_1 = \\frac{(y_1 - y_2)^2}{2}
# $$
# <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/example_constant_model.svg'>
# </img>
# `,`
# Let \\(g(x) = a\\).
# Datapoints have coordinates \\((x_1;y_1)\\) and \\((x_2;y_2)\\).
# Designate \\(s_1(a) = a - y_1\\), \\(s_2(a) = y_2 - a\\), and \\(s = y_2 - y1\\).
# <br>
# <br>
# <img src='https://fbeilstein.github.io/machine_learning/lecture_08_statistics/example_constant_model_errors.svg'>
# </img>
# <br>
# <br>
# ...

# %%
#@title Mean squared error for linear model

# %%html
<script src='https://www.gstatic.com/external_hosted/mathjax/latest/MathJax.js?config=default'></script>

<div id="all_slides">

<div>
<list>
<li> Linear model
</list>
One can always draw a line through two points, say
$$
    g_2(x) = y_2 + \frac{x - x_2}{x_1 - x_2} (y_1 - y_2)
$$
that leads to an error
$$
    e_2 = 0
$$
<?xml version="1.0" encoding="UTF-8" standalone="no"?>
<!-- Created with Inkscape (http://www.inkscape.org/) -->

<svg width="111.88mm" height="80.873mm" version="1.1" viewBox="0 0 111.88 80.873" xmlns="http://www.w3.org/2000/svg" xmlns:ns0="http://www.iki.fi/pav/software/textext/">
 <defs>
  <marker id="a" overflow="visible" orient="auto">
   <path transform="matrix(-.4 0 0 -.4 -4 0)" d="m0 0 5-5-17.5 5 17.5 5z" fill-opacity=".90196" fill-rule="evenodd" stroke="#000" stroke-opacity=".90196" stroke-width="1pt"/>
  </marker>
  <marker id="b" overflow="visible" orient="auto">
   <path transform="matrix(-.4 0 0 -.4 -4 0)" d="m0 0 5-5-17.5 5 17.5 5z" fill-opacity=".90196" fill-rule="evenodd" stroke="#000" stroke-opacity=".90196" stroke-width="1pt"/>
  </marker>
 </defs>
 <g transform="translate(132.94 -3.3342)">
  <text x="35.246281" y="42.149555" fill="#000000" font-family="Verdana" font-size="10.583px" letter-spacing="0px" stroke-width=".26458" word-spacing="0px" style="line-height:1.25" xml:space="preserve"><tspan x="35.246281" y="51.80505" stroke-width=".26458"/></text>
  <text x="76.906807" y="21.511925" fill="#000000" font-family="Verdana" font-size="10.583px" letter-spacing="0px" stroke-width=".26458" word-spacing="0px" style="line-height:1.25" xml:space="preserve"><tspan x="76.906807" y="31.167419" stroke-width=".26458"/></text>
  <g transform="matrix(1.2512 0 0 -1.2512 -160.51 876.57)" fill-rule="evenodd" stroke="#000" stroke-miterlimit="10.433" stroke-width="1.1988" ns0:preamble="default_packages.tex" ns0:text="$p q$\n" xml:space="preserve"><g transform="matrix(1.5 0 0 -1.5 -165.9 1212.8)" fill-rule="evenodd" stroke="#000" stroke-miterlimit="10.433" ns0:preamble="default_packages.tex" ns0:text="$\\text{delete readjust}$\n" xml:space="preserve"><g transform="matrix(1.5 0 0 -1.5 -165.59 1212.8)" fill-rule="evenodd" stroke="#000" stroke-miterlimit="10.433" ns0:preamble="default_packages.tex" ns0:text="$delete readjust$\n" xml:space="preserve"><flowRoot fill="#000000" font-family="Verdana" font-size="40px" letter-spacing="0px" stroke="none" word-spacing="0px" style="line-height:1.25" xml:space="preserve"><flowRegion><rect x="78.929" y="457.16" width="60" height="76.429"/></flowRegion><flowPara/></flowRoot><g transform="matrix(.20006 0 0 .20006 165.85 418.79)" fill-rule="evenodd" stroke-miterlimit="10.433" stroke-width="8.9882" ns0:preamble="default_packages.tex" ns0:text="$f bias variance All functions Learnable functions$\n" xml:space="preserve"><path d="m155.58 661.29v140.65" fill="none" marker-end="url(#a)" stroke="#000" stroke-miterlimit="10.433" stroke-opacity=".90196" stroke-width=".64804"/><path d="m142.21 674.98h177.12" fill="none" marker-end="url(#b)" stroke="#000" stroke-miterlimit="10.433" stroke-opacity=".90196" stroke-width=".64804"/><ellipse transform="scale(1,-1)" cx="241.13" cy="-761.79" rx="2.3559" ry="2.3559" fill="#003186" fill-opacity=".59608" stroke="none"/><g transform="matrix(1.5 0 0 1.5 17.997 -402.96)" fill-rule="evenodd" stroke="#000" stroke-miterlimit="10.433" ns0:preamble="default_packages.tex" ns0:text="feature $x y$\n" xml:space="preserve"><g><g stroke-width="0"><path d="m186.99 714.58v0.71485c0 0.54081 0.29838 0.83918 0.57188 0.83918 0.0124 0 0.10568 0 0.19892-0.0435-0.0746-0.0249-0.18648-0.10567-0.18648-0.26
235 0.0113 0.0236 0.0113 0.0345 0.0241 0.0929 0.0589 0.16244 0.10613 0.34911 0.21102 0.0235 0.0113 0.0224 0.0247 0.0345 0.0241 0.0937 0.0461 0.16141 0.11922 0.0235 0.0113 0.0236 0.0114 0.0471 0.0226 0.0808 0.0593 0.0235 0.0113 0.0236 0.0114 0.0345 0.0241 0.0236 0.0114 0.0224 0.0247 0.0235 0.0113 0.0236 0.0114" fill="none" stroke="#ac4100" stroke-linecap="square" stroke-miterlimit="3" stroke-opacity=".59608" stroke-width=".65455"/></g></g></g></g></g>
 </g>
</svg>


</div>


<div>
Obviously, expression
$$
    g_2(x) = y_2 + \frac{\color{red}{x} - x_2}{x_1 - x_2} (y_1 - y_2)
$$
defines a linear function.
</div>

<div>
For \(x = x_1\) we have
$$
    g_2(x_1) = y_2 + \frac{\color{red}{x_1} - x_2}{x_1 - x_2} (y_1 - y_2)
             = y_2 + (y_1 - y_2) = y_1
$$
For \(x = x_2\) we have
$$
    g_2(x_2) = y_2 + \frac{\color{red}{x_2} - x_2}{x_1 - x_2} (y_1 - y_2)
             = y_2
$$
This proves that the line passes through \((x_1;y_1)\) and \((x_2;y_2)\).
</div>


</div>

<div style="position:absolute; top:30px; left:900px;">

<div id="arrow_left" style="border-width: 1px; border-style:solid; float:left; height:32px;">
<svg width="8.7464mm" height="8.7464mm" version="1.1" viewBox="0 0 8.7464 8.7464" xmlns="http://www.w3.org/2000/svg" xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
<metadata>
<rdf:RDF>
<cc:Work rdf:about="">
<dc:format>image/svg+xml</dc:format>
<dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
<dc:title/>
</cc:Work>
</rdf:RDF>
</metadata>
<g transform="translate(-38.564 -29.908)">
<rect x="38.564" y="29.908" width="8.7464" height="8.7464" fill-opacity=".16425" opacity=".97" stroke-miterlimit="10.433" stroke-width="0"/>
<path d="m45.796 34.331h-5.8931" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m40.068 34.267 2.7141-2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m40.069 34.396 2.7141 2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
</g>
</svg>
</div>

<div id="arrow_right" style="border-width: 1px; border-style:solid; float:right; height:32px;">
<svg width="8.7464mm" height="8.7464mm" version="1.1" viewBox="0 0 8.7464 8.7464" xmlns="http://www.w3.org/2000/svg" xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
<metadata>
<rdf:RDF>
<cc:Work rdf:about="">
<dc:format>image/svg+xml</dc:format>
<dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
<dc:title/>
</cc:Work>
</rdf:RDF>
</metadata>
<g transform="translate(-38.564 -29.908)">
<rect transform="scale(-1,1)" x="-47.31" y="29.908" width="8.7464" height="8.7464" fill-opacity=".16425" opacity=".97" stroke-miterlimit="10.433" stroke-width="0"/>
<path d="m40.078 34.331h5.8931" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m45.806 34.267-2.7141-2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m45.805 34.396-2.7141 2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
</g>
</svg>
</div>

</div>

<style>
#arrow_left:hover{color:blue;}
#arrow_right:hover{color:blue;}
</style>

<script  type="text/javascript">
//var slides = ["slide_1", "slide_2", "slide_3"];

var container = document.getElementById("all_slides");
var menu_conn = document.createElement("div");
menu_conn.style.height = "90px";
menu_conn.id = "menu_div";
container.prepend(menu_conn);

// crutches
var slides = [];
var tmp = container.getElementsByTagName("div");
for (var i = 0; i < tmp.length; ++i)
  if (!tmp[i].id || tmp[i].id != "menu_div")
  {
    tmp[i].classList.add('slide_style');
    slides.push(tmp[i]);
  }


var left_btn_id = "arrow_left";
var right_btn_id = "arrow_right";
var current_slide = 0;
var menu = [];

function change_slide_to(new_slide_idx)
{
  menu[current_slide].style.borderWidth = "0px";
  var old_slide = slides[current_slide]; //document.getElementById(slides[current_slide]);
  current_slide = new_slide_idx;
  menu[current_slide].style.borderWidth = "2px";
  var new_slide = slides[current_slide]; //document.getElementById(slides[current_slide]);
  old_slide.style.display='none';
  new_slide.style.display='block';
}

function slide_left()
{
  var new_idx = current_slide - 1;
  if (new_idx < 0) {new_idx = 0;}
  change_slide_to(new_idx);
}

function slide_right()
{
  var new_idx = current_slide + 1;
  if (new_idx >= slides.length) {new_idx = slides.length - 1;}
  change_slide_to(new_idx);
}

function change(obj, is_correct)
{
//   alert(obj.parentNode.rowIndex);
    var rowId = obj.parentNode.rowIndex;
    var table = obj.parentNode.parentNode.parentNode;
    var rowsNotSelected = table.getElementsByTagName('tr');
    for (var row = 0; row < rowsNotSelected.length; row++)
    {
        rowsNotSelected[row].cells[0].style.backgroundColor = "white";
    }
    var rowSelected = table.getElementsByTagName('tr')[rowId];
    if (is_correct > 0)
    {
        rowSelected.cells[0].style.backgroundColor = "#66bb6aa9";
        menu[current_slide].style.backgroundColor = "#66bb6aa9";
    }
    else
    {
        rowSelected.cells[0].style.backgroundColor = "#ff3a3981";
        menu[current_slide].style.backgroundColor = "#ff3a3981";
    }
}

function make_callback(obj, is_correct)
{
  return function() { change(obj, is_correct); }
}

function change_callback(new_idx)
{
  return function() { change_slide_to(new_idx); }
}

document.getElementById(left_btn_id).addEventListener("click", slide_left);
document.getElementById(right_btn_id).addEventListener("click", slide_right);
slides[current_slide].style.display='block'; //document.getElementById(slides[current_slide]).style.display='block';

// create upper menu
upper_menu = document.getElementById("menu_div");

var tbl      = document.createElement("table");
var tbl_body = document.createElement("tbody");
var tbl_row  = document.createElement("tr");
for (idx = 0; idx < slides.length; idx++)
{
    var tbl_cell = document.createElement("td");
    var cell_text = document.createTextNode(idx+1);
    tbl_cell.appendChild(cell_text);
    tbl_cell.onclick = change_callback(idx);
    tbl_row.appendChild(tbl_cell);
    menu.push(tbl_cell);
    tbl_cell.style.borderWidth = "0px";

    var slide = slides[idx]; //document.getElementById(slides[idx]);
    var all_tables = slide.getElementsByTagName("table");
    for (t_i = 0; t_i < all_tables.length; t_i++)
    {
      var table = all_tables[t_i];
      if (!table.classList.contains("question_style"))
        continue;
      var rows = table.getElementsByTagName('tr');
      for (r_i = 0; r_i < rows.length; r_i++)
      {
        var question_cell = rows[r_i].cells[0];
        question_cell.classList.add("highlight");
        if (question_cell.classList.contains("ok"))
        {
          question_cell.onclick = make_callback(question_cell, 1);
        } else {
          question_cell.onclick = make_callback(question_cell, 0);
        }


        var cell = rows[r_i].insertCell(0);
        cell.width = "50px";
      }
    }
}
tbl_body.appendChild(tbl_row);
tbl.appendChild(tbl_body);
upper_menu.appendChild(tbl);
tbl.classList.add('menu_style');
menu[current_slide].style.borderWidth = "2px";

</script>

<style>
    .slide_style {
      max-width:750px;
      display:none;
      font: 14pt/18pt sans-serif;
      position: static;
      top: 80px;
      left: 0px;
    }

    .question_style {
        width:600px;
        font: 16pt/14pt sans-serif bold;
        text-align:left;
        cursor: default;
    }
    .question_style td{
        padding:7px;
        height: 50px;
        border:#4e95f4 0px solid;
        text-align:left;
        font: 13pt/16pt sans-serif;
    }
    .highlight:hover{
        background-color: #00000019
    }
    .menu_style {
        height:50px;
        font: 16pt/14pt sans-serif bold;
        text-align:left;
        cursor: default;
    }
    .menu_style td{
        width:50px;
        padding:7px;
        border:#787878ff solid;
        text-align:center;
        font: 16pt/14pt sans-serif;
        color: #606060ff;
    }
</style>
# Out:
# <script src='https://www.gstatic.com/external_hosted/mathjax/latest/MathJax.js?config=default'></script>
#
# <div id="all_slides">
#
# <div>
# <list>
# <li> Linear model
# </list>
# One can always draw a line through two points, say
# $$
#     g_2(x) = y_2 + \frac{x - x_2}{x_1 - x_2} (y_1 - y_2)
# $$
# that leads to an error
# $$
#     e_2 = 0
# $$
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!-- Created with Inkscape (http://www.inkscape.org/) -->
#
# <svg width="111.88mm" height="80.873mm" version="1.1" viewBox="0 0 111.88 80.873" xmlns="http://www.w3.org/2000/svg" xmlns:ns0="http://www.iki.fi/pav/software/textext/">
#  <defs>
#   <marker id="a" overflow="visible" orient="auto">
#    <path transform="matrix(-.4 0 0 -.4 -4 0)" d="m0 0 5-5-17.5 5 17.5 5z" fill-opacity=".90196" fill-rule="evenodd" stroke="#000" stroke-opacity=".90196" stroke-width="1pt"/>
#   </marker>
#   <marker id="b" overflow="visible" orient="auto">
# ...

# %% [markdown]
# **Conclusions**
#
# Seems like $H_2$ wins, but this proof is bad.

# %% [markdown]
# **Why this result is wrong?**
#
# * Most cases we are not interested in model's performance on training set, but on real data. Say it another way: I have just tested the models on the train set. Never ever do that (and a bit later you'll see why).

# %% [markdown]
# **How do we test on real data?**
#
# * In real life we have validation set
# * Suppose for simplicity you know that $f(x) = 4/9 - (x - 2/3)^2$
# * Can you tell now, which model is better?

# %%
#@title Best fit for constant model

# %%html
<script src='https://www.gstatic.com/external_hosted/mathjax/latest/MathJax.js?config=default'></script>

<div id="all_slides">

<div>
<list>
<li> Constant model
</list>
<br>
Expression for square error is
$$
   e_1(a)
 = \int\limits_0^1 (f(x) - a)^2 dx
$$
The best result we can expect
$$
\min_{a} e_1(a) = \frac{2}{135} \approx 0.015
$$
<?xml version="1.0" encoding="UTF-8" standalone="no"?>
<!-- Created with Inkscape (http://www.inkscape.org/) -->

<svg width="111.88mm" height="80.873mm" version="1.1" viewBox="0 0 111.88 80.873" xmlns="http://www.w3.org/2000/svg" xmlns:ns0="http://www.iki.fi/pav/software/textext/">
 <defs>
  <marker id="a" overflow="visible" orient="auto">
   <path transform="matrix(-.4 0 0 -.4 -4 0)" d="m0 0 5-5-17.5 5 17.5 5z" fill-opacity=".2657" fill-rule="evenodd" stroke="#000" stroke-opacity=".2657" stroke-width="1pt"/>
  </marker>
  <marker id="b" overflow="visible" orient="auto">
   <path transform="matrix(-.4 0 0 -.4 -4 0)" d="m0 0 5-5-17.5 5 17.5 5z" fill-opacity=".90196" fill-rule="evenodd" stroke="#000" stroke-opacity=".90196" stroke-width="1pt"/>
  </marker>
 </defs>
 <g transform="translate(132.94 -3.3342)">
  <text x="35.246281" y="42.149555" fill="#000000" font-family="Verdana" font-size="10.583px" letter-spacing="0px" stroke-width=".26458" word-spacing="0px" style="line-height:1.25" xml:space="preserve"><tspan x="35.246281" y="51.80505" stroke-width=".26458"/></text>
  <text x="76.906807" y="21.511925" fill="#000000" font-family="Verdana" font-size="10.583px" letter-spacing="0px" stroke-width=".26458" word-spacing="0px" style="line-height:1.25" xml:space="preserve"><tspan x="76.906807" y="31.167419" stroke-width=".26458"/></text>
  <g transform="matrix(1.2512 0 0 -1.2512 -160.51 876.57)" fill-rule="evenodd" stroke="#000" stroke-miterlimit="10.433" stroke-width="1.1988" ns0:preamble="default_packages.tex" ns0:text="$p q$\n" xml:space="preserve"><g transform="matrix(1.5 0 0 -1.5 -165.9 1212.8)" fill-rule="evenodd" stroke="#000" stroke-miterlimit="10.433" ns0:preamble="default_packages.tex" ns0:text="$\\text{delete readjust}$\n" xml:space="preserve"><g transform="matrix(1.5 0 0 -1.5 -165.59 1212.8)" fill-rule="evenodd" stroke-miterlimit="10.433" ns0:preamble="
" y2="708.94" stroke="#000" stroke-opacity=".90196" stroke-width="1.0543"/><path d="m151.75 703.74h0.1442l0.0721-0.0144h0.0577l0.0721-0.0144 0.0721-0.0288 0.0577-0.0144 0.0577-0.0288 0.0721-0.0288 0.1154-0.0576 0.0433-0.0433 0.0577-0.0288 0.0433-0.0432 0.0577-0.0433 0.0432-0.0577 0.0433-0.0433 0.0432-0.0577 0.0433-0.0577 0.0288-0.0721 0.0288-0.0577 0.0433-0.0721 0.0288-0.0721 0.0144-0.0721 0.0288-0.0721 0.0144-0.0865 0.0288-0.0865 0.0144-0.0865v-0.0865l0.0144-0.0865v-0.20181c0-1.2397-0.72076-1.6145-1.2974-1.6145-0.40363 0-1.2974 0.11533-1.7154 0.70635 0.47571 0.0144 0.57661 0.34597 0.57661 0.56219 0 0.31714-0.24506 0.54778-0.54778 0.54778-0.2883 0-0.56219-0.17298-0.56219-0.57661 0-0.9514 1.0379-1.5568 2.2632-1.5568 1.3983 0 2.3641 0.93699 2.3641 1.9316 0 0.77842-0.64869 1.5713-1.7442 1.8019 1.0523 0.3748 1.4415 1.1244 1.4415 1.7442 0 0.79284-0.92257 1.3839-2.047 1.3839-1.11 0-1.9749-0.54778-1.9749-1.3406 0-0.34596 0.23064-0.53336 0.53336-0.53336s0.50454 0.23064 0.50454 0.50453c0 0.28831-0.20182 0.50454-0.50454 0.51895 0.34597 0.44687 1.0379 0.5622 1.4127 0.5622 0.46128 0 1.0956-0.23065 1.0956-1.0956 0-0.41804-0.14415-0.87933-0.40362-1.1965-0.33155-0.37479-0.61986-0.40362-1.1244-0.43245-0.24506-0.0144-0.27389-0.0144-0.31714-0.0288-0.0288 0-0.1009-0.0144-0.1009-0.12974 0-0.14415 0.0865-0.14415 0.25947-0.14415z" stroke-width="0"/></g></g></g></g></g></g></g>
 </g>
</svg>


</div>

<div>
<b>Proof:</b><br>
Write by definition
$$
\begin{aligned}
\min_{a} e_1(a) &=
  \min_{a} \int\limits_0^1 [4/9 - (x - 2/3)^2 - a]^2 dx =\\
&\phantom{= \min_{a} \int\limits_{-2/3}^{1/3} [(4/9 - a) - x^2]^2 dx =}\\
&\phantom{= \min_{a} \int\limits_{-2/3}^{1/3} (4/9 - a)^2 - 2 x^2 (4/9 - a) + x^4 dx =}\\
&\phantom{= \frac{17}{135} + \min_{a} \left(a^2 - \frac{2a}{3}\right)}
\end{aligned}
$$
</div>

<div>
<b>Proof:</b><br>
Change limits
$$
\begin{aligned}
\min_{a} e_1(a) &=
  \min_{a} \int\limits_0^1 [4/9 - (x - 2/3)^2 - a]^2 dx =\\
&= \min_{a} \int\limits_{-2/3}^{1/3} [(4/9 - a) - x^2]^2 dx =\\
&\phantom{= \min_{a} \int\limits_{-2/3}^{1/3} (4/9 - a)^2 - 2 x^2 (4/9 - a) + x^4 dx =}\\
&\phantom{= \frac{17}{135} + \min_{a} \left(a^2 - \frac{2a}{3}\right)}
\end{aligned}
$$
</div>

<div>
<b>Proof:</b><br>
Expand square
$$
\begin{aligned}
\min_{a} e_1(a) &=
  \min_{a} \int\limits_0^1 [4/9 - (x - 2/3)^2 - a]^2 dx =\\
&= \min_{a} \int\limits_{-2/3}^{1/3} [(4/9 - a) - x^2]^2 dx =\\
&= \min_{a} \int\limits_{-2/3}^{1/3} (4/9 - a)^2 - 2 x^2 (4/9 - a) + x^4 dx =\\
&\phantom{= \frac{17}{135} + \min_{a} \left(a^2 - \frac{2a}{3}\right)}
\end{aligned}
$$
</div>

<div>
<b>Proof:</b><br>
Integrate
$$
\begin{aligned}
\min_{a} e_1(a) &=
  \min_{a} \int\limits_0^1 [4/9 - (x - 2/3)^2 - a]^2 dx =\\
&= \min_{a} \int\limits_{-2/3}^{1/3} [(4/9 - a) - x^2]^2 dx =\\
&= \min_{a} \int\limits_{-2/3}^{1/3} (4/9 - a)^2 - 2 x^2 (4/9 - a) + x^4 dx =\\
&= \frac{17}{135} + \min_{a} \left(a^2 - \frac{2a}{3}\right)
\end{aligned}
$$
</div>

<div>
<b>Proof:</b><br>
Minimize over \(a\) by means of calculus
$$
\begin{aligned}
   \min_{a} e_1(a)
 = \frac{17}{135} + \min_{a} \left(a^2 - \frac{2a}{3}\right)
\end{aligned}
$$
minimum is obtained when \(a = \hat{a}\)
$$
0 = \left.\frac{d}{da} (a^2 - \frac{2a}{3})\right|_{a=\hat{a}}
$$
</div>

<div>
<b>Proof:</b><br>
Minimize over \(a\) by means of calculus
$$
\begin{aligned}
   \min_{a} e_1(a)
 = \frac{17}{135} + \min_{a} \left(a^2 - \frac{2a}{3}\right)
\end{aligned}
$$
minimum is obtained when \(a = \hat{a}\)
$$
0 = \left.\frac{d}{da} (a^2 - \frac{2a}{3})\right|_{a=\hat{a}}
= 2 \hat{a} - \frac{2}{3}
$$
</div>

<div>
<b>Proof:</b><br>
Minimize over \(a\) by means of calculus
$$
\begin{aligned}
   \min_{a} e_1(a)
 = \frac{17}{135} + \min_{a} \left(a^2 - \frac{2a}{3}\right)
\end{aligned}
$$
minimum is obtained when \(a = \hat{a}\)
$$
\hat{a} = \frac{1}{3}
$$
</div>

<div>
<b>Proof:</b><br>
Minimize over \(a\) by means of calculus
$$
\begin{aligned}
   \min_{a} e_1(a)
 = \frac{2}{135}
\end{aligned}
$$
</div>

</div>

<div style="position:absolute; top:30px; left:900px;">

<div id="arrow_left" style="border-width: 1px; border-style:solid; float:left; height:32px;">
<svg width="8.7464mm" height="8.7464mm" version="1.1" viewBox="0 0 8.7464 8.7464" xmlns="http://www.w3.org/2000/svg" xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
<metadata>
<rdf:RDF>
<cc:Work rdf:about="">
<dc:format>image/svg+xml</dc:format>
<dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
<dc:title/>
</cc:Work>
</rdf:RDF>
</metadata>
<g transform="translate(-38.564 -29.908)">
<rect x="38.564" y="29.908" width="8.7464" height="8.7464" fill-opacity=".16425" opacity=".97" stroke-miterlimit="10.433" stroke-width="0"/>
<path d="m45.796 34.331h-5.8931" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m40.068 34.267 2.7141-2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m40.069 34.396 2.7141 2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
</g>
</svg>
</div>

<div id="arrow_right" style="border-width: 1px; border-style:solid; float:right; height:32px;">
<svg width="8.7464mm" height="8.7464mm" version="1.1" viewBox="0 0 8.7464 8.7464" xmlns="http://www.w3.org/2000/svg" xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
<metadata>
<rdf:RDF>
<cc:Work rdf:about="">
<dc:format>image/svg+xml</dc:format>
<dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
<dc:title/>
</cc:Work>
</rdf:RDF>
</metadata>
<g transform="translate(-38.564 -29.908)">
<rect transform="scale(-1,1)" x="-47.31" y="29.908" width="8.7464" height="8.7464" fill-opacity=".16425" opacity=".97" stroke-miterlimit="10.433" stroke-width="0"/>
<path d="m40.078 34.331h5.8931" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m45.806 34.267-2.7141-2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m45.805 34.396-2.7141 2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
</g>
</svg>
</div>

</div>

<style>
#arrow_left:hover{color:blue;}
#arrow_right:hover{color:blue;}
</style>

<script  type="text/javascript">
//var slides = ["slide_1", "slide_2", "slide_3"];

var container = document.getElementById("all_slides");
var menu_conn = document.createElement("div");
menu_conn.style.height = "90px";
menu_conn.id = "menu_div";
container.prepend(menu_conn);

// crutches
var slides = [];
var tmp = container.getElementsByTagName("div");
for (var i = 0; i < tmp.length; ++i)
  if (!tmp[i].id || tmp[i].id != "menu_div")
  {
    tmp[i].classList.add('slide_style');
    slides.push(tmp[i]);
  }


var left_btn_id = "arrow_left";
var right_btn_id = "arrow_right";
var current_slide = 0;
var menu = [];

function change_slide_to(new_slide_idx)
{
  menu[current_slide].style.borderWidth = "0px";
  var old_slide = slides[current_slide]; //document.getElementById(slides[current_slide]);
  current_slide = new_slide_idx;
  menu[current_slide].style.borderWidth = "2px";
  var new_slide = slides[current_slide]; //document.getElementById(slides[current_slide]);
  old_slide.style.display='none';
  new_slide.style.display='block';
}

function slide_left()
{
  var new_idx = current_slide - 1;
  if (new_idx < 0) {new_idx = 0;}
  change_slide_to(new_idx);
}

function slide_right()
{
  var new_idx = current_slide + 1;
  if (new_idx >= slides.length) {new_idx = slides.length - 1;}
  change_slide_to(new_idx);
}

function change(obj, is_correct)
{
//   alert(obj.parentNode.rowIndex);
    var rowId = obj.parentNode.rowIndex;
    var table = obj.parentNode.parentNode.parentNode;
    var rowsNotSelected = table.getElementsByTagName('tr');
    for (var row = 0; row < rowsNotSelected.length; row++)
    {
        rowsNotSelected[row].cells[0].style.backgroundColor = "white";
    }
    var rowSelected = table.getElementsByTagName('tr')[rowId];
    if (is_correct > 0)
    {
        rowSelected.cells[0].style.backgroundColor = "#66bb6aa9";
        menu[current_slide].style.backgroundColor = "#66bb6aa9";
    }
    else
    {
        rowSelected.cells[0].style.backgroundColor = "#ff3a3981";
        menu[current_slide].style.backgroundColor = "#ff3a3981";
    }
}

function make_callback(obj, is_correct)
{
  return function() { change(obj, is_correct); }
}

function change_callback(new_idx)
{
  return function() { change_slide_to(new_idx); }
}

document.getElementById(left_btn_id).addEventListener("click", slide_left);
document.getElementById(right_btn_id).addEventListener("click", slide_right);
slides[current_slide].style.display='block'; //document.getElementById(slides[current_slide]).style.display='block';

// create upper menu
upper_menu = document.getElementById("menu_div");

var tbl      = document.createElement("table");
var tbl_body = document.createElement("tbody");
var tbl_row  = document.createElement("tr");
for (idx = 0; idx < slides.length; idx++)
{
    var tbl_cell = document.createElement("td");
    var cell_text = document.createTextNode(idx+1);
    tbl_cell.appendChild(cell_text);
    tbl_cell.onclick = change_callback(idx);
    tbl_row.appendChild(tbl_cell);
    menu.push(tbl_cell);
    tbl_cell.style.borderWidth = "0px";

    var slide = slides[idx]; //document.getElementById(slides[idx]);
    var all_tables = slide.getElementsByTagName("table");
    for (t_i = 0; t_i < all_tables.length; t_i++)
    {
      var table = all_tables[t_i];
      if (!table.classList.contains("question_style"))
        continue;
      var rows = table.getElementsByTagName('tr');
      for (r_i = 0; r_i < rows.length; r_i++)
      {
        var question_cell = rows[r_i].cells[0];
        question_cell.classList.add("highlight");
        if (question_cell.classList.contains("ok"))
        {
          question_cell.onclick = make_callback(question_cell, 1);
        } else {
          question_cell.onclick = make_callback(question_cell, 0);
        }


        var cell = rows[r_i].insertCell(0);
        cell.width = "50px";
      }
    }
}
tbl_body.appendChild(tbl_row);
tbl.appendChild(tbl_body);
upper_menu.appendChild(tbl);
tbl.classList.add('menu_style');
menu[current_slide].style.borderWidth = "2px";

</script>

<style>
    .slide_style {
      max-width:750px;
      display:none;
      font: 14pt/18pt sans-serif;
      position: static;
      top: 80px;
      left: 0px;
    }

    .question_style {
        width:600px;
        font: 16pt/14pt sans-serif bold;
        text-align:left;
        cursor: default;
    }
    .question_style td{
        padding:7px;
        height: 50px;
        border:#4e95f4 0px solid;
        text-align:left;
        font: 13pt/16pt sans-serif;
    }
    .highlight:hover{
        background-color: #00000019
    }
    .menu_style {
        height:50px;
        font: 16pt/14pt sans-serif bold;
        text-align:left;
        cursor: default;
    }
    .menu_style td{
        width:50px;
        padding:7px;
        border:#787878ff solid;
        text-align:center;
        font: 16pt/14pt sans-serif;
        color: #606060ff;
    }
</style>
# Out:
# <script src='https://www.gstatic.com/external_hosted/mathjax/latest/MathJax.js?config=default'></script>
#
# <div id="all_slides">
#
# <div>
# <list>
# <li> Constant model
# </list>
# <br>
# Expression for square error is
# $$
#    e_1(a)
#  = \int\limits_0^1 (f(x) - a)^2 dx
# $$
# The best result we can expect
# $$
# \min_{a} e_1(a) = \frac{2}{135} \approx 0.015
# $$
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!-- Created with Inkscape (http://www.inkscape.org/) -->
#
# <svg width="111.88mm" height="80.873mm" version="1.1" viewBox="0 0 111.88 80.873" xmlns="http://www.w3.org/2000/svg" xmlns:ns0="http://www.iki.fi/pav/software/textext/">
#  <defs>
#   <marker id="a" overflow="visible" orient="auto">
#    <path transform="matrix(-.4 0 0 -.4 -4 0)" d="m0 0 5-5-17.5 5 17.5 5z" fill-opacity=".2657" fill-rule="evenodd" stroke="#000" stroke-opacity=".2657" stroke-width="1pt"/>
#   </marker>
#   <marker id="b" overflow="visible" orient="auto">
# ...

# %%
#@title Best fit for linear model

# %%html
<script src='https://www.gstatic.com/external_hosted/mathjax/latest/MathJax.js?config=default'></script>

<div id="all_slides">

<div>
<list>
<li> Linear model
</list>
<br>
Expression for square error is
$$
   e_2(a, b)
 = \int\limits_0^1 (f(x) - ax - b)^2 dx
$$
The best result we can expect
$$
\min_{a,b} e_2(a,b) = \frac{1}{180} \approx 0.006
$$
<?xml version="1.0" encoding="UTF-8" standalone="no"?>
<!-- Created with Inkscape (http://www.inkscape.org/) -->

<svg width="111.88mm" height="80.873mm" version="1.1" viewBox="0 0 111.88 80.873" xmlns="http://www.w3.org/2000/svg" xmlns:ns0="http://www.iki.fi/pav/software/textext/">
 <defs>
  <marker id="a" overflow="visible" orient="auto">
   <path transform="matrix(-.4 0 0 -.4 -4 0)" d="m0 0 5-5-17.5 5 17.5 5z" fill-opacity=".90196" fill-rule="evenodd" stroke="#000" stroke-opacity=".90196" stroke-width="1pt"/>
  </marker>
  <marker id="b" overflow="visible" orient="auto">
   <path transform="matrix(-.4 0 0 -.4 -4 0)" d="m0 0 5-5-17.5 5 17.5 5z" fill-opacity=".90196" fill-rule="evenodd" stroke="#000" stroke-opacity=".90196" stroke-width="1pt"/>
  </marker>
 </defs>
 <g transform="translate(132.94 -3.3342)">
  <text x="35.246281" y="42.149555" fill="#000000" font-family="Verdana" font-size="10.583px" letter-spacing="0px" stroke-width=".26458" word-spacing="0px" style="line-height:1.25" xml:space="preserve"><tspan x="35.246281" y="51.80505" stroke-width=".26458"/></text>
  <text x="76.906807" y="21.511925" fill="#000000" font-family="Verdana" font-size="10.583px" letter-spacing="0px" stroke-width=".26458" word-spacing="0px" style="line-height:1.25" xml:space="preserve"><tspan x="76.906807" y="31.167419" stroke-width=".26458"/></text>
   \min_{a,b} \int\limits_0^1 [4/9 - (x - 2/3)^2 - ax - b]^2 dx =\\&\phantom{=
   \min_{a,b} \int\limits_0^1 [(4/3 - a)x - x^2 - b]^2 dx =}\\&\phantom{=
   \min_{a,b} \int\limits_0^1 (4/3 - a)^2 x^2 + x^4 + b^2 - 2(4/3 - a)x^3 - 2b(4/3 - a)x + 2bx^2 dx =}\\&\phantom{=
   \min_{a,b} (4/3 - a)^2 \frac{1}{3} + \frac{1}{5} + b^2 - 2(4/3 - a)\frac{1}{4} - 2b(4/3 - a) + 2b\frac{1}{3} =}\\&\phantom{=
   \min_{a,b} \frac{17}{135} - \frac{7a}{18} + \frac{a^2}{3} - \frac{2b}{3} + ab + b^2}
\end{aligned}
$$
</div>

<div>
<b>Proof:</b><br>
Expand square in round brackets and simplify
$$
\begin{aligned}
\min_{a,b} e_2(a,b) &=
   \min_{a,b} \int\limits_0^1 [4/9 - (x - 2/3)^2 - ax - b]^2 dx =\\&=
   \min_{a,b} \int\limits_0^1 [(4/3 - a)x - x^2 - b]^2 dx =\\&\phantom{=
   \min_{a,b} \int\limits_0^1 (4/3 - a)^2 x^2 + x^4 + b^2 - 2(4/3 - a)x^3 - 2b(4/3 - a)x + 2bx^2 dx =}\\&\phantom{=
   \min_{a,b} (4/3 - a)^2 \frac{1}{3} + \frac{1}{5} + b^2 - 2(4/3 - a)\frac{1}{4} - 2b(4/3 - a) + 2b\frac{1}{3} =}\\&\phantom{=
   \min_{a,b} \frac{17}{135} - \frac{7a}{18} + \frac{a^2}{3} - \frac{2b}{3} + ab + b^2}
\end{aligned}
$$
</div>

<div>
<b>Proof:</b><br>
Expand square in square brackets
$$
\begin{aligned}
\min_{a,b} e_2(a,b) &=
   \min_{a,b} \int\limits_0^1 [4/9 - (x - 2/3)^2 - ax - b]^2 dx =\\&=
   \min_{a,b} \int\limits_0^1 [(4/3 - a)x - x^2 - b]^2 dx =\\&=
   \min_{a,b} \int\limits_0^1 (4/3 - a)^2 x^2 + x^4 + b^2 - 2(4/3 - a)x^3 - 2b(4/3 - a)x + 2bx^2 dx =\\&\phantom{=
   \min_{a,b} (4/3 - a)^2 \frac{1}{3} + \frac{1}{5} + b^2 - 2(4/3 - a)\frac{1}{4} - 2b(4/3 - a) + 2b\frac{1}{3} =}\\&\phantom{=
   \min_{a,b} \frac{17}{135} - \frac{7a}{18} + \frac{a^2}{3} - \frac{2b}{3} + ab + b^2}
\end{aligned}
$$
</div>

<div>
<b>Proof:</b><br>
Integrate
$$
\begin{aligned}
\min_{a,b} e_2(a,b) &=
   \min_{a,b} \int\limits_0^1 [4/9 - (x - 2/3)^2 - ax - b]^2 dx =\\&=
   \min_{a,b} \int\limits_0^1 [(4/3 - a)x - x^2 - b]^2 dx =\\&=
   \min_{a,b} \int\limits_0^1 (4/3 - a)^2 x^2 + x^4 + b^2 - 2(4/3 - a)x^3 - 2b(4/3 - a)x + 2bx^2 dx =\\&=
   \min_{a,b} (4/3 - a)^2 \frac{1}{3} + \frac{1}{5} + b^2 - 2(4/3 - a)\frac{1}{4} - 2b(4/3 - a) + 2b\frac{1}{3} =\\&\phantom{=
   \min_{a,b} \frac{17}{135} - \frac{7a}{18} + \frac{a^2}{3} - \frac{2b}{3} + ab + b^2}
\end{aligned}
$$
</div>

<div>
<b>Proof:</b><br>
Simplify
$$
\begin{aligned}
\min_{a,b} e_2(a,b) &=
   \min_{a,b} \int\limits_0^1 [4/9 - (x - 2/3)^2 - ax - b]^2 dx =\\&=
   \min_{a,b} \int\limits_0^1 [(4/3 - a)x - x^2 - b]^2 dx =\\&=
   \min_{a,b} \int\limits_0^1 (4/3 - a)^2 x^2 + x^4 + b^2 - 2(4/3 - a)x^3 - 2b(4/3 - a)x + 2bx^2 dx =\\&=
   \min_{a,b} (4/3 - a)^2 \frac{1}{3} + \frac{1}{5} + b^2 - 2(4/3 - a)\frac{1}{4} - 2b(4/3 - a) + 2b\frac{1}{3} =\\&=
   \min_{a,b} \frac{17}{135} - \frac{7a}{18} + \frac{a^2}{3} - \frac{2b}{3} + ab + b^2
\end{aligned}
$$
</div>

<div>
<b>Proof:</b><br>
Minimize over \(a\) and \(b\) by means of calculus
$$
   \min_{a,b} e_2(a,b)
 = \frac{17}{135} + \min_{a,b} \left(\frac{a^2}{3} - \frac{7a}{18} - \frac{2b}{3} + ab + b^2\right)
$$
minimum is obtained when \(a = \hat{a}\) and \(b= \hat{b}\)
$$
\left\{
\begin{aligned}
0 &= \left.\frac{\partial}{\partial a}
         \left(
               \frac{a^2}{3} - \frac{7a}{18} - \frac{2b}{3} + ab + b^2
         \right)
     \right|_{a=\hat{a},~b=\hat{b}}\\
0 &= \left.\frac{\partial}{\partial b}
         \left(
               \frac{a^2}{3} - \frac{7a}{18} - \frac{2b}{3} + ab + b^2
         \right)
     \right|_{a=\hat{a},~b=\hat{b}}
\end{aligned}
\right.
$$
</div>

<div>
<b>Proof:</b><br>
Minimize over \(a\) and \(b\) by means of calculus
$$
   \min_{a,b} e_2(a,b)
 = \frac{17}{135} + \min_{a,b} \left(\frac{a^2}{3} - \frac{7a}{18} - \frac{2b}{3} + ab + b^2\right)
$$
minimum is obtained when \(a = \hat{a}\) and \(b= \hat{b}\)
$$
\left\{
\begin{aligned}
0 &= \frac{2\hat{a}}{3} - \frac{7}{18} + \hat{b}\\
0 &= - \frac{2}{3} + \hat{a} + 2\hat{b}
\end{aligned}
\right.
$$
</div>

<div>
<b>Proof:</b><br>
Minimize over \(a\) and \(b\) by means of calculus
$$
   \min_{a,b} e_2(a,b)
 = \frac{17}{135} + \min_{a,b} \left(\frac{a^2}{3} - \frac{7a}{18} - \frac{2b}{3} + ab + b^2\right)
$$
minimum is obtained when \(a = \hat{a}\) and \(b= \hat{b}\)
$$
\left\{
\begin{aligned}
\hat{a} &= \frac{1}{3}\\
\hat{b} &= \frac{1}{6}
\end{aligned}
\right.
$$
</div>

<div>
<b>Proof:</b><br>
Minimize over \(a\) and \(b\) by means of calculus
$$
   \min_{a,b} e_2(a,b) = \frac{1}{180}
$$
QED
</div>


</div>

<div style="position:absolute; top:30px; left:900px;">

<div id="arrow_left" style="border-width: 1px; border-style:solid; float:left; height:32px;">
<svg width="8.7464mm" height="8.7464mm" version="1.1" viewBox="0 0 8.7464 8.7464" xmlns="http://www.w3.org/2000/svg" xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
<metadata>
<rdf:RDF>
<cc:Work rdf:about="">
<dc:format>image/svg+xml</dc:format>
<dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
<dc:title/>
</cc:Work>
</rdf:RDF>
</metadata>
<g transform="translate(-38.564 -29.908)">
<rect x="38.564" y="29.908" width="8.7464" height="8.7464" fill-opacity=".16425" opacity=".97" stroke-miterlimit="10.433" stroke-width="0"/>
<path d="m45.796 34.331h-5.8931" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m40.068 34.267 2.7141-2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m40.069 34.396 2.7141 2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
</g>
</svg>
</div>

<div id="arrow_right" style="border-width: 1px; border-style:solid; float:right; height:32px;">
<svg width="8.7464mm" height="8.7464mm" version="1.1" viewBox="0 0 8.7464 8.7464" xmlns="http://www.w3.org/2000/svg" xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
<metadata>
<rdf:RDF>
<cc:Work rdf:about="">
<dc:format>image/svg+xml</dc:format>
<dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
<dc:title/>
</cc:Work>
</rdf:RDF>
</metadata>
<g transform="translate(-38.564 -29.908)">
<rect transform="scale(-1,1)" x="-47.31" y="29.908" width="8.7464" height="8.7464" fill-opacity=".16425" opacity=".97" stroke-miterlimit="10.433" stroke-width="0"/>
<path d="m40.078 34.331h5.8931" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m45.806 34.267-2.7141-2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m45.805 34.396-2.7141 2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
</g>
</svg>
</div>

</div>

<style>
#arrow_left:hover{color:blue;}
#arrow_right:hover{color:blue;}
</style>

<script  type="text/javascript">
//var slides = ["slide_1", "slide_2", "slide_3"];

var container = document.getElementById("all_slides");
var menu_conn = document.createElement("div");
menu_conn.style.height = "90px";
menu_conn.id = "menu_div";
container.prepend(menu_conn);

// crutches
var slides = [];
var tmp = container.getElementsByTagName("div");
for (var i = 0; i < tmp.length; ++i)
  if (!tmp[i].id || tmp[i].id != "menu_div")
  {
    tmp[i].classList.add('slide_style');
    slides.push(tmp[i]);
  }


var left_btn_id = "arrow_left";
var right_btn_id = "arrow_right";
var current_slide = 0;
var menu = [];

function change_slide_to(new_slide_idx)
{
  menu[current_slide].style.borderWidth = "0px";
  var old_slide = slides[current_slide]; //document.getElementById(slides[current_slide]);
  current_slide = new_slide_idx;
  menu[current_slide].style.borderWidth = "2px";
  var new_slide = slides[current_slide]; //document.getElementById(slides[current_slide]);
  old_slide.style.display='none';
  new_slide.style.display='block';
}

function slide_left()
{
  var new_idx = current_slide - 1;
  if (new_idx < 0) {new_idx = 0;}
  change_slide_to(new_idx);
}

function slide_right()
{
  var new_idx = current_slide + 1;
  if (new_idx >= slides.length) {new_idx = slides.length - 1;}
  change_slide_to(new_idx);
}

function change(obj, is_correct)
{
//   alert(obj.parentNode.rowIndex);
    var rowId = obj.parentNode.rowIndex;
    var table = obj.parentNode.parentNode.parentNode;
    var rowsNotSelected = table.getElementsByTagName('tr');
    for (var row = 0; row < rowsNotSelected.length; row++)
    {
        rowsNotSelected[row].cells[0].style.backgroundColor = "white";
    }
    var rowSelected = table.getElementsByTagName('tr')[rowId];
    if (is_correct > 0)
    {
        rowSelected.cells[0].style.backgroundColor = "#66bb6aa9";
        menu[current_slide].style.backgroundColor = "#66bb6aa9";
    }
    else
    {
        rowSelected.cells[0].style.backgroundColor = "#ff3a3981";
        menu[current_slide].style.backgroundColor = "#ff3a3981";
    }
}

function make_callback(obj, is_correct)
{
  return function() { change(obj, is_correct); }
}

function change_callback(new_idx)
{
  return function() { change_slide_to(new_idx); }
}

document.getElementById(left_btn_id).addEventListener("click", slide_left);
document.getElementById(right_btn_id).addEventListener("click", slide_right);
slides[current_slide].style.display='block'; //document.getElementById(slides[current_slide]).style.display='block';

// create upper menu
upper_menu = document.getElementById("menu_div");

var tbl      = document.createElement("table");
var tbl_body = document.createElement("tbody");
var tbl_row  = document.createElement("tr");
for (idx = 0; idx < slides.length; idx++)
{
    var tbl_cell = document.createElement("td");
    var cell_text = document.createTextNode(idx+1);
    tbl_cell.appendChild(cell_text);
    tbl_cell.onclick = change_callback(idx);
    tbl_row.appendChild(tbl_cell);
    menu.push(tbl_cell);
    tbl_cell.style.borderWidth = "0px";

    var slide = slides[idx]; //document.getElementById(slides[idx]);
    var all_tables = slide.getElementsByTagName("table");
    for (t_i = 0; t_i < all_tables.length; t_i++)
    {
      var table = all_tables[t_i];
      if (!table.classList.contains("question_style"))
        continue;
      var rows = table.getElementsByTagName('tr');
      for (r_i = 0; r_i < rows.length; r_i++)
      {
        var question_cell = rows[r_i].cells[0];
        question_cell.classList.add("highlight");
        if (question_cell.classList.contains("ok"))
        {
          question_cell.onclick = make_callback(question_cell, 1);
        } else {
          question_cell.onclick = make_callback(question_cell, 0);
        }


        var cell = rows[r_i].insertCell(0);
        cell.width = "50px";
      }
    }
}
tbl_body.appendChild(tbl_row);
tbl.appendChild(tbl_body);
upper_menu.appendChild(tbl);
tbl.classList.add('menu_style');
menu[current_slide].style.borderWidth = "2px";

</script>

<style>
    .slide_style {
      max-width:750px;
      display:none;
      font: 14pt/18pt sans-serif;
      position: static;
      top: 80px;
      left: 0px;
    }

    .question_style {
        width:600px;
        font: 16pt/14pt sans-serif bold;
        text-align:left;
        cursor: default;
    }
    .question_style td{
        padding:7px;
        height: 50px;
        border:#4e95f4 0px solid;
        text-align:left;
        font: 13pt/16pt sans-serif;
    }
    .highlight:hover{
        background-color: #00000019
    }
    .menu_style {
        height:50px;
        font: 16pt/14pt sans-serif bold;
        text-align:left;
        cursor: default;
    }
    .menu_style td{
        width:50px;
        padding:7px;
        border:#787878ff solid;
        text-align:center;
        font: 16pt/14pt sans-serif;
        color: #606060ff;
    }
</style>
# Out:
# <script src='https://www.gstatic.com/external_hosted/mathjax/latest/MathJax.js?config=default'></script>
#
# <div id="all_slides">
#
# <div>
# <list>
# <li> Linear model
# </list>
# <br>
# Expression for square error is
# $$
#    e_2(a, b)
#  = \int\limits_0^1 (f(x) - ax - b)^2 dx
# $$
# The best result we can expect
# $$
# \min_{a,b} e_2(a,b) = \frac{1}{180} \approx 0.006
# $$
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!-- Created with Inkscape (http://www.inkscape.org/) -->
#
# <svg width="111.88mm" height="80.873mm" version="1.1" viewBox="0 0 111.88 80.873" xmlns="http://www.w3.org/2000/svg" xmlns:ns0="http://www.iki.fi/pav/software/textext/">
#  <defs>
#   <marker id="a" overflow="visible" orient="auto">
#    <path transform="matrix(-.4 0 0 -.4 -4 0)" d="m0 0 5-5-17.5 5 17.5 5z" fill-opacity=".90196" fill-rule="evenodd" stroke="#000" stroke-opacity=".90196" stroke-width="1pt"/>
#   </marker>
#   <marker id="b" overflow="visible" orient="auto">
# ...

# %% [markdown]
# **Conclusions**
#
# Seems like $H_2$ wins, but this proof is bad as well (lol).

# %% [markdown]
# **Why this result is wrong?**
#
# * We calculated not the scenario we have in practice

# %% [markdown]
# **What is the real scenario?**
#
# * We obtain training set -- two datapoints $(x_1;y_1)$ and $(x_2;y_2)$
# * We train two models -- one from $H_1$ and one from $H_2$
# * We test performance of our models on validation set

# %%
#@title Mean squared error for constant model

# %%html
<script src='https://www.gstatic.com/external_hosted/mathjax/latest/MathJax.js?config=default'></script>

<div id="all_slides">

<div>
<list>
<li> Constant model
</list>
<br>
Given the dataset, i.e. \((x_1;f(x_1))\) and \((x_2;f(x_2))\) we do the best possible fit.
Using previous results, it is easy to see that trained model looks like
$$
  g_1(x|x_1;x_2) = \frac{f(x_1) + f(x_2)}{2}
                 = (2/3 - x_1/2)x_1 + (2/3 - x_2/2)x_2.
$$
The squared error of the model trained on \((x_1;f(x_1))\) and \((x_2;f(x_2))\) reads
$$
e_1(x_1;x_2) = \int\limits_0^1
                   (f(x) - g_1(x|x_1;x_2))^2
               dx.
$$
Since all datasets are equally possible, we expect (on average) the error to be
$$
e_1 =
\mathbb{E}_{x_1;x_2} [e_1(x_1;x_2)] =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
    (f(x) - g_1(x|x_1;x_2))^2
dx\, dx_1 dx_2 =
\frac{1}{45} \approx 0.02
$$
</div>

<div>
<b>Proof:</b><br>
Write by definition
$$
\begin{aligned}
e_1 &=
\mathbb{E}_{x_1;x_2} [e_1(x_1;x_2)] =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
    (f(x) - g_1(x|x_1;x_2))^2
dx\, dx_1 dx_2 = \\ & \phantom{=
\int\limits_0^1\int\limits_0^1\int\limits_0^1
    \left(4/9 - (x-2/3)^2 - 2x_1/3 + x_1^2/2 - 2x_2/3 + x_2^2/2 \right)^2
dx\, dx_1 dx_2 =} \\ & \phantom{=
\frac{1}{4}
\int\limits_0^1\int\limits_0^1\int\limits_0^1
\left[(x_1-2/3)^2 + (x_2-2/3)^2 - 2(x-2/3)^2\right]^2
dx\, dx_1 dx_2 =} \\ & \phantom{=
\frac{1}{4}
\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}
\left(x_1^2 + x_2^2 - 2x^2\right)^2
dx\, dx_1 dx_2 =} \\ & \phantom{=
\frac{1}{4}
\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}
x_1^4 + x_2^4 + 4x^4 + 2 x_1^2 x_2^2 - 4 x_1^2 x^2 - 4 x_2^2 x^2
dx\, dx_1 dx_2 =} \\ & \phantom{=
\frac{1}{45}}
\end{aligned}
$$
</div>

<div>
<b>Proof:</b><br>
Write by definition
$$
\begin{aligned}
e_1 &=
\mathbb{E}_{x_1;x_2} [e_1(x_1;x_2)] =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
    (f(x) - g_1(x|x_1;x_2))^2
dx\, dx_1 dx_2 = \\ & =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
    \left(4/9 - (x-2/3)^2 - 2x_1/3 + x_1^2/2 - 2x_2/3 + x_2^2/2 \right)^2
dx\, dx_1 dx_2 = \\ & \phantom{=
\frac{1}{4}
\int\limits_0^1\int\limits_0^1\int\limits_0^1
\left[(x_1-2/3)^2 + (x_2-2/3)^2 - 2(x-2/3)^2\right]^2
dx\, dx_1 dx_2 =} \\ & \phantom{=
\frac{1}{4}
\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}
\left(x_1^2 + x_2^2 - 2x^2\right)^2
dx\, dx_1 dx_2 =} \\ & \phantom{=
\frac{1}{4}
\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}
x_1^4 + x_2^4 + 4x^4 + 2 x_1^2 x_2^2 - 4 x_1^2 x^2 - 4 x_2^2 x^2
dx\, dx_1 dx_2 =} \\ & \phantom{=
\frac{1}{45}}
\end{aligned}
$$
</div>

<div>
<b>Proof:</b><br>
Collect squares
$$
\begin{aligned}
e_1 &=
\mathbb{E}_{x_1;x_2} [e_1(x_1;x_2)] =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
    (f(x) - g_1(x|x_1;x_2))^2
dx\, dx_1 dx_2 = \\ & =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
    \left(4/9 - (x-2/3)^2 - 2x_1/3 + x_1^2/2 - 2x_2/3 + x_2^2/2 \right)^2
dx\, dx_1 dx_2 = \\ & =
\frac{1}{4}
\int\limits_0^1\int\limits_0^1\int\limits_0^1
\left[(x_1-2/3)^2 + (x_2-2/3)^2 - 2(x-2/3)^2\right]^2
dx\, dx_1 dx_2 = \\ & \phantom{=
\frac{1}{4}
\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}
\left(x_1^2 + x_2^2 - 2x^2\right)^2
dx\, dx_1 dx_2 =} \\ & \phantom{=
\frac{1}{4}
\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}
x_1^4 + x_2^4 + 4x^4 + 2 x_1^2 x_2^2 - 4 x_1^2 x^2 - 4 x_2^2 x^2
dx\, dx_1 dx_2 =} \\ & \phantom{=
\frac{1}{45}}
\end{aligned}
$$
</div>

<div>
<b>Proof:</b><br>
Change limits
$$
\begin{aligned}
e_1 &=
\mathbb{E}_{x_1;x_2} [e_1(x_1;x_2)] =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
    (f(x) - g_1(x|x_1;x_2))^2
dx\, dx_1 dx_2 = \\ & =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
    \left(4/9 - (x-2/3)^2 - 2x_1/3 + x_1^2/2 - 2x_2/3 + x_2^2/2 \right)^2
dx\, dx_1 dx_2 = \\ & =
\frac{1}{4}
\int\limits_0^1\int\limits_0^1\int\limits_0^1
\left[(x_1-2/3)^2 + (x_2-2/3)^2 - 2(x-2/3)^2\right]^2
dx\, dx_1 dx_2 = \\ & =
\frac{1}{4}
\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}
\left(x_1^2 + x_2^2 - 2x^2\right)^2
dx\, dx_1 dx_2 = \\ & \phantom{=
\frac{1}{4}
\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}
x_1^4 + x_2^4 + 4x^4 + 2 x_1^2 x_2^2 - 4 x_1^2 x^2 - 4 x_2^2 x^2
dx\, dx_1 dx_2 =} \\ & \phantom{=
\frac{1}{45}}
\end{aligned}
$$
</div>

<div>
<b>Proof:</b><br>
Expand square
$$
\begin{aligned}
e_1 &=
\mathbb{E}_{x_1;x_2} [e_1(x_1;x_2)] =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
    (f(x) - g_1(x|x_1;x_2))^2
dx\, dx_1 dx_2 = \\ & =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
    \left(4/9 - (x-2/3)^2 - 2x_1/3 + x_1^2/2 - 2x_2/3 + x_2^2/2 \right)^2
dx\, dx_1 dx_2 = \\ & =
\frac{1}{4}
\int\limits_0^1\int\limits_0^1\int\limits_0^1
\left[(x_1-2/3)^2 + (x_2-2/3)^2 - 2(x-2/3)^2\right]^2
dx\, dx_1 dx_2 = \\ & =
\frac{1}{4}
\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}
\left(x_1^2 + x_2^2 - 2x^2\right)^2
dx\, dx_1 dx_2 = \\ & =
\frac{1}{4}
\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}
x_1^4 + x_2^4 + 4x^4 + 2 x_1^2 x_2^2 - 4 x_1^2 x^2 - 4 x_2^2 x^2
dx\, dx_1 dx_2 = \\ & \phantom{=
\frac{1}{45}}
\end{aligned}
$$
</div>

<div>
<b>Proof:</b><br>
Integrate polynomials (that's easy)
$$
\begin{aligned}
e_1 &=
\mathbb{E}_{x_1;x_2} [e_1(x_1;x_2)] =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
    (f(x) - g_1(x|x_1;x_2))^2
dx\, dx_1 dx_2 = \\ & =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
    \left(4/9 - (x-2/3)^2 - 2x_1/3 + x_1^2/2 - 2x_2/3 + x_2^2/2 \right)^2
dx\, dx_1 dx_2 = \\ & =
\frac{1}{4}
\int\limits_0^1\int\limits_0^1\int\limits_0^1
\left[(x_1-2/3)^2 + (x_2-2/3)^2 - 2(x-2/3)^2\right]^2
dx\, dx_1 dx_2 = \\ & =
\frac{1}{4}
\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}
\left(x_1^2 + x_2^2 - 2x^2\right)^2
dx\, dx_1 dx_2 = \\ & =
\frac{1}{4}
\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}
x_1^4 + x_2^4 + 4x^4 + 2 x_1^2 x_2^2 - 4 x_1^2 x^2 - 4 x_2^2 x^2
dx\, dx_1 dx_2 = \\ & =
\frac{1}{45}
\end{aligned}
$$
</div>

</div>

<div style="position:absolute; top:30px; left:900px;">

<div id="arrow_left" style="border-width: 1px; border-style:solid; float:left; height:32px;">
<svg width="8.7464mm" height="8.7464mm" version="1.1" viewBox="0 0 8.7464 8.7464" xmlns="http://www.w3.org/2000/svg" xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
<metadata>
<rdf:RDF>
<cc:Work rdf:about="">
<dc:format>image/svg+xml</dc:format>
<dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
<dc:title/>
</cc:Work>
</rdf:RDF>
</metadata>
<g transform="translate(-38.564 -29.908)">
<rect x="38.564" y="29.908" width="8.7464" height="8.7464" fill-opacity=".16425" opacity=".97" stroke-miterlimit="10.433" stroke-width="0"/>
<path d="m45.796 34.331h-5.8931" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m40.068 34.267 2.7141-2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m40.069 34.396 2.7141 2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
</g>
</svg>
</div>

<div id="arrow_right" style="border-width: 1px; border-style:solid; float:right; height:32px;">
<svg width="8.7464mm" height="8.7464mm" version="1.1" viewBox="0 0 8.7464 8.7464" xmlns="http://www.w3.org/2000/svg" xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
<metadata>
<rdf:RDF>
<cc:Work rdf:about="">
<dc:format>image/svg+xml</dc:format>
<dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
<dc:title/>
</cc:Work>
</rdf:RDF>
</metadata>
<g transform="translate(-38.564 -29.908)">
<rect transform="scale(-1,1)" x="-47.31" y="29.908" width="8.7464" height="8.7464" fill-opacity=".16425" opacity=".97" stroke-miterlimit="10.433" stroke-width="0"/>
<path d="m40.078 34.331h5.8931" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m45.806 34.267-2.7141-2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m45.805 34.396-2.7141 2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
</g>
</svg>
</div>

</div>

<style>
#arrow_left:hover{color:blue;}
#arrow_right:hover{color:blue;}
</style>

<script  type="text/javascript">
//var slides = ["slide_1", "slide_2", "slide_3"];

var container = document.getElementById("all_slides");
var menu_conn = document.createElement("div");
menu_conn.style.height = "90px";
menu_conn.id = "menu_div";
container.prepend(menu_conn);

// crutches
var slides = [];
var tmp = container.getElementsByTagName("div");
for (var i = 0; i < tmp.length; ++i)
  if (!tmp[i].id || tmp[i].id != "menu_div")
  {
    tmp[i].classList.add('slide_style');
    slides.push(tmp[i]);
  }


var left_btn_id = "arrow_left";
var right_btn_id = "arrow_right";
var current_slide = 0;
var menu = [];

function change_slide_to(new_slide_idx)
{
  menu[current_slide].style.borderWidth = "0px";
  var old_slide = slides[current_slide]; //document.getElementById(slides[current_slide]);
  current_slide = new_slide_idx;
  menu[current_slide].style.borderWidth = "2px";
  var new_slide = slides[current_slide]; //document.getElementById(slides[current_slide]);
  old_slide.style.display='none';
  new_slide.style.display='block';
}

function slide_left()
{
  var new_idx = current_slide - 1;
  if (new_idx < 0) {new_idx = 0;}
  change_slide_to(new_idx);
}

function slide_right()
{
  var new_idx = current_slide + 1;
  if (new_idx >= slides.length) {new_idx = slides.length - 1;}
  change_slide_to(new_idx);
}

function change(obj, is_correct)
{
//   alert(obj.parentNode.rowIndex);
    var rowId = obj.parentNode.rowIndex;
    var table = obj.parentNode.parentNode.parentNode;
    var rowsNotSelected = table.getElementsByTagName('tr');
    for (var row = 0; row < rowsNotSelected.length; row++)
    {
        rowsNotSelected[row].cells[0].style.backgroundColor = "white";
    }
    var rowSelected = table.getElementsByTagName('tr')[rowId];
    if (is_correct > 0)
    {
        rowSelected.cells[0].style.backgroundColor = "#66bb6aa9";
        menu[current_slide].style.backgroundColor = "#66bb6aa9";
    }
    else
    {
        rowSelected.cells[0].style.backgroundColor = "#ff3a3981";
        menu[current_slide].style.backgroundColor = "#ff3a3981";
    }
}

function make_callback(obj, is_correct)
{
  return function() { change(obj, is_correct); }
}

function change_callback(new_idx)
{
  return function() { change_slide_to(new_idx); }
}

document.getElementById(left_btn_id).addEventListener("click", slide_left);
document.getElementById(right_btn_id).addEventListener("click", slide_right);
slides[current_slide].style.display='block'; //document.getElementById(slides[current_slide]).style.display='block';

// create upper menu
upper_menu = document.getElementById("menu_div");

var tbl      = document.createElement("table");
var tbl_body = document.createElement("tbody");
var tbl_row  = document.createElement("tr");
for (idx = 0; idx < slides.length; idx++)
{
    var tbl_cell = document.createElement("td");
    var cell_text = document.createTextNode(idx+1);
    tbl_cell.appendChild(cell_text);
    tbl_cell.onclick = change_callback(idx);
    tbl_row.appendChild(tbl_cell);
    menu.push(tbl_cell);
    tbl_cell.style.borderWidth = "0px";

    var slide = slides[idx]; //document.getElementById(slides[idx]);
    var all_tables = slide.getElementsByTagName("table");
    for (t_i = 0; t_i < all_tables.length; t_i++)
    {
      var table = all_tables[t_i];
      if (!table.classList.contains("question_style"))
        continue;
      var rows = table.getElementsByTagName('tr');
      for (r_i = 0; r_i < rows.length; r_i++)
      {
        var question_cell = rows[r_i].cells[0];
        question_cell.classList.add("highlight");
        if (question_cell.classList.contains("ok"))
        {
          question_cell.onclick = make_callback(question_cell, 1);
        } else {
          question_cell.onclick = make_callback(question_cell, 0);
        }


        var cell = rows[r_i].insertCell(0);
        cell.width = "50px";
      }
    }
}
tbl_body.appendChild(tbl_row);
tbl.appendChild(tbl_body);
upper_menu.appendChild(tbl);
tbl.classList.add('menu_style');
menu[current_slide].style.borderWidth = "2px";

</script>

<style>
    .slide_style {
      max-width:750px;
      display:none;
      font: 14pt/18pt sans-serif;
      position: static;
      top: 80px;
      left: 0px;
    }

    .question_style {
        width:600px;
        font: 16pt/14pt sans-serif bold;
        text-align:left;
        cursor: default;
    }
    .question_style td{
        padding:7px;
        height: 50px;
        border:#4e95f4 0px solid;
        text-align:left;
        font: 13pt/16pt sans-serif;
    }
    .highlight:hover{
        background-color: #00000019
    }
    .menu_style {
        height:50px;
        font: 16pt/14pt sans-serif bold;
        text-align:left;
        cursor: default;
    }
    .menu_style td{
        width:50px;
        padding:7px;
        border:#787878ff solid;
        text-align:center;
        font: 16pt/14pt sans-serif;
        color: #606060ff;
    }
</style>
# Out:
# <script src='https://www.gstatic.com/external_hosted/mathjax/latest/MathJax.js?config=default'></script>
#
# <div id="all_slides">
#
# <div>
# <list>
# <li> Constant model
# </list>
# <br>
# Given the dataset, i.e. \((x_1;f(x_1))\) and \((x_2;f(x_2))\) we do the best possible fit.
# Using previous results, it is easy to see that trained model looks like
# $$
#   g_1(x|x_1;x_2) = \frac{f(x_1) + f(x_2)}{2}
#                  = (2/3 - x_1/2)x_1 + (2/3 - x_2/2)x_2.
# $$
# The squared error of the model trained on \((x_1;f(x_1))\) and \((x_2;f(x_2))\) reads
# $$
# e_1(x_1;x_2) = \int\limits_0^1
#                    (f(x) - g_1(x|x_1;x_2))^2
#                dx.
# $$
# Since all datasets are equally possible, we expect (on average) the error to be
# $$
# e_1 =
# \mathbb{E}_{x_1;x_2} [e_1(x_1;x_2)] =
# \int\limits_0^1\int\limits_0^1\int\limits_0^1
#     (f(x) - g_1(x|x_1;x_2))^2
# dx\, dx_1 dx_2 =
# \frac{1}{45} \approx 0.02
# $$
# </div>
#
# <div>
# <b>Proof:</b><br>
# Write by definition
# ...

# %%
#@title Mean squared error for linear model

# %%html
<script src='https://www.gstatic.com/external_hosted/mathjax/latest/MathJax.js?config=default'></script>

<div id="all_slides">

<div>
<list>
<li> Linear model
</list>
<br>
Given the dataset, i.e. \((x_1;f(x_1))\) and \((x_2;f(x_2))\) we do the best possible fit.
Using previous results, it is easy to see that trained model looks like
$$
    g_2(x|x_1;x_2) = f(x_2)
                   + \frac{x - x_2}{x_1 - x_2}
                     (f(x_1) - f(x_2))
$$
The squared error of the model trained on \((x_1;f(x_1))\) and \((x_2;f(x_2))\) reads
$$
e_2(x_1;x_2) = \int\limits_0^1
                   (f(x) - g_2(x|x_1;x_2))^2
               dx.
$$
Since all datasets are equally possible, we expect (on average) the error to be
$$
e_2 =
\mathbb{E}_{x_1;x_2} [e_2(x_1;x_2)] =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
    (f(x) - g_2(x|x_1;x_2))^2
dx\, dx_1 dx_2 =
\frac{1}{30} \approx 0.03
$$
</div>

<div>
<b>Proof:</b><br>
First we find distance along \(Y\) axis between straigth line and parabola \(a - (x-b)^2\).
Line and parabola intersect at points \(x_1; a - (x_1-b)^2\) and \(x_2; a - (x_2-b)^2\)
$$
\begin{aligned}
d(x|x_1;x_2) &=
    \underbrace{\color{blue}{a} - (x-b)^2}_{\text{parabola}} -
    \underbrace{\left[
        \color{blue}{a}
      - (x_2-b)^2 + \frac{x - x_2}{x_1 - x_2}
                    (\color{blue}{a} - (x_1-b)^2 - \color{blue}{a} + (x_2-b)^2)
    \right]}_{\text{line}}
 = \\ & \phantom{=
          (x_2-b)^2 - (x-b)^2
        - \frac{x - x_2}{x_1 - x_2} ((x_2-b)^2 - (x_1-b)^2)
 =} \\ & \phantom{=
    (x_2-\color{blue}{b}-x+\color{blue}{b})(x_2-b+x-b)
                 - \frac{x - x_2}{x_1 - x_2}
                   ((x_2-\color{blue}{b}-x_1+\color{blue}{b})(x_2-b+x_1-b))
 =} \\ & \phantom{=
    (x_2-x)(x_2+x-2b)
                 - \frac{x - x_2}{\color{blue}{x_1 - x_2}} ((\color{blue}{x_1 - x_2})(x_2+x_1-2b))
 =} \\ & \phantom{=
    (x_2-x)[(\color{blue}{x_2}+x-\color{blue}{2b}) - (\color{blue}{x_2}+x_1-\color{blue}{2b})]
 =} \\ & \phantom{=
    (x_2-x)(x-x_1)}
\end{aligned}
$$
</div>

<div>
<b>Proof:</b><br>
First we find distance along \(Y\) axis between straigth line and parabola \(a - (x-b)^2\).
Line and parabola intersect at points \(x_1; a - (x_1-b)^2\) and \(x_2; a - (x_2-b)^2\)
$$
\begin{aligned}
d(x|x_1;x_2) &=
    \underbrace{\color{blue}{a} - (x-b)^2}_{\text{parabola}} -
    \underbrace{\left[
        \color{blue}{a}
      - (x_2-b)^2 + \frac{x - x_2}{x_1 - x_2}
                    (\color{blue}{a} - (x_1-b)^2 - \color{blue}{a} + (x_2-b)^2)
    \right]}_{\text{line}}
 = \\ & =
          (x_2-b)^2 - (x-b)^2
        - \frac{x - x_2}{x_1 - x_2} ((x_2-b)^2 - (x_1-b)^2)
 = \\ & \phantom{=
    (x_2-\color{blue}{b}-x+\color{blue}{b})(x_2-b+x-b)
                 - \frac{x - x_2}{x_1 - x_2}
                   ((x_2-\color{blue}{b}-x_1+\color{blue}{b})(x_2-b+x_1-b))
 =} \\ & \phantom{=
    (x_2-x)(x_2+x-2b)
                 - \frac{x - x_2}{\color{blue}{x_1 - x_2}} ((\color{blue}{x_1 - x_2})(x_2+x_1-2b))
 =} \\ & \phantom{=
    (x_2-x)[(\color{blue}{x_2}+x-\color{blue}{2b}) - (\color{blue}{x_2}+x_1-\color{blue}{2b})]
 =} \\ & \phantom{=
    (x_2-x)(x-x_1)}
\end{aligned}
$$
</div>

<div>
<b>Proof:</b><br>
First we find distance along \(Y\) axis between straigth line and parabola \(a - (x-b)^2\).
Line and parabola intersect at points \(x_1; a - (x_1-b)^2\) and \(x_2; a - (x_2-b)^2\)
$$
\begin{aligned}
d(x|x_1;x_2) &=
    \underbrace{\color{blue}{a} - (x-b)^2}_{\text{parabola}} -
    \underbrace{\left[
        \color{blue}{a}
      - (x_2-b)^2 + \frac{x - x_2}{x_1 - x_2}
                    (\color{blue}{a} - (x_1-b)^2 - \color{blue}{a} + (x_2-b)^2)
    \right]}_{\text{line}}
 = \\ & =
          (x_2-b)^2 - (x-b)^2
        - \frac{x - x_2}{x_1 - x_2} ((x_2-b)^2 - (x_1-b)^2)
 = \\ & =
    (x_2-\color{blue}{b}-x+\color{blue}{b})(x_2-b+x-b)
                 - \frac{x - x_2}{x_1 - x_2}
                   ((x_2-\color{blue}{b}-x_1+\color{blue}{b})(x_2-b+x_1-b))
 = \\ & \phantom{=
    (x_2-x)(x_2+x-2b)
                 - \frac{x - x_2}{\color{blue}{x_1 - x_2}} ((\color{blue}{x_1 - x_2})(x_2+x_1-2b))
 =} \\ & \phantom{=
    (x_2-x)[(\color{blue}{x_2}+x-\color{blue}{2b}) - (\color{blue}{x_2}+x_1-\color{blue}{2b})]
 =} \\ & \phantom{=
    (x_2-x)(x-x_1)}
\end{aligned}
$$
</div>

<div>
<b>Proof:</b><br>
First we find distance along \(Y\) axis between straigth line and parabola \(a - (x-b)^2\).
Line and parabola intersect at points \(x_1; a - (x_1-b)^2\) and \(x_2; a - (x_2-b)^2\)
$$
\begin{aligned}
d(x|x_1;x_2) &=
    \underbrace{\color{blue}{a} - (x-b)^2}_{\text{parabola}} -
    \underbrace{\left[
        \color{blue}{a}
      - (x_2-b)^2 + \frac{x - x_2}{x_1 - x_2}
                    (\color{blue}{a} - (x_1-b)^2 - \color{blue}{a} + (x_2-b)^2)
    \right]}_{\text{line}}
 = \\ & =
          (x_2-b)^2 - (x-b)^2
        - \frac{x - x_2}{x_1 - x_2} ((x_2-b)^2 - (x_1-b)^2)
 = \\ & =
    (x_2-\color{blue}{b}-x+\color{blue}{b})(x_2-b+x-b)
                 - \frac{x - x_2}{x_1 - x_2}
                   ((x_2-\color{blue}{b}-x_1+\color{blue}{b})(x_2-b+x_1-b))
 = \\ & =
    (x_2-x)(x_2+x-2b)
                 - \frac{x - x_2}{\color{blue}{x_1 - x_2}} ((\color{blue}{x_1 - x_2})(x_2+x_1-2b))
 = \\ & \phantom{=
    (x_2-x)[(\color{blue}{x_2}+x-\color{blue}{2b}) - (\color{blue}{x_2}+x_1-\color{blue}{2b})]
 =} \\ & \phantom{=
    (x_2-x)(x-x_1)}
\end{aligned}
$$
</div>

<div>
<b>Proof:</b><br>
First we find distance along \(Y\) axis between straigth line and parabola \(a - (x-b)^2\).
Line and parabola intersect at points \(x_1; a - (x_1-b)^2\) and \(x_2; a - (x_2-b)^2\)
$$
\begin{aligned}
d(x|x_1;x_2) &=
    \underbrace{\color{blue}{a} - (x-b)^2}_{\text{parabola}} -
    \underbrace{\left[
        \color{blue}{a}
      - (x_2-b)^2 + \frac{x - x_2}{x_1 - x_2}
                    (\color{blue}{a} - (x_1-b)^2 - \color{blue}{a} + (x_2-b)^2)
    \right]}_{\text{line}}
 = \\ & =
          (x_2-b)^2 - (x-b)^2
        - \frac{x - x_2}{x_1 - x_2} ((x_2-b)^2 - (x_1-b)^2)
 = \\ & =
    (x_2-\color{blue}{b}-x+\color{blue}{b})(x_2-b+x-b)
                 - \frac{x - x_2}{x_1 - x_2}
                   ((x_2-\color{blue}{b}-x_1+\color{blue}{b})(x_2-b+x_1-b))
 = \\ & =
    (x_2-x)(x_2+x-2b)
                 - \frac{x - x_2}{\color{blue}{x_1 - x_2}} ((\color{blue}{x_1 - x_2})(x_2+x_1-2b))
 = \\ & =
    (x_2-x)[(\color{blue}{x_2}+x-\color{blue}{2b}) - (\color{blue}{x_2}+x_1-\color{blue}{2b})]
 = \\ & \phantom{=
    (x_2-x)(x-x_1)}
\end{aligned}
$$
</div>

<div>
<b>Proof:</b><br>
First we find distance along \(Y\) axis between straigth line and parabola \(a - (x-b)^2\).
Line and parabola intersect at points \(x_1; a - (x_1-b)^2\) and \(x_2; a - (x_2-b)^2\)
$$
\begin{aligned}
d(x|x_1;x_2) &=
    \underbrace{\color{blue}{a} - (x-b)^2}_{\text{parabola}} -
    \underbrace{\left[
        \color{blue}{a}
      - (x_2-b)^2 + \frac{x - x_2}{x_1 - x_2}
                    (\color{blue}{a} - (x_1-b)^2 - \color{blue}{a} + (x_2-b)^2)
    \right]}_{\text{line}}
 = \\ & =
          (x_2-b)^2 - (x-b)^2
        - \frac{x - x_2}{x_1 - x_2} ((x_2-b)^2 - (x_1-b)^2)
 = \\ & =
    (x_2-\color{blue}{b}-x+\color{blue}{b})(x_2-b+x-b)
                 - \frac{x - x_2}{x_1 - x_2}
                   ((x_2-\color{blue}{b}-x_1+\color{blue}{b})(x_2-b+x_1-b))
 = \\ & =
    (x_2-x)(x_2+x-2b)
                 - \frac{x - x_2}{\color{blue}{x_1 - x_2}} ((\color{blue}{x_1 - x_2})(x_2+x_1-2b))
 = \\ & =
    (x_2-x)[(\color{blue}{x_2}+x-\color{blue}{2b}) - (\color{blue}{x_2}+x_1-\color{blue}{2b})]
 = \\ & =
    (x_2-x)(x-x_1)
\end{aligned}
$$
That gives us a nice method to multiply with parabola!<br>

<svg
   xmlns:ns0="http://www.iki.fi/pav/software/textext/"
   xmlns:dc="http://purl.org/dc/elements/1.1/"
   xmlns:cc="http://creativecommons.org/ns#"
   xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
   xmlns:svg="http://www.w3.org/2000/svg"
   xmlns="http://www.w3.org/2000/svg"
   xmlns:sodipodi="http://sodipodi.sourceforge.net/DTD/sodipodi-0.dtd"
   xmlns:inkscape="http://www.inkscape.org/namespaces/inkscape"
   width="120mm"
   height="100mm"
   viewBox="0 0 63.405618 52.814444"
   version="1.1"
   id="svg8"
   inkscape:export-filename="D:\nice1.png"
   inkscape:export-xdpi="101.87865"
   inkscape:export-ydpi="101.87865"
   inkscape:version="0.92.2 (5c3e80d, 2017-08-06)"
   sodipodi:docname="parabola.svg">
  <sodipodi:namedview
     id="base"
     pagecolor="#ffffff"
     bordercolor="#666666"
     borderopacity="1.0"
     inkscape:pageopacity="0.0"
     inkscape:pageshadow="2"
     inkscape:zoom="2.670475"
     inkscape:cx="-23.206091"
     inkscape:cy="80.649489"
     inkscape:document-units="mm"
     inkscape:current-layer="layer1"
     showgrid="false"
     inkscape:window-width="1920"
     inkscape:window-height="1017"
     inkscape:window-x="1912"
     inkscape:window-y="-8"
     inkscape:window-maximized="1"
     fit-margin-top="0"
     fit-margin-left="0"
     fit-margin-right="0"
     fit-margin-bottom="0" />
  <defs
     id="defs2">
    <marker
       inkscape:stockid="Arrow1Mend"
       orient="auto"
       refY="0"
       refX="0"
       id="marker36301"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         inkscape:connector-curvature="0"
         id="path36299"
         d="M 0,0 5,-5 -12.5,0 5,5 Z"
         style="fill:#000000;fill-opacity:0.26570052;fill-rule:evenodd;stroke:#000000;stroke-width:1.00000003pt;stroke-opacity:0.26570052"
         transform="matrix(-0.4,0,0,-0.4,-4,0)" />
    </marker>
    <marker
       inkscape:isstock="true"
       style="overflow:visible"
       id="marker19600"
       refX="0"
       refY="0"
       orient="auto"
       inkscape:stockid="Arrow1Mstart">
      <path
         transform="matrix(0.4,0,0,0.4,4,0)"
         style="fill:#000000;fill-opacity:0.25120778;fill-rule:evenodd;stroke:#000000;stroke-width:1.00000003pt;stroke-opacity:0.25120778"
         d="M 0,0 5,-5 -12.5,0 5,5 Z"
         id="path19598"
         inkscape:connector-curvature="0" />
    </marker>
    <marker
       inkscape:stockid="Arrow1Mend"
       orient="auto"
       refY="0"
       refX="0"
       id="marker19404"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         inkscape:connector-curvature="0"
         id="path19402"
         d="M 0,0 5,-5 -12.5,0 5,5 Z"
         style="fill:#000000;fill-opacity:1;fill-rule:evenodd;stroke:#000000;stroke-width:1.00000003pt;stroke-opacity:1"
         transform="matrix(-0.4,0,0,-0.4,-4,0)" />
    </marker>
    <marker
       inkscape:stockid="Arrow1Mend"
       orient="auto"
       refY="0"
       refX="0"
       id="marker19394"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         inkscape:connector-curvature="0"
         id="path19392"
         d="M 0,0 5,-5 -12.5,0 5,5 Z"
         style="fill:#000000;fill-opacity:0.26570052;fill-rule:evenodd;stroke:#000000;stroke-width:1.00000003pt;stroke-opacity:0.26570052"
         transform="matrix(-0.4,0,0,-0.4,-4,0)" />
    </marker>
    <marker
       inkscape:isstock="true"
       style="overflow:visible"
       id="marker19208"
       refX="0"
       refY="0"
       orient="auto"
       inkscape:stockid="Arrow2Send">
      <path
         transform="matrix(-0.3,0,0,-0.3,0.69,0)"
         d="M 8.7185878,4.0337352 -2.2072895,0.01601326 8.7185884,-4.0017078 c -1.7454984,2.3720609 -1.7354408,5.6174519 -6e-7,8.035443 z"
         style="fill:#000000;fill-opacity:1;fill-rule:evenodd;stroke:#000000;stroke-width:0.625;stroke-linejoin:round;stroke-opacity:1"
         id="path19206"
         inkscape:connector-curvature="0" />
    </marker>
    <marker
       inkscape:isstock="true"
       style="overflow:visible"
       id="marker15374"
       refX="0"
       refY="0"
       orient="auto"
       inkscape:stockid="Arrow1Mend">
      <path
         transform="matrix(-0.4,0,0,-0.4,-4,0)"
         style="fill:#006000;fill-opacity:0.46376815;fill-rule:evenodd;stroke:#006000;stroke-width:1.00000003pt;stroke-opacity:0.46376815"
         d="M 0,0 5,-5 -12.5,0 5,5 Z"
         id="path15372"
         inkscape:connector-curvature="0" />
    </marker>
    <marker
       inkscape:isstock="true"
       style="overflow:visible"
       id="marker15364"
       refX="0"
       refY="0"
       orient="auto"
       inkscape:stockid="Arrow1Mend">
      <path
         transform="matrix(-0.4,0,0,-0.4,-4,0)"
         style="fill:#000000;fill-opacity:0.25120778;fill-rule:evenodd;stroke:#000000;stroke-width:1.00000003pt;stroke-opacity:0.25120778"
         d="M 0,0 5,-5 -12.5,0 5,5 Z"
         id="path15362"
         inkscape:connector-curvature="0" />
    </marker>
    <marker
       inkscape:isstock="true"
       style="overflow:visible"
       id="marker14991"
       refX="0"
       refY="0"
       orient="auto"
       inkscape:stockid="Arrow1Mend">
      <path
         transform="matrix(-0.4,0,0,-0.4,-4,0)"
         style="fill:#000000;fill-opacity:0.51690823;fill-rule:evenodd;stroke:#000000;stroke-width:1.00000003pt;stroke-opacity:0.51690823"
         d="M 0,0 5,-5 -12.5,0 5,5 Z"
         id="path14989"
         inkscape:connector-curvature="0" />
    </marker>
    <marker
       inkscape:isstock="true"
       style="overflow:visible"
       id="marker7628"
       refX="0"
       refY="0"
       orient="auto"
       inkscape:stockid="Arrow1Mend">
      <path
         transform="matrix(-0.4,0,0,-0.4,-4,0)"
         style="fill:#000000;fill-opacity:0.40096621;fill-rule:evenodd;stroke:#000000;stroke-width:1.00000003pt;stroke-opacity:0.40096621"
         d="M 0,0 5,-5 -12.5,0 5,5 Z"
         id="path7626"
         inkscape:connector-curvature="0" />
    </marker>
    <marker
       inkscape:isstock="true"
       style="overflow:visible"
       id="marker5718"
       refX="0"
       refY="0"
       orient="auto"
       inkscape:stockid="Arrow1Mend">
      <path
         inkscape:connector-curvature="0"
         transform="matrix(-0.4,0,0,-0.4,-4,0)"
         style="fill:#000000;fill-opacity:0.33333333;fill-rule:evenodd;stroke:#000000;stroke-width:1.00000003pt;stroke-opacity:0.33333333"
         d="M 0,0 5,-5 -12.5,0 5,5 Z"
         id="path5716" />
    </marker>
    <marker
       inkscape:stockid="Arrow2Send"
       orient="auto"
       refY="0"
       refX="0"
       id="Arrow2Send"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         id="path914"
         style="fill:#000000;fill-opacity:0.47826089;fill-rule:evenodd;stroke:#000000;stroke-width:0.625;stroke-linejoin:round;stroke-opacity:0.47826089"
         d="M 8.7185878,4.0337352 -2.2072895,0.01601326 8.7185884,-4.0017078 c -1.7454984,2.3720609 -1.7354408,5.6174519 -6e-7,8.035443 z"
         transform="matrix(-0.3,0,0,-0.3,0.69,0)"
         inkscape:connector-curvature="0" />
    </marker>
    <marker
       inkscape:stockid="Arrow1Mend"
       orient="auto"
       refY="0"
       refX="0"
       id="Arrow1Mend"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         id="path890"
         d="M 0,0 5,-5 -12.5,0 5,5 Z"
         style="fill:#000000;fill-opacity:0.352657;fill-rule:evenodd;stroke:#000000;stroke-width:1.00000003pt;stroke-opacity:0.352657"
         transform="matrix(-0.4,0,0,-0.4,-4,0)"
         inkscape:connector-curvature="0" />
    </marker>
    <marker
       inkscape:stockid="Arrow2Send"
       orient="auto"
       refY="0"
       refX="0"
       id="Arrow2Send-8"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         inkscape:connector-curvature="0"
         id="path914-8"
         style="fill:#000000;fill-opacity:0.47826089;fill-rule:evenodd;stroke:#000000;stroke-width:0.625;stroke-linejoin:round;stroke-opacity:0.47826089"
         d="M 8.7185878,4.0337352 -2.2072895,0.01601326 8.7185884,-4.0017078 c -1.7454984,2.3720609 -1.7354408,5.6174519 -6e-7,8.035443 z"
         transform="matrix(-0.3,0,0,-0.3,0.69,0)" />
    </marker>
    <marker
       inkscape:stockid="Arrow2Send"
       orient="auto"
       refY="0"
       refX="0"
       id="Arrow2Send-1"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         inkscape:connector-curvature="0"
         id="path914-4"
         style="fill:#000000;fill-opacity:0.47826089;fill-rule:evenodd;stroke:#000000;stroke-width:0.625;stroke-linejoin:round;stroke-opacity:0.47826089"
         d="M 8.7185878,4.0337352 -2.2072895,0.01601326 8.7185884,-4.0017078 c -1.7454984,2.3720609 -1.7354408,5.6174519 -6e-7,8.035443 z"
         transform="matrix(-0.3,0,0,-0.3,0.69,0)" />
    </marker>
    <marker
       inkscape:stockid="Arrow2Send"
       orient="auto"
       refY="0"
       refX="0"
       id="Arrow2Send-0"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         inkscape:connector-curvature="0"
         id="path914-3"
         style="fill:#000000;fill-opacity:0.47826089;fill-rule:evenodd;stroke:#000000;stroke-width:0.625;stroke-linejoin:round;stroke-opacity:0.47826089"
         d="M 8.7185878,4.0337352 -2.2072895,0.01601326 8.7185884,-4.0017078 c -1.7454984,2.3720609 -1.7354408,5.6174519 -6e-7,8.035443 z"
         transform="matrix(-0.3,0,0,-0.3,0.69,0)" />
    </marker>
    <marker
       inkscape:stockid="Arrow2Send"
       orient="auto"
       refY="0"
       refX="0"
       id="Arrow2Send-7"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         inkscape:connector-curvature="0"
         id="path914-0"
         style="fill:#000000;fill-opacity:0.47826089;fill-rule:evenodd;stroke:#000000;stroke-width:0.625;stroke-linejoin:round;stroke-opacity:0.47826089"
         d="M 8.7185878,4.0337352 -2.2072895,0.01601326 8.7185884,-4.0017078 c -1.7454984,2.3720609 -1.7354408,5.6174519 -6e-7,8.035443 z"
         transform="matrix(-0.3,0,0,-0.3,0.69,0)" />
    </marker>
    <marker
       inkscape:stockid="Arrow2Send"
       orient="auto"
       refY="0"
       refX="0"
       id="Arrow2Send-9-0"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         inkscape:connector-curvature="0"
         id="path914-38-0"
         style="fill:#000000;fill-opacity:0.47826089;fill-rule:evenodd;stroke:#000000;stroke-width:0.625;stroke-linejoin:round;stroke-opacity:0.47826089"
         d="M 8.7185878,4.0337352 -2.2072895,0.01601326 8.7185884,-4.0017078 c -1.7454984,2.3720609 -1.7354408,5.6174519 -6e-7,8.035443 z"
         transform="matrix(-0.3,0,0,-0.3,0.69,0)" />
    </marker>
    <marker
       inkscape:stockid="Arrow2Send"
       orient="auto"
       refY="0"
       refX="0"
       id="Arrow2Send-7-1"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         inkscape:connector-curvature="0"
         id="path914-0-5"
         style="fill:#000000;fill-opacity:0.10628022;fill-rule:evenodd;stroke:#000000;stroke-width:0.625;stroke-linejoin:round;stroke-opacity:0.10628022"
         d="M 8.7185878,4.0337352 -2.2072895,0.01601326 8.7185884,-4.0017078 c -1.7454984,2.3720609 -1.7354408,5.6174519 -6e-7,8.035443 z"
         transform="matrix(-0.3,0,0,-0.3,0.69,0)" />
    </marker>
    <marker
       inkscape:stockid="Arrow2Send"
       orient="auto"
       refY="0"
       refX="0"
       id="Arrow2Send-0-2"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         inkscape:connector-curvature="0"
         id="path914-3-2"
         style="fill:#000000;fill-opacity:0.10628022;fill-rule:evenodd;stroke:#000000;stroke-width:0.625;stroke-linejoin:round;stroke-opacity:0.10628022"
         d="M 8.7185878,4.0337352 -2.2072895,0.01601326 8.7185884,-4.0017078 c -1.7454984,2.3720609 -1.7354408,5.6174519 -6e-7,8.035443 z"
         transform="matrix(-0.3,0,0,-0.3,0.69,0)" />
    </marker>
    <marker
       inkscape:stockid="Arrow2Send"
       orient="auto"
       refY="0"
       refX="0"
       id="Arrow2Send-1-7"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         inkscape:connector-curvature="0"
         id="path914-4-3"
         style="fill:#000000;fill-opacity:0.10628022;fill-rule:evenodd;stroke:#000000;stroke-width:0.625;stroke-linejoin:round;stroke-opacity:0.10628022"
         d="M 8.7185878,4.0337352 -2.2072895,0.01601326 8.7185884,-4.0017078 c -1.7454984,2.3720609 -1.7354408,5.6174519 -6e-7,8.035443 z"
         transform="matrix(-0.3,0,0,-0.3,0.69,0)" />
    </marker>
    <marker
       inkscape:stockid="Arrow2Send"
       orient="auto"
       refY="0"
       refX="0"
       id="Arrow2Send-8-4"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         inkscape:connector-curvature="0"
         id="path914-8-0"
         style="fill:#000000;fill-opacity:0.10628022;fill-rule:evenodd;stroke:#000000;stroke-width:0.625;stroke-linejoin:round;stroke-opacity:0.10628022"
         d="M 8.7185878,4.0337352 -2.2072895,0.01601326 8.7185884,-4.0017078 c -1.7454984,2.3720609 -1.7354408,5.6174519 -6e-7,8.035443 z"
         transform="matrix(-0.3,0,0,-0.3,0.69,0)" />
    </marker>
    <marker
       inkscape:stockid="Arrow2Send"
       orient="auto"
       refY="0"
       refX="0"
       id="Arrow2Send-80"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         id="path914-06"
         style="fill:#000000;fill-opacity:0.47826089;fill-rule:evenodd;stroke:#000000;stroke-width:0.625;stroke-linejoin:round;stroke-opacity:0.47826089"
         d="M 8.7185878,4.0337352 -2.2072895,0.01601326 8.7185884,-4.0017078 c -1.7454984,2.3720609 -1.7354408,5.6174519 -6e-7,8.035443 z"
         transform="matrix(-0.3,0,0,-0.3,0.69,0)"
         inkscape:connector-curvature="0" />
    </marker>
    <marker
       inkscape:stockid="Arrow2Send"
       orient="auto"
       refY="0"
       refX="0"
       id="Arrow2Send-8-9"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         inkscape:connector-curvature="0"
         id="path914-8-8"
         style="fill:#000000;fill-opacity:0.47826089;fill-rule:evenodd;stroke:#000000;stroke-width:0.625;stroke-linejoin:round;stroke-opacity:0.47826089"
         d="M 8.7185878,4.0337352 -2.2072895,0.01601326 8.7185884,-4.0017078 c -1.7454984,2.3720609 -1.7354408,5.6174519 -6e-7,8.035443 z"
         transform="matrix(-0.3,0,0,-0.3,0.69,0)" />
    </marker>
    <marker
       inkscape:stockid="Arrow2Send"
       orient="auto"
       refY="0"
       refX="0"
       id="Arrow2Send
="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;font-size:10.58333302px;line-height:1.25;font-family:Verdana;-inkscape-font-specification:Verdana;letter-spacing:0px;word-spacing:0px;fill:#000000;fill-opacity:1;stroke:none;stroke-width:0.26458332"
       xml:space="preserve"><tspan
         style="stroke-width:0.26458332"
         y="31.167419"
         x="76.906807"
         id="tspan1474"
         sodipodi:role="line" /></text>
    <g
       ns0:preamble="default_packages.tex"
       ns0:text="$p q$\n"
       word-spacing="normal"
       letter-spacing="normal"
       font-size-adjust="none"
       font-stretch="normal"
       font-weight="normal"
       font-variant="normal"
       font-style="normal"
       stroke-miterlimit="10.433"
       xml:space="preserve"
       transform="matrix(1.2512431,0,0,-1.2512431,-160.51273,876.57255)"
       id="g1983"
       style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;letter-spacing:normal;word-spacing:normal;text-anchor:start;fill:#000000;fill-opacity:1;fill-rule:evenodd;stroke:#000000;stroke-width:1.19880784;stroke-linecap:butt;stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:1"><g
         style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;letter-spacing:normal;word-spacing:normal;text-anchor:start;fill:#000000;fill-opacity:1;fill-rule:evenodd;stroke:#000000;stroke-linecap:butt;stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:1"
         id="g2079"
         transform="matrix(1.5,0,0,-1.5,-165.9,1212.8325)"
         xml:space="preserve"
         stroke-miterlimit="10.433"
         font-style="normal"
         font-variant="normal"
         font-weight="normal"
         font-stretch="normal"
         font-size-adjust="none"
         letter-spacing="normal"
         word-spacing="normal"
         ns0:text="$\\text{delete readjust}$\n"
         ns0:preamble="default_packages.tex"><g
           style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;letter-spacing:normal;word-spacing:normal;text-anchor:start;fill:#000000;fill-opacity:1;fill-rule:evenodd;stroke:#000000;stroke-linecap:butt;stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:1"
           ns0:preamble="default_packages.tex"
           ns0:text="$delete readjust$\n"
           word-spacing="normal"
           letter-spacing="normal"
           font-size-adjust="none"
           font-stretch="normal"
           font-weight="normal"
           font-variant="normal"
           font-style="normal"
           stroke-miterlimit="10.433"
           xml:space="preserve"
           transform="matrix(1.5,0,0,-1.5,-165.5925,1212.8325)"
           id="g3320"><flowRoot
             style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;font-size:40px;line-height:1.25;font-family:Verdana;-inkscape-font-specification:Verdana;letter-spacing:0px;word-spacing:0px;fill:#000000;fill-opacity:1;stroke:none"
             id="flowRoot5311"
             xml:space="preserve"><flowRegion
               id="flowRegion5313"><rect
                 y="457.16251"
                 x="78.928574"
                 height="76.428574"
                 width="60"
                 id="rect5315" /></flowRegion><flowPara
               id="flowPara5317" /></flowRoot><g
             style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;letter-spacing:normal;word-spacing:normal;text-anchor:start;fill:#000000;fill-opacity:1;fill-rule:evenodd;stroke:#000000;stroke-width:8.98821449;stroke-linecap:butt;stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:1"
             id="g25067"
             transform="matrix(0.20006332,0,0,0.20006326,165.85422,418.79014)"
             xml:space="preserve"
             stroke-miterlimit="10.433"
             font-style="normal"
             font-variant="normal"
             font-weight="normal"
             font-stretch="normal"
             font-size-adjust="none"
             letter-spacing="normal"
             word-spacing="normal"
             ns0:text="$f bias variance All functions Learnable functions$\n"
             ns0:preamble="default_packages.tex"><path
               id="path2161"
               d="m 184.28331,719.65557 3.03455,-6.96568 2.82765,-6.06911 2.77592,-5.53461 3.01731,-5.56909 2.81041,-4.74149 3.0518,-4.68976 2.98283,-4.12079 2.79316,-3.43111 3.01731,-3.24146 0.0517,-0.0517 0.0345,-0.0517 0.0862,-0.0862 0.18966,-0.17242 0.34484,-0.32759 0.70691,-0.67243 1.41382,-1.2414 0.0517,-0.0517 0.0517,-0.0345 0.0862,-0.0862 0.18966,-0.15518 0.37932,-0.31035 0.77588,-0.60347 0.0345,-0.0345 0.0517,-0.0345 0.10345,-0.0862 0.18966,-0.13793 0.37932,-0.27587 0.75864,-0.55174 0.0517,-0.0345 0.0517,-0.0172 0.0862,-0.069 0.18967,-0.1207
stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:0.83137255"
               id="path2399-60"
               cx="264.85767"
               cy="-698.24445"
               rx="1.7192211"
               ry="1.7192215"
               transform="scale(1,-1)" /><text
               xml:space="preserve"
               style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;font-size:3.53762031px;line-height:1.25;font-family:Verdana;-inkscape-font-specification:Verdana;letter-spacing:0px;word-spacing:0px;fill:#000000;fill-opacity:0.52657004;stroke:none;stroke-width:4.22225332"
               x="235.71082"
               y="-666.25909"
               id="text2451"
               transform="scale(0.9999999,-1.0000001)"><tspan
                 sodipodi:role="line"
                 id="tspan2449"
                 x="235.71082"
                 y="-666.25909"
                 style="font-style:normal;font-variant:normal;font-weight:bold;font-stretch:normal;font-size:3.53762031px;font-family:'Courier New';-inkscape-font-specification:'Courier New, Bold';font-variant-ligatures:normal;font-variant-caps:normal;font-variant-numeric:normal;font-feature-settings:normal;text-align:start;writing-mode:lr-tb;text-anchor:start;fill:#000000;fill-opacity:0.52657004;stroke-width:4.22225332">1</tspan></text>
<text
               xml:space="preserve"
               style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;font-size:3.53762007px;line-height:1.25;font-family:Verdana;-inkscape-font-specification:Verdana;letter-spacing:0px;word-spacing:0px;text-anchor:start;fill:#000000;fill-opacity:0.52657004;fill-rule:evenodd;stroke:none;stroke-width:4.22225332;stroke-linecap:butt;stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:1"
               x="242.60927"
               y="-669.81085"
               id="text2451-1"
               transform="scale(0.99999989,-1.0000001)"><tspan
                 sodipodi:role="line"
                 id="tspan2449-1"
                 x="242.60927"
                 y="-669.81085"
                 style="font-style:normal;font-variant:normal;font-weight:bold;font-stretch:normal;font-size:3.53762007px;font-family:'Courier New';-inkscape-font-specification:'Courier New, Bold';font-variant-ligatures:normal;font-variant-caps:normal;font-variant-numeric:normal;font-feature-settings:normal;text-align:start;writing-mode:lr-tb;text-anchor:start;fill:#000000;fill-opacity:0.52657004;stroke-width:4.22225332">2</tspan></text>
<text
               xml:space="preserve"
               style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;font-size:3.53762007px;line-height:1.25;font-family:Verdana;-inkscape-font-specification:Verdana;letter-spacing:0px;word-spacing:0px;text-anchor:start;fill:#000000;fill-opacity:0.52657004;fill-rule:evenodd;stroke:none;stroke-width:4.22225332;stroke-linecap:butt;stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:1"
               x="250.03986"
               y="-677.03534"
               id="text2451-8"
               transform="scale(0.99999989,-1.0000001)"><tspan
                 sodipodi:role="line"
                 id="tspan2449-9"
                 x="250.03986"
                 y="-677.03534"
                 style="font-style:normal;font-variant:normal;font-weight:bold;font-stretch:normal;font-size:3.53762007px;font-family:'Courier New';-inkscape-font-specification:'Courier New, Bold';font-variant-ligatures:normal;font-variant-caps:normal;font-variant-numeric:normal;font-feature-settings:normal;text-align:start;writing-mode:lr-tb;text-anchor:start;fill:#000000;fill-opacity:0.52657004;stroke-width:4.22225332">3</tspan></text>
<text
               xml:space="preserve"
               style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;font-size:3.53762007px;line-height:1.25;font-family:Verdana;-inkscape-font-specification:Verdana;letter-spacing:0px;word-spacing:0px;text-anchor:start;fill:#000000;fill-opacity:0.52657004;fill-rule:evenodd;stroke:none;stroke-width:4.22225332;stroke-linecap:butt;stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:1"
               x="256.78085"
               y="-686.03082"
               id="text2451-4"
               transform="scale(0.99999989,-1.0000001)"><tspan
                 sodipodi:role="line"
                 id="tspan2449-93"
                 x="256.78085"
                 y="-686.03082"
                 style="font-style:normal;font-variant:normal;font-weight:bold;font-stretch:normal;font-size:3.53762007px;font-family:'Courier New';-inkscape-font-specification:'Courier New, Bold';font-variant-ligatures:normal;font-variant-caps:normal;font-variant-numeric:normal;font-feature-settings:normal;text-align:start;writing-mode:lr-tb;text-anchor:start;fill:#000000;fill-opacity:0.52657004;stroke-width:4.22225332">4</tspan></text>
<ellipse
               style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;letter-spacing:normal;word-spacing:normal;text-anchor:start;opacity:1;fill:#e3e3e3;fill-opacity:1;fill-rule:evenodd;stroke:none;stroke-width:0.98182386;stroke-linecap:square;stroke-linejoin:miter;stroke-miterlimit:3;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:0.83137255"
               id="path2399-3"
               cx="229.40138"
               cy="-665.96747"
               rx="1.7192211"
               ry="1.7192215"
               transform="scale(1,-1)" /><text
               xml:space="preserve"
               style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;font-size:3.53761983px;line-height:1.25;font-family:Verdana;-inkscape-font-specification:Verdana;letter-spacing:0px;word-spacing:0px;text-anchor:start;fill:#000000;fill-opacity:0.52657004;fill-rule:evenodd;stroke:none;stroke-width:4.22225332;stroke-linecap:butt;stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:1"
               x="263.89496"
               y="-697.10089"
               id="text2451-4-9"
               transform="scale(0.99999989,-1.0000001)"><tspan
                 sodipodi:role="line"
                 id="tspan2449-93-6"
                 x="263.89496"
                 y="-697.10089"
                 style="font-style:normal;font-variant:normal;font-weight:bold;font-stretch:normal;font-size:3.53761983px;font-family:'Courier New';-inkscape-font-specification:'Courier New, Bold';font-variant-ligatures:normal;font-variant-caps:normal;font-variant-numeric:normal;font-feature-settings:normal;text-align:start;writing-mode:lr-tb;text-anchor:start;fill:#000000;fill-opacity:0.52657004;stroke-width:4.22225332">5</tspan></text>
<ellipse
               style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;letter-spacing:normal;word-spacing:normal;text-anchor:start;opacity:1;fill:#e3e3e3;fill-opacity:1;fill-rule:evenodd;stroke:none;stroke-width:0.98182386;stroke-linecap:square;stroke-linejoin:miter;stroke-miterlimit:3;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:0.83137255"
               id="path2399-601"
               cx="-222.42375"
               cy="-667.3847"
               rx="1.7192211"
               ry="1.7192215"
               transform="scale(-1)" /><ellipse
               style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;letter-spacing:normal;word-spacing:normal;text-anchor:start;opacity:1;fill:#e3e3e3;fill-opacity:1;fill-rule:evenodd;stroke:none;stroke-width:0.98182386;stroke-linecap:square;stroke-linejoin:miter;stroke-miterlimit:3;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:0.83137255"
               id="path2399-6-3"
               cx="-215.54688"
               cy="-670.96906"
               rx="1.7192211"
               ry="1.7192215"
               transform="scale(-1)" /><ellipse
               style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;letter-spacing:normal;word-spacing:normal;text-anchor:start;opacity:1;fill:#e3e3e3;fill-opacity:1;fill-rule:evenodd;stroke:none;stroke-width:0.98182386;stroke-linecap:square;stroke-linejoin:miter;stroke-miterlimit:3;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:0.83137255"
               id="path2399-8-1"
               cx="-208.02122"
               cy="-678.17035"
               rx="1.7192211"
               ry="1.7192215"
               transform="scale(-1)" /><ellipse
               style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;letter-spacing:normal;word-spacing:normal;text-anchor:start;opacity:1;fill:#e3e3e3;fill-opacity:1;fill-rule:evenodd;stroke:none;stroke-width:0.98182386;stroke-linecap:square;stroke-linejoin:miter;stroke-miterlimit:3;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:0.83137255"
               id="path2399-1-4"
               cx="-201.20921"
               cy="-687.18817"
               rx="1.7192211"
               ry="1.7192215"
               transform="scale(-1)" /><text
               xml:space="preserve"
               style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;font-size:3.53762007px;line-height:1.25;font-family:Verdana;-inkscape-font-specification:Verdana;letter-spacing:0px;word-spacing:0px;text-anchor:start;fill:#000000;fill-opacity:0.52657004;fill-rule:evenodd;stroke:none;stroke-width:4.22225332;stroke-linecap:butt;stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:1"
               x="221.51173"
               y="-666.18951"
               id="text2451-2"
               transform="scale(0.9999999,-1.0000001)"><tspan
                 sodipodi:role="line"
                 id="tspan2449-8"
                 x="221.51173"
                 y="-666.18951"
                 style="font-style:normal;font-variant:normal;font-weight:bold;font-stretch:normal;font-size:3.53762007px;font-family:'Courier New';-inkscape-font-specification:'Courier New, Bold';font-variant-ligatures:normal;font-variant-caps:normal;font-variant-numeric:normal;font-feature-settings:normal;text-align:start;writing-mode:lr-tb;text-anchor:start;fill:#000000;fill-opacity:0.52657004;stroke-width:4.22225332">1</tspan></text>
<text
               xml:space="preserve"
               style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;font-size:3.53761983px;line-height:1.25;font-family:Verdana;-inkscape-font-specification:Verdana;letter-spacing:0px;word-spacing:0px;text-anchor:start;fill:#000000;fill-opacity:0.52657004;fill-rule:evenodd;stroke:none;stroke-width:4.22225332;stroke-linecap:butt;stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:1"
               x="214.58661"
               y="-669.73755"
               id="text2451-1-2"
               transform="scale(0.99999989,-1.0000001)"><tspan
                 sodipodi:role="line"
                 id="tspan2449-1-3"
                 x="214.58661"
                 y="-669.73755"
                 style="font-style:normal;font-variant:normal;font-weight:bold;font-stretch:normal;font-size:3.53761983px;font-family:'Courier New';-inkscape-font-specification:'Courier New, Bold';font-variant-ligatures:normal;font-variant-caps:normal;font-variant-numeric:normal;font-feature-settings:normal;text-align:start;writing-mode:lr-tb;text-anchor:start;fill:#000000;fill-opacity:0.52657004;stroke-width:4.22225332">2</tspan></text>
<text
               xml:space="preserve"
               style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;font-size:3.53761983px;line-height:1.25;font-family:Verdana;-inkscape-font-specification:Verdana;letter-spacing:0px;word-spacing:0px;text-anchor:start;fill:#000000;fill-opacity:0.52657004;fill-rule:evenodd;stroke:none;stroke-width:4.22225332;stroke-linecap:butt;stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:1"
               x="207.05099"
               y="-677.01953"
               id="text2451-8-9"
               transform="scale(0.99999989,-1.0000001)"><tspan
                 sodipodi:role="line"
                 id="tspan2449-9-7"
                 x="207.05099"
                 y="-677.01953"
                 style="font-style:normal;font-variant:normal;font-weight:bold;font-stretch:normal;font-size:3.53761983px;font-family:'Courier New';-inkscape-font-specification:'Courier New, Bold';font-variant-ligatures:normal;font-variant-caps:normal;font-variant-numeric:normal;font-feature-settings:normal;text-align:start;writing-mode:lr-tb;text-anchor:start;fill:#000000;fill-opacity:0.52657004;stroke-width:4.22225332">3</tspan></text>
<text
               xml:space="preserve"
               style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;font-size:3.53761983px;line-height:1.25;font-family:Verdana;-inkscape-font-specification:Verdana;letter-spacing:0px;word-spacing:0px;text-anchor:start;fill:#000000;fill-opacity:0.52657004;fill-rule:evenodd;stroke:none;stroke-width:4.22225332;stroke-linecap:butt;stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:1"
               x="200.08289"
               y="-686.05939"
               id="text2451-4-1"
               transform="scale(0.9999999,-1.0000001)"><tspan
                 sodipodi:role="line"
                 id="tspan2449-93-7"
                 x="200.08289"
                 y="-686.05939"
                 style="font-style:normal;font-variant:normal;font-weight:bold;font-stretch:normal;font-size:3.53761983px;font-family:'Courier New';-inkscape-font-specification:'Courier New, Bold';font-variant-ligatures:normal;font-variant-caps:normal;font-variant-numeric:normal;font-feature-settings:normal;text-align:start;writing-mode:lr-tb;text-anchor:start;fill:#000000;fill-opacity:0.52657004;stroke-width:4.22225332">4</tspan></text>
<text
               xml:space="preserve"
               style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;font-size:3.53762007px;line-height:1.25;font-family:Verdana;-inkscape-font-specification:Verdana;letter-spacing:0px;word-spacing:0px;text-anchor:start;fill:#000000;fill-opacity:0.52657004;fill-rule:evenodd;stroke:none;stroke-width:4.22225332;stroke-linecap:butt;stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:1"
               x="228.35291"
               y="-664.79022"
               id="text2451-80"
               transform="scale(0.99999989,-1.0000001)"><tspan
                 sodipodi:role="line"
                 id="tspan2449-5"
                 x="228.35291"
                 y="-664.79022"
                 style="font-style:normal;font-variant:normal;font-weight:bold;font-stretch:normal;font-size:3.53762007px;font-family:'Courier New';-inkscape-font-specification:'Courier New, Bold';font-variant-ligatures:normal;font-variant-caps:normal;font-variant-numeric:normal;font
stroke-linecap:butt;stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:0.44927596"
               d="m 230.12551,699.34137 h -1.10346"
               id="path2754-7-9-41"
               inkscape:connector-curvature="0" /><text
               xml:space="preserve"
               style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;font-size:3.53761959px;line-height:1.25;font-family:Verdana;-inkscape-font-specification:Verdana;letter-spacing:0px;word-spacing:0px;text-anchor:start;fill:#000000;fill-opacity:0.72946861;fill-rule:evenodd;stroke:none;stroke-width:4.22225332;stroke-linecap:butt;stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:1"
               x="230.13873"
               y="-680.88953"
               id="text2451-8-9-2"
               transform="scale(0.9999999,-1.0000001)"><tspan
                 sodipodi:role="line"
                 id="tspan2449-9-7-5"
                 x="230.13873"
                 y="-680.88953"
                 style="font-style:normal;font-variant:normal;font-weight:bold;font-stretch:normal;font-size:3.53761959px;font-family:'Courier New';-inkscape-font-specification:'Courier New, Bold';font-variant-ligatures:normal;font-variant-caps:normal;font-variant-numeric:normal;font-feature-settings:normal;text-align:start;writing-mode:lr-tb;text-anchor:start;fill:#000000;fill-opacity:0.72946861;stroke-width:4.22225332">12</tspan></text>
<ellipse
               style="opacity:1;fill:#000000;fill-opacity:0.72946861;stroke:#272727;stroke-width:0.17754497;stroke-linecap:square;stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:0.47826089"
               id="path3956"
               cx="229.61906"
               cy="-681.70215"
               transform="scale(1,-1)"
               rx="0.41979867"
               ry="0.41979879" /></g></g></g></g>  </g>
</svg>

</div>

<div>
<b>Proof:</b><br>
We notice that
$$
\begin{aligned}
e_2 &=
\mathbb{E}_{x_1;x_2} [e_2(x_1;x_2)] =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
    (f(x) - g_2(x|x_1;x_2))^2
dx\, dx_1 dx_2 =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
d^2(x|x_1;x_2)
dx\, dx_1 dx_2 = \\ & \phantom{=
\int\limits_0^1\int\limits_0^1\int\limits_0^1
(x_2 - x)^2 (x - x_1)^2
dx\, dx_1 dx_2 =} \\ & \phantom{=
\int\limits_0^1\int\limits_0^1\int\limits_0^1
(x_2 - x)^2 (x_1 - x)^2
dx_1 dx_2 dx =
\int\limits_0^1\int\limits_{-x}^{1-x}\int\limits_{-x}^{1-x}
x_2^2 x_1^2
dx_1 dx_2 dx =} \\ & \phantom{=
\frac{1}{9} \int\limits_0^1
((1-x)^3 + x^3)^2
dx = \frac{3}{90} }
\end{aligned}
$$
</div>

<div>
<b>Proof:</b><br>
Substitute \(d\)
$$
\begin{aligned}
e_2 &=
\mathbb{E}_{x_1;x_2} [e_2(x_1;x_2)] =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
    (f(x) - g_2(x|x_1;x_2))^2
dx\, dx_1 dx_2 =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
d^2(x|x_1;x_2)
dx\, dx_1 dx_2 = \\ & =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
(x_2 - x)^2 (x - x_1)^2
dx\, dx_1 dx_2 = \\ & \phantom{=
\int\limits_0^1\int\limits_0^1\int\limits_0^1
(x_2 - x)^2 (x_1 - x)^2
dx_1 dx_2 dx =
\int\limits_0^1\int\limits_{-x}^{1-x}\int\limits_{-x}^{1-x}
x_2^2 x_1^2
dx_1 dx_2 dx =} \\ & \phantom{=
\frac{1}{9} \int\limits_0^1
((1-x)^3 + x^3)^2
dx = \frac{3}{90} }
\end{aligned}
$$
</div>

<div>
<b>Proof:</b><br>
Change integration order and limits
$$
\begin{aligned}
e_2 &=
\mathbb{E}_{x_1;x_2} [e_2(x_1;x_2)] =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
    (f(x) - g_2(x|x_1;x_2))^2
dx\, dx_1 dx_2 =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
d^2(x|x_1;x_2)
dx\, dx_1 dx_2 = \\ & =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
(x_2 - x)^2 (x - x_1)^2
dx\, dx_1 dx_2 = \\ & =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
(x_2 - x)^2 (x_1 - x)^2
dx_1 dx_2 dx =
\int\limits_0^1\int\limits_{-x}^{1-x}\int\limits_{-x}^{1-x}
x_2^2 x_1^2
dx_1 dx_2 dx = \\ & \phantom{=
\frac{1}{9} \int\limits_0^1
((1-x)^3 + x^3)^2
dx = \frac{3}{90} }
\end{aligned}
$$
</div>

<div>
<b>Proof:</b><br>
Integrate
$$
\begin{aligned}
e_2 &=
\mathbb{E}_{x_1;x_2} [e_2(x_1;x_2)] =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
    (f(x) - g_2(x|x_1;x_2))^2
dx\, dx_1 dx_2 =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
d^2(x|x_1;x_2)
dx\, dx_1 dx_2 = \\ & =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
(x_2 - x)^2 (x - x_1)^2
dx\, dx_1 dx_2 = \\ & =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
(x_2 - x)^2 (x_1 - x)^2
dx_1 dx_2 dx =
\int\limits_0^1\int\limits_{-x}^{1-x}\int\limits_{-x}^{1-x}
x_2^2 x_1^2
dx_1 dx_2 dx = \\ & =
\frac{1}{9} \int\limits_0^1
((1-x)^3 + x^3)^2
dx = \frac{3}{90}  = \frac{1}{30}
\end{aligned}
$$
<b>QED</b>
</div>

</div>

<div style="position:absolute; top:30px; left:900px;">

<div id="arrow_left" style="border-width: 1px; border-style:solid; float:left; height:32px;">
<svg width="8.7464mm" height="8.7464mm" version="1.1" viewBox="0 0 8.7464 8.7464" xmlns="http://www.w3.org/2000/svg" xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
<metadata>
<rdf:RDF>
<cc:Work rdf:about="">
<dc:format>image/svg+xml</dc:format>
<dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
<dc:title/>
</cc:Work>
</rdf:RDF>
</metadata>
<g transform="translate(-38.564 -29.908)">
<rect x="38.564" y="29.908" width="8.7464" height="8.7464" fill-opacity=".16425" opacity=".97" stroke-miterlimit="10.433" stroke-width="0"/>
<path d="m45.796 34.331h-5.8931" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m40.068 34.267 2.7141-2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m40.069 34.396 2.7141 2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
</g>
</svg>
</div>

<div id="arrow_right" style="border-width: 1px; border-style:solid; float:right; height:32px;">
<svg width="8.7464mm" height="8.7464mm" version="1.1" viewBox="0 0 8.7464 8.7464" xmlns="http://www.w3.org/2000/svg" xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
<metadata>
<rdf:RDF>
<cc:Work rdf:about="">
<dc:format>image/svg+xml</dc:format>
<dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
<dc:title/>
</cc:Work>
</rdf:RDF>
</metadata>
<g transform="translate(-38.564 -29.908)">
<rect transform="scale(-1,1)" x="-47.31" y="29.908" width="8.7464" height="8.7464" fill-opacity=".16425" opacity=".97" stroke-miterlimit="10.433" stroke-width="0"/>
<path d="m40.078 34.331h5.8931" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m45.806 34.267-2.7141-2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m45.805 34.396-2.7141 2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
</g>
</svg>
</div>

</div>

<style>
#arrow_left:hover{color:blue;}
#arrow_right:hover{color:blue;}
</style>

<script  type="text/javascript">
//var slides = ["slide_1", "slide_2", "slide_3"];

var container = document.getElementById("all_slides");
var menu_conn = document.createElement("div");
menu_conn.style.height = "90px";
menu_conn.id = "menu_div";
container.prepend(menu_conn);

// crutches
var slides = [];
var tmp = container.getElementsByTagName("div");
for (var i = 0; i < tmp.length; ++i)
  if (!tmp[i].id || tmp[i].id != "menu_div")
  {
    tmp[i].classList.add('slide_style');
    slides.push(tmp[i]);
  }


var left_btn_id = "arrow_left";
var right_btn_id = "arrow_right";
var current_slide = 0;
var menu = [];

function change_slide_to(new_slide_idx)
{
  menu[current_slide].style.borderWidth = "0px";
  var old_slide = slides[current_slide]; //document.getElementById(slides[current_slide]);
  current_slide = new_slide_idx;
  menu[current_slide].style.borderWidth = "2px";
  var new_slide = slides[current_slide]; //document.getElementById(slides[current_slide]);
  old_slide.style.display='none';
  new_slide.style.display='block';
}

function slide_left()
{
  var new_idx = current_slide - 1;
  if (new_idx < 0) {new_idx = 0;}
  change_slide_to(new_idx);
}

function slide_right()
{
  var new_idx = current_slide + 1;
  if (new_idx >= slides.length) {new_idx = slides.length - 1;}
  change_slide_to(new_idx);
}

function change(obj, is_correct)
{
//   alert(obj.parentNode.rowIndex);
    var rowId = obj.parentNode.rowIndex;
    var table = obj.parentNode.parentNode.parentNode;
    var rowsNotSelected = table.getElementsByTagName('tr');
    for (var row = 0; row < rowsNotSelected.length; row++)
    {
        rowsNotSelected[row].cells[0].style.backgroundColor = "white";
    }
    var rowSelected = table.getElementsByTagName('tr')[rowId];
    if (is_correct > 0)
    {
        rowSelected.cells[0].style.backgroundColor = "#66bb6aa9";
        menu[current_slide].style.backgroundColor = "#66bb6aa9";
    }
    else
    {
        rowSelected.cells[0].style.backgroundColor = "#ff3a3981";
        menu[current_slide].style.backgroundColor = "#ff3a3981";
    }
}

function make_callback(obj, is_correct)
{
  return function() { change(obj, is_correct); }
}

function change_callback(new_idx)
{
  return function() { change_slide_to(new_idx); }
}

document.getElementById(left_btn_id).addEventListener("click", slide_left);
document.getElementById(right_btn_id).addEventListener("click", slide_right);
slides[current_slide].style.display='block'; //document.getElementById(slides[current_slide]).style.display='block';

// create upper menu
upper_menu = document.getElementById("menu_div");

var tbl      = document.createElement("table");
var tbl_body = document.createElement("tbody");
var tbl_row  = document.createElement("tr");
for (idx = 0; idx < slides.length; idx++)
{
    var tbl_cell = document.createElement("td");
    var cell_text = document.createTextNode(idx+1);
    tbl_cell.appendChild(cell_text);
    tbl_cell.onclick = change_callback(idx);
    tbl_row.appendChild(tbl_cell);
    menu.push(tbl_cell);
    tbl_cell.style.borderWidth = "0px";

    var slide = slides[idx]; //document.getElementById(slides[idx]);
    var all_tables = slide.getElementsByTagName("table");
    for (t_i = 0; t_i < all_tables.length; t_i++)
    {
      var table = all_tables[t_i];
      if (!table.classList.contains("question_style"))
        continue;
      var rows = table.getElementsByTagName('tr');
      for (r_i = 0; r_i < rows.length; r_i++)
      {
        var question_cell = rows[r_i].cells[0];
        question_cell.classList.add("highlight");
        if (question_cell.classList.contains("ok"))
        {
          question_cell.onclick = make_callback(question_cell, 1);
        } else {
          question_cell.onclick = make_callback(question_cell, 0);
        }


        var cell = rows[r_i].insertCell(0);
        cell.width = "50px";
      }
    }
}
tbl_body.appendChild(tbl_row);
tbl.appendChild(tbl_body);
upper_menu.appendChild(tbl);
tbl.classList.add('menu_style');
menu[current_slide].style.borderWidth = "2px";

</script>

<style>
    .slide_style {
      max-width:750px;
      display:none;
      font: 14pt/18pt sans-serif;
      position: static;
      top: 80px;
      left: 0px;
    }

    .question_style {
        width:600px;
        font: 16pt/14pt sans-serif bold;
        text-align:left;
        cursor: default;
    }
    .question_style td{
        padding:7px;
        height: 50px;
        border:#4e95f4 0px solid;
        text-align:left;
        font: 13pt/16pt sans-serif;
    }
    .highlight:hover{
        background-color: #00000019
    }
    .menu_style {
        height:50px;
        font: 16pt/14pt sans-serif bold;
        text-align:left;
        cursor: default;
    }
    .menu_style td{
        width:50px;
        padding:7px;
        border:#787878ff solid;
        text-align:center;
        font: 16pt/14pt sans-serif;
        color: #606060ff;
    }
</style>
# Out:
# <script src='https://www.gstatic.com/external_hosted/mathjax/latest/MathJax.js?config=default'></script>
#
# <div id="all_slides">
#
# <div>
# <list>
# <li> Linear model
# </list>
# <br>
# Given the dataset, i.e. \((x_1;f(x_1))\) and \((x_2;f(x_2))\) we do the best possible fit.
# Using previous results, it is easy to see that trained model looks like
# $$
#     g_2(x|x_1;x_2) = f(x_2)
#                    + \frac{x - x_2}{x_1 - x_2}
#                      (f(x_1) - f(x_2))
# $$
# The squared error of the model trained on \((x_1;f(x_1))\) and \((x_2;f(x_2))\) reads
# $$
# e_2(x_1;x_2) = \int\limits_0^1
#                    (f(x) - g_2(x|x_1;x_2))^2
#                dx.
# $$
# Since all datasets are equally possible, we expect (on average) the error to be
# $$
# e_2 =
# \mathbb{E}_{x_1;x_2} [e_2(x_1;x_2)] =
# \int\limits_0^1\int\limits_0^1\int\limits_0^1
#     (f(x) - g_2(x|x_1;x_2))^2
# dx\, dx_1 dx_2 =
# \frac{1}{30} \approx 0.03
# $$
# </div>
#
# <div>
# <b>Proof:</b><br>
# ...

# %% [markdown]
# **Conclusions**
#
# Seems like $H_1$ is better (WOW)
#
# * Think what to do and what to do not, when assessing the quality of models
# * Make a guess, why is the result $H_1$ better than $H_2$

# %%
#@title Bias and variance for constant model

# %%html
<script src='https://www.gstatic.com/external_hosted/mathjax/latest/MathJax.js?config=default'></script>

<div id="all_slides">

<div>
<list>
<li> Constant model
</list>
<br>
The mean trained model is
$$
\bar{g}(x) =
\int\limits_0^1\int\limits_0^1
(2/3 - x_1/2) x_1 + (2/3 - x_2/2) x_2
dx_1 dx_2 = \frac{1}{3}
$$
Expected squared bias is
$$
\mathbb{B}ias^2[f] = \mathbb{E}_x [(f(x) - \bar{g}(x))^2] = \frac{2}{135} \approx 0.0148
$$
Expected variance is
$$
\mathbb{V}ar[f] =
\mathbb{E}_{x} [\mathbb{E}_{x_1;x_2}[(\bar{g}(x) - g(x|x_1;x_2))^2] ] =
\frac{1}{135} \approx 0.0074
$$
It is easy to check that
$$
\mathbb{V}ar[f] + \mathbb{B}ias^2[f] = \frac{1}{45}
\approx 0.022
$$
as it should be according to bias-variance decomposition.
</div>

<div>
Proof:<br>
From previous results write expressio for "mean model"
$$
\begin{aligned}
\bar{g}(x) &=
\int\limits_0^1\int\limits_0^1
(2/3 - x_1/2) x_1 + (2/3 - x_2/2) x_2
dx_1 dx_2 = \\ & \phantom{=
\int\limits_0^1\int\limits_0^1
(2/3 - x_1/2) x_1
dx_1 dx_2 +
\int\limits_0^1\int\limits_0^1
(2/3 - x_2/2) x_2
dx_1 dx_2 =} \\ & \phantom{=
\int\limits_0^1
(2/3 - x_1/2) x_1
dx_1 +
\int\limits_0^1
(2/3 - x_2/2) x_2
dx_2 =} \\ & \phantom{=
\int\limits_0^1
(4/3 - x') x'
dx' = \frac{1}{3}}
\end{aligned}
$$
</div>

<div>
Proof:<br>
Integral of sum is sum of integrals
$$
\begin{aligned}
\bar{g}(x) &=
\int\limits_0^1\int\limits_0^1
(2/3 - x_1/2) x_1 + (2/3 - x_2/2) x_2
dx_1 dx_2 = \\ & =
\int\limits_0^1\int\limits_0^1
(2/3 - x_1/2) x_1
dx_1 dx_2 +
\int\limits_0^1\int\limits_0^1
(2/3 - x_2/2) x_2
dx_1 dx_2 = \\ & \phantom{=
\int\limits_0^1
(2/3 - x_1/2) x_1
dx_1 +
\int\limits_0^1
(2/3 - x_2/2) x_2
dx_2 =} \\ & \phantom{=
\int\limits_0^1
(4/3 - x') x'
dx' = \frac{1}{3}}
\end{aligned}
$$
</div>

<div>
Proof:<br>
Integrate once
$$
\begin{aligned}
\bar{g}(x) &=
\int\limits_0^1\int\limits_0^1
(2/3 - x_1/2) x_1 + (2/3 - x_2/2) x_2
dx_1 dx_2 = \\ & =
\int\limits_0^1\int\limits_0^1
(2/3 - x_1/2) x_1
dx_1 dx_2 +
\int\limits_0^1\int\limits_0^1
(2/3 - x_2/2) x_2
dx_1 dx_2 = \\ & =
\int\limits_0^1
(2/3 - x_1/2) x_1
dx_1 +
\int\limits_0^1
(2/3 - x_2/2) x_2
dx_2 = \\ & \phantom{=
\int\limits_0^1
(4/3 - x') x'
dx' = \frac{1}{3}}
\end{aligned}
$$
</div>

<div>
Proof:<br>
Notice that integrals are essentially equal; finish integration
$$
\begin{aligned}
\bar{g}(x) &=
\int\limits_0^1\int\limits_0^1
(2/3 - x_1/2) x_1 + (2/3 - x_2/2) x_2
dx_1 dx_2 = \\ & =
\int\limits_0^1\int\limits_0^1
(2/3 - x_1/2) x_1
dx_1 dx_2 +
\int\limits_0^1\int\limits_0^1
(2/3 - x_2/2) x_2
dx_1 dx_2 = \\ & =
\int\limits_0^1
(2/3 - x_1/2) x_1
dx_1 +
\int\limits_0^1
(2/3 - x_2/2) x_2
dx_2 = \\ & =
\int\limits_0^1
(4/3 - x') x'
dx' = \frac{1}{3}
\end{aligned}
$$
that gives us the "mean model"
</div>

<div>
Proof:<br>
Now substitute the result into the expression for bias squared
$$
\begin{aligned}
\mathbb{B}ias^2[f] &= \mathbb{E}_x [(f(x) - \bar{g}(x))^2] =
\int_0^1
(4/9 - (x - 2/3)^2 - 1/3)^2
dx = \\ & \phantom{=
\int_{-2/3}^{1/3}
(1/9 - x^2)^2
dx = \frac{2}{135}}
\end{aligned}
$$
</div>

<div>
Proof:<br>
Perform integration
$$
\begin{aligned}
\mathbb{B}ias^2[f] &= \mathbb{E}_x [(f(x) - \bar{g}(x))^2] =
\int_0^1
(4/9 - (x - 2/3)^2 - 1/3)^2
dx = \\ & =
\int_{-2/3}^{1/3}
(1/9 - x^2)^2
dx = \frac{2}{135}
\end{aligned}
$$
that gives us squared bias.
</div>

<div>
Proof:<br>
Write definition of variance
$$
\begin{aligned}
\mathbb{V}ar[f] &=
\mathbb{E}_{x} [\mathbb{E}_{x_1;x_2}[(\bar{g}(x) - g(x|x_1;x_2))^2] ] = \\ & \phantom{=
\int\limits_0^1\int\limits_0^1\int\limits_0^1
\left(\frac{1}{3} - \left(\frac{2}{3} - \frac{x_1}{2}\right)x_1 - \left(\frac{2}{3} - \frac{x_2}{2}\right)x_2\right)^2
dx_1 dx_2 dx =} \\ & \phantom{=
\frac{1}{4}\int\limits_0^1\int\limits_0^1\int\limits_0^1
\left(\left(x_1 - \frac{2}{3}\right)^2 + \left(x_2 - \frac{2}{3}\right)^2 - \frac{2}{9}\right)^2
dx_1 dx_2 dx =} \\ & \phantom{=
\frac{1}{4}\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}
\left(x_1^2 + x_2^2 - \frac{2}{9}\right)^2
dx_1 dx_2 = \frac{1}{135}}
\end{aligned}
$$
</div>

<div>
Proof:<br>
Substitute expressions for \(g\) and \(\bar{g}\)
$$
\begin{aligned}
\mathbb{V}ar[f] &=
\mathbb{E}_{x} [\mathbb{E}_{x_1;x_2}[(\bar{g}(x) - g(x|x_1;x_2))^2] ] = \\ & =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
\left(\frac{1}{3} - \left(\frac{2}{3} - \frac{x_1}{2}\right)x_1 - \left(\frac{2}{3} - \frac{x_2}{2}\right)x_2\right)^2
dx_1 dx_2 dx = \\ & \phantom{=
\frac{1}{4}\int\limits_0^1\int\limits_0^1\int\limits_0^1
\left(\left(x_1 - \frac{2}{3}\right)^2 + \left(x_2 - \frac{2}{3}\right)^2 - \frac{2}{9}\right)^2
dx_1 dx_2 dx =} \\ & \phantom{=
\frac{1}{4}\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}
\left(x_1^2 + x_2^2 - \frac{2}{9}\right)^2
dx_1 dx_2 = \frac{1}{135}}
\end{aligned}
$$
</div>

<div>
Proof:<br>
Collect squares of differences
$$
\begin{aligned}
\mathbb{V}ar[f] &=
\mathbb{E}_{x} [\mathbb{E}_{x_1;x_2}[(\bar{g}(x) - g(x|x_1;x_2))^2] ] = \\ & =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
\left(\frac{1}{3} - \left(\frac{2}{3} - \frac{x_1}{2}\right)x_1 - \left(\frac{2}{3} - \frac{x_2}{2}\right)x_2\right)^2
dx_1 dx_2 dx = \\ & =
\frac{1}{4}\int\limits_0^1\int\limits_0^1\int\limits_0^1
\left(\left(x_1 - \frac{2}{3}\right)^2 + \left(x_2 - \frac{2}{3}\right)^2 - \frac{2}{9}\right)^2
dx_1 dx_2 dx = \\ & \phantom{=
\frac{1}{4}\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}
\left(x_1^2 + x_2^2 - \frac{2}{9}\right)^2
dx_1 dx_2 = \frac{1}{135}}
\end{aligned}
$$
</div>

<div>
Proof:<br>
Change integration limits; finish integration
$$
\begin{aligned}
\mathbb{V}ar[f] &=
\mathbb{E}_{x} [\mathbb{E}_{x_1;x_2}[(\bar{g}(x) - g(x|x_1;x_2))^2] ] = \\ & =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
\left(\frac{1}{3} - \left(\frac{2}{3} - \frac{x_1}{2}\right)x_1 - \left(\frac{2}{3} - \frac{x_2}{2}\right)x_2\right)^2
dx_1 dx_2 dx = \\ & =
\frac{1}{4}\int\limits_0^1\int\limits_0^1\int\limits_0^1
\left(\left(x_1 - \frac{2}{3}\right)^2 + \left(x_2 - \frac{2}{3}\right)^2 - \frac{2}{9}\right)^2
dx_1 dx_2 dx = \\ & =
\frac{1}{4}\int\limits_{-2/3}^{1/3}\int\limits_{-2/3}^{1/3}
\left(x_1^2 + x_2^2 - \frac{2}{9}\right)^2
dx_1 dx_2 = \frac{1}{135}
\end{aligned}
$$
that gives us variation.
</div>


</div>

<div style="position:absolute; top:30px; left:900px;">

<div id="arrow_left" style="border-width: 1px; border-style:solid; float:left; height:32px;">
<svg width="8.7464mm" height="8.7464mm" version="1.1" viewBox="0 0 8.7464 8.7464" xmlns="http://www.w3.org/2000/svg" xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
<metadata>
<rdf:RDF>
<cc:Work rdf:about="">
<dc:format>image/svg+xml</dc:format>
<dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
<dc:title/>
</cc:Work>
</rdf:RDF>
</metadata>
<g transform="translate(-38.564 -29.908)">
<rect x="38.564" y="29.908" width="8.7464" height="8.7464" fill-opacity=".16425" opacity=".97" stroke-miterlimit="10.433" stroke-width="0"/>
<path d="m45.796 34.331h-5.8931" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m40.068 34.267 2.7141-2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m40.069 34.396 2.7141 2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
</g>
</svg>
</div>

<div id="arrow_right" style="border-width: 1px; border-style:solid; float:right; height:32px;">
<svg width="8.7464mm" height="8.7464mm" version="1.1" viewBox="0 0 8.7464 8.7464" xmlns="http://www.w3.org/2000/svg" xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
<metadata>
<rdf:RDF>
<cc:Work rdf:about="">
<dc:format>image/svg+xml</dc:format>
<dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
<dc:title/>
</cc:Work>
</rdf:RDF>
</metadata>
<g transform="translate(-38.564 -29.908)">
<rect transform="scale(-1,1)" x="-47.31" y="29.908" width="8.7464" height="8.7464" fill-opacity=".16425" opacity=".97" stroke-miterlimit="10.433" stroke-width="0"/>
<path d="m40.078 34.331h5.8931" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m45.806 34.267-2.7141-2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m45.805 34.396-2.7141 2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
</g>
</svg>
</div>

</div>

<style>
#arrow_left:hover{color:blue;}
#arrow_right:hover{color:blue;}
</style>

<script  type="text/javascript">
//var slides = ["slide_1", "slide_2", "slide_3"];

var container = document.getElementById("all_slides");
var menu_conn = document.createElement("div");
menu_conn.style.height = "90px";
menu_conn.id = "menu_div";
container.prepend(menu_conn);

// crutches
var slides = [];
var tmp = container.getElementsByTagName("div");
for (var i = 0; i < tmp.length; ++i)
  if (!tmp[i].id || tmp[i].id != "menu_div")
  {
    tmp[i].classList.add('slide_style');
    slides.push(tmp[i]);
  }


var left_btn_id = "arrow_left";
var right_btn_id = "arrow_right";
var current_slide = 0;
var menu = [];

function change_slide_to(new_slide_idx)
{
  menu[current_slide].style.borderWidth = "0px";
  var old_slide = slides[current_slide]; //document.getElementById(slides[current_slide]);
  current_slide = new_slide_idx;
  menu[current_slide].style.borderWidth = "2px";
  var new_slide = slides[current_slide]; //document.getElementById(slides[current_slide]);
  old_slide.style.display='none';
  new_slide.style.display='block';
}

function slide_left()
{
  var new_idx = current_slide - 1;
  if (new_idx < 0) {new_idx = 0;}
  change_slide_to(new_idx);
}

function slide_right()
{
  var new_idx = current_slide + 1;
  if (new_idx >= slides.length) {new_idx = slides.length - 1;}
  change_slide_to(new_idx);
}

function change(obj, is_correct)
{
//   alert(obj.parentNode.rowIndex);
    var rowId = obj.parentNode.rowIndex;
    var table = obj.parentNode.parentNode.parentNode;
    var rowsNotSelected = table.getElementsByTagName('tr');
    for (var row = 0; row < rowsNotSelected.length; row++)
    {
        rowsNotSelected[row].cells[0].style.backgroundColor = "white";
    }
    var rowSelected = table.getElementsByTagName('tr')[rowId];
    if (is_correct > 0)
    {
        rowSelected.cells[0].style.backgroundColor = "#66bb6aa9";
        menu[current_slide].style.backgroundColor = "#66bb6aa9";
    }
    else
    {
        rowSelected.cells[0].style.backgroundColor = "#ff3a3981";
        menu[current_slide].style.backgroundColor = "#ff3a3981";
    }
}

function make_callback(obj, is_correct)
{
  return function() { change(obj, is_correct); }
}

function change_callback(new_idx)
{
  return function() { change_slide_to(new_idx); }
}

document.getElementById(left_btn_id).addEventListener("click", slide_left);
document.getElementById(right_btn_id).addEventListener("click", slide_right);
slides[current_slide].style.display='block'; //document.getElementById(slides[current_slide]).style.display='block';

// create upper menu
upper_menu = document.getElementById("menu_div");

var tbl      = document.createElement("table");
var tbl_body = document.createElement("tbody");
var tbl_row  = document.createElement("tr");
for (idx = 0; idx < slides.length; idx++)
{
    var tbl_cell = document.createElement("td");
    var cell_text = document.createTextNode(idx+1);
    tbl_cell.appendChild(cell_text);
    tbl_cell.onclick = change_callback(idx);
    tbl_row.appendChild(tbl_cell);
    menu.push(tbl_cell);
    tbl_cell.style.borderWidth = "0px";

    var slide = slides[idx]; //document.getElementById(slides[idx]);
    var all_tables = slide.getElementsByTagName("table");
    for (t_i = 0; t_i < all_tables.length; t_i++)
    {
      var table = all_tables[t_i];
      if (!table.classList.contains("question_style"))
        continue;
      var rows = table.getElementsByTagName('tr');
      for (r_i = 0; r_i < rows.length; r_i++)
      {
        var question_cell = rows[r_i].cells[0];
        question_cell.classList.add("highlight");
        if (question_cell.classList.contains("ok"))
        {
          question_cell.onclick = make_callback(question_cell, 1);
        } else {
          question_cell.onclick = make_callback(question_cell, 0);
        }


        var cell = rows[r_i].insertCell(0);
        cell.width = "50px";
      }
    }
}
tbl_body.appendChild(tbl_row);
tbl.appendChild(tbl_body);
upper_menu.appendChild(tbl);
tbl.classList.add('menu_style');
menu[current_slide].style.borderWidth = "2px";

</script>

<style>
    .slide_style {
      max-width:750px;
      display:none;
      font: 14pt/18pt sans-serif;
      position: static;
      top: 80px;
      left: 0px;
    }

    .question_style {
        width:600px;
        font: 16pt/14pt sans-serif bold;
        text-align:left;
        cursor: default;
    }
    .question_style td{
        padding:7px;
        height: 50px;
        border:#4e95f4 0px solid;
        text-align:left;
        font: 13pt/16pt sans-serif;
    }
    .highlight:hover{
        background-color: #00000019
    }
    .menu_style {
        height:50px;
        font: 16pt/14pt sans-serif bold;
        text-align:left;
        cursor: default;
    }
    .menu_style td{
        width:50px;
        padding:7px;
        border:#787878ff solid;
        text-align:center;
        font: 16pt/14pt sans-serif;
        color: #606060ff;
    }
</style>
# Out:
# <script src='https://www.gstatic.com/external_hosted/mathjax/latest/MathJax.js?config=default'></script>
#
# <div id="all_slides">
#
# <div>
# <list>
# <li> Constant model
# </list>
# <br>
# The mean trained model is
# $$
# \bar{g}(x) =
# \int\limits_0^1\int\limits_0^1
# (2/3 - x_1/2) x_1 + (2/3 - x_2/2) x_2
# dx_1 dx_2 = \frac{1}{3}
# $$
# Expected squared bias is
# $$
# \mathbb{B}ias^2[f] = \mathbb{E}_x [(f(x) - \bar{g}(x))^2] = \frac{2}{135} \approx 0.0148
# $$
# Expected variance is
# $$
# \mathbb{V}ar[f] =
# \mathbb{E}_{x} [\mathbb{E}_{x_1;x_2}[(\bar{g}(x) - g(x|x_1;x_2))^2] ] =
# \frac{1}{135} \approx 0.0074
# $$
# It is easy to check that
# $$
# \mathbb{V}ar[f] + \mathbb{B}ias^2[f] = \frac{1}{45}
# \approx 0.022
# $$
# as it should be according to bias-variance decomposition.
# </div>
#
# <div>
# Proof:<br>
# From previous results write expressio for "mean model"
# $$
# \begin{aligned}
# \bar{g}(x) &=
# \int\limits_0^1\int\limits_0^1
# (2/3 - x_1/2) x_1 + (2/3 - x_2/2) x_2
# ...

# %%
#@title Bias and variance for linear model

# %%html
<script src='https://www.gstatic.com/external_hosted/mathjax/latest/MathJax.js?config=default'></script>

<div id="all_slides">

<div>
<list>
<li> Linear model
</list>
<br>
The mean trained model is
$$
\bar{g}(x) = \frac{x}{3} + \frac{1}{4}
$$
Expected squared bias is
$$
\mathbb{B}ias^2[f] = \mathbb{E}_x [(f(x) - \bar{g}(x))^2] = \frac{1}{80} \approx 0.0125
$$
The expected variance is
$$
\mathbb{V}ar[f] =
\mathbb{E}_{x} [\mathbb{E}_{x_1;x_2}[(\bar{g}(x) - g(x|x_1;x_2))^2] ] =
\frac{1}{48} \approx 0.02
$$
It is easy to check that
$$
\mathbb{V}ar[f] + \mathbb{B}ias^2[f] =
\frac{1}{30} \approx 0.03
$$
as it should be according to bias-variance decomposition.
</div>

<div>
Proof:<br>
From previous results we know that for
$$
f(x) = a - (x-b)^2
$$
we can write \(g(x|x_1;x_2)\) as
$$
g(x|x_1;x_2) = f(x) + (x-x_1)(x-x_2).
$$
One may double-check this by
<ul>
<li> expanding to see that the function is Linear
<li> substituting \(x = x_1\) and \(x = x_2\) to see that it passes through \((x_1;f(x_1))\) and \((x_1;f(x_1))\)
</ul>
</div>

<div>
Proof:<br>
Thus mean trained model is
$$
\begin{aligned}
\bar{g}(x) &=
\int\limits_0^1\int\limits_0^1
f(x) + (x-x_1)(x-x_2)
dx_1 dx_2 = \\ & \phantom{=
f(x) +
\int\limits_0^1(x-x_1)dx_1
\int\limits_0^1(x-x_2)dx_2 =} \\ & \phantom{=
f(x) + (x - 1/2)^2 = \frac{x}{3} + \frac{1}{4}}
\end{aligned}
$$
</div>

<div>
Proof:<br>
Rearrange integrals
$$
\begin{aligned}
\bar{g}(x) &=
\int\limits_0^1\int\limits_0^1
f(x) + (x-x_1)(x-x_2)
dx_1 dx_2 = \\ & =
f(x) +
\int\limits_0^1(x-x_1)dx_1
\int\limits_0^1(x-x_2)dx_2 = \\ & \phantom{=
f(x) + (x - 1/2)^2 = \frac{x}{3} + \frac{1}{4}}
\end{aligned}
$$
</div>

<div>
Proof:<br>
Integrate
$$
\begin{aligned}
\bar{g}(x) &=
\int\limits_0^1\int\limits_0^1
f(x) + (x-x_1)(x-x_2)
dx_1 dx_2 = \\ & =
f(x) +
\int\limits_0^1(x-x_1)dx_1
\int\limits_0^1(x-x_2)dx_2 = \\ & =
f(x) + (x - 1/2)^2 = \frac{x}{3} + \frac{1}{4}
\end{aligned}
$$
</div>

<div>
Proof:<br>
Now we can write bias squared as
$$
\begin{aligned}
\mathbb{B}ias^2[f] &=
\mathbb{E}_x [(f(x) - \bar{g}(x))^2] =
\int_0^1 (x - 1/2)^4 dx = \\ & \phantom{=
\int_{-1/2}^{1/2} x^4 dx = \frac{1}{80} \approx 0.0125}
\end{aligned}
$$
</div>

<div>
Proof:<br>
And perform integration
$$
\begin{aligned}
\mathbb{B}ias^2[f] &=
\mathbb{E}_x [(f(x) - \bar{g}(x))^2] =
\int_0^1 (x - 1/2)^4 dx = \\ & =
\int_{-1/2}^{1/2} x^4 dx = \frac{1}{80}
\end{aligned}
$$
</div>

<div>
Proof:<br>
Write definition of variance
$$
\begin{aligned}
\mathbb{V}ar[f] &=
\mathbb{E}_{x} [\mathbb{E}_{x_1;x_2}[(\bar{g}(x) - g(x|x_1;x_2))^2] ] = \\ & \phantom{=
\int\limits_0^1\int\limits_0^1\int\limits_0^1
\left((x-1/2)^2 - (x_1 - x)(x_2 - x)\right)^2
dx_1 dx_2 dx =} \\ & \phantom{=
\int\limits_0^1\int\limits_{-x}^{1-x}\int\limits_{-x}^{1-x}
\left((x-1/2)^2 - x_1 x_2 \right)^2
dx_1 dx_2 dx =} \\ & \phantom{=
\int\limits_{-1/2}^{1/2}\int\limits_{-1/2-x}^{1/2-x}\int\limits_{-1/2-x}^{1/2-x}
\left(x^2 - x_1 x_2\right)^2
dx_1 dx_2 dx =} \\ & \phantom{=
\int\limits_{-1/2}^{1/2}\int\limits_{-1/2-x}^{1/2-x}\int\limits_{-1/2-x}^{1/2-x}
(x^4 - 2 x^2 x_1 x_2 + x_1^2 x_2^2)
dx_1 dx_2 dx =} \\ & \phantom{=
\int\limits_{-1/2}^{1/2}
\frac{1}{144}+\frac{x^2}{6}
dx = \frac{1}{48}}
\end{aligned}
$$
</div>

<div>
Proof:<br>
Substitute functions
$$
\begin{aligned}
\mathbb{V}ar[f] &=
\mathbb{E}_{x} [\mathbb{E}_{x_1;x_2}[(\bar{g}(x) - g(x|x_1;x_2))^2] ] = \\ & =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
\left((x-1/2)^2 - (x_1 - x)(x_2 - x)\right)^2
dx_1 dx_2 dx = \\ & \phantom{=
\int\limits_0^1\int\limits_{-x}^{1-x}\int\limits_{-x}^{1-x}
\left((x-1/2)^2 - x_1 x_2 \right)^2
dx_1 dx_2 dx =} \\ & \phantom{=
\int\limits_{-1/2}^{1/2}\int\limits_{-1/2-x}^{1/2-x}\int\limits_{-1/2-x}^{1/2-x}
\left(x^2 - x_1 x_2\right)^2
dx_1 dx_2 dx =} \\ & \phantom{=
\int\limits_{-1/2}^{1/2}\int\limits_{-1/2-x}^{1/2-x}\int\limits_{-1/2-x}^{1/2-x}
(x^4 - 2 x^2 x_1 x_2 + x_1^2 x_2^2)
dx_1 dx_2 dx =} \\ & \phantom{=
\int\limits_{-1/2}^{1/2}
\frac{1}{144}+\frac{x^2}{6}
dx = \frac{1}{48}}
\end{aligned}
$$
</div>

<div>
Proof:<br>
Change limits for integrals with \(x_1\) and \(x_2\)
$$
\begin{aligned}
\mathbb{V}ar[f] &=
\mathbb{E}_{x} [\mathbb{E}_{x_1;x_2}[(\bar{g}(x) - g(x|x_1;x_2))^2] ] = \\ & =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
\left((x-1/2)^2 - (x_1 - x)(x_2 - x)\right)^2
dx_1 dx_2 dx = \\ & =
\int\limits_0^1\int\limits_{-x}^{1-x}\int\limits_{-x}^{1-x}
\left((x-1/2)^2 - x_1 x_2 \right)^2
dx_1 dx_2 dx = \\ & \phantom{=
\int\limits_{-1/2}^{1/2}\int\limits_{-1/2-x}^{1/2-x}\int\limits_{-1/2-x}^{1/2-x}
\left(x^2 - x_1 x_2\right)^2
dx_1 dx_2 dx =} \\ & \phantom{=
\int\limits_{-1/2}^{1/2}\int\limits_{-1/2-x}^{1/2-x}\int\limits_{-1/2-x}^{1/2-x}
(x^4 - 2 x^2 x_1 x_2 + x_1^2 x_2^2)
dx_1 dx_2 dx =} \\ & \phantom{=
\int\limits_{-1/2}^{1/2}
\frac{1}{144}+\frac{x^2}{6}
dx = \frac{1}{48}}
\end{aligned}
$$
</div>

<div>
Proof:<br>
Change limits for integral with \(x\)
$$
\begin{aligned}
\mathbb{V}ar[f] &=
\mathbb{E}_{x} [\mathbb{E}_{x_1;x_2}[(\bar{g}(x) - g(x|x_1;x_2))^2] ] = \\ & =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
\left((x-1/2)^2 - (x_1 - x)(x_2 - x)\right)^2
dx_1 dx_2 dx = \\ & =
\int\limits_0^1\int\limits_{-x}^{1-x}\int\limits_{-x}^{1-x}
\left((x-1/2)^2 - x_1 x_2 \right)^2
dx_1 dx_2 dx = \\ & =
\int\limits_{-1/2}^{1/2}\int\limits_{-1/2-x}^{1/2-x}\int\limits_{-1/2-x}^{1/2-x}
\left(x^2 - x_1 x_2\right)^2
dx_1 dx_2 dx = \\ & \phantom{=
\int\limits_{-1/2}^{1/2}\int\limits_{-1/2-x}^{1/2-x}\int\limits_{-1/2-x}^{1/2-x}
(x^4 - 2 x^2 x_1 x_2 + x_1^2 x_2^2)
dx_1 dx_2 dx =} \\ & \phantom{=
\int\limits_{-1/2}^{1/2}
\frac{1}{144}+\frac{x^2}{6}
dx = \frac{1}{48}}
\end{aligned}
$$
</div>

<div>
Proof:<br>
Expand
$$
\begin{aligned}
\mathbb{V}ar[f] &=
\mathbb{E}_{x} [\mathbb{E}_{x_1;x_2}[(\bar{g}(x) - g(x|x_1;x_2))^2] ] = \\ & =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
\left((x-1/2)^2 - (x_1 - x)(x_2 - x)\right)^2
dx_1 dx_2 dx = \\ & =
\int\limits_0^1\int\limits_{-x}^{1-x}\int\limits_{-x}^{1-x}
\left((x-1/2)^2 - x_1 x_2 \right)^2
dx_1 dx_2 dx = \\ & =
\int\limits_{-1/2}^{1/2}\int\limits_{-1/2-x}^{1/2-x}\int\limits_{-1/2-x}^{1/2-x}
\left(x^2 - x_1 x_2\right)^2
dx_1 dx_2 dx = \\ & =
\int\limits_{-1/2}^{1/2}\int\limits_{-1/2-x}^{1/2-x}\int\limits_{-1/2-x}^{1/2-x}
(x^4 - 2 x^2 x_1 x_2 + x_1^2 x_2^2)
dx_1 dx_2 dx = \\ & \phantom{=
\int\limits_{-1/2}^{1/2}
\frac{1}{144}+\frac{x^2}{6}
dx = \frac{1}{48}}
\end{aligned}
$$
</div>

<div>
Proof:<br>
Integrate
$$
\begin{aligned}
\mathbb{V}ar[f] &=
\mathbb{E}_{x} [\mathbb{E}_{x_1;x_2}[(\bar{g}(x) - g(x|x_1;x_2))^2] ] = \\ & =
\int\limits_0^1\int\limits_0^1\int\limits_0^1
\left((x-1/2)^2 - (x_1 - x)(x_2 - x)\right)^2
dx_1 dx_2 dx = \\ & =
\int\limits_0^1\int\limits_{-x}^{1-x}\int\limits_{-x}^{1-x}
\left((x-1/2)^2 - x_1 x_2 \right)^2
dx_1 dx_2 dx = \\ & =
\int\limits_{-1/2}^{1/2}\int\limits_{-1/2-x}^{1/2-x}\int\limits_{-1/2-x}^{1/2-x}
\left(x^2 - x_1 x_2\right)^2
dx_1 dx_2 dx = \\ & =
\int\limits_{-1/2}^{1/2}\int\limits_{-1/2-x}^{1/2-x}\int\limits_{-1/2-x}^{1/2-x}
(x^4 - 2 x^2 x_1 x_2 + x_1^2 x_2^2)
dx_1 dx_2 dx = \\ & =
\int\limits_{-1/2}^{1/2}
\frac{1}{144}+\frac{x^2}{6}
dx = \frac{1}{48}
\end{aligned}
$$
</div>

</div>

<div style="position:absolute; top:30px; left:900px;">

<div id="arrow_left" style="border-width: 1px; border-style:solid; float:left; height:32px;">
<svg width="8.7464mm" height="8.7464mm" version="1.1" viewBox="0 0 8.7464 8.7464" xmlns="http://www.w3.org/2000/svg" xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
<metadata>
<rdf:RDF>
<cc:Work rdf:about="">
<dc:format>image/svg+xml</dc:format>
<dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
<dc:title/>
</cc:Work>
</rdf:RDF>
</metadata>
<g transform="translate(-38.564 -29.908)">
<rect x="38.564" y="29.908" width="8.7464" height="8.7464" fill-opacity=".16425" opacity=".97" stroke-miterlimit="10.433" stroke-width="0"/>
<path d="m45.796 34.331h-5.8931" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m40.068 34.267 2.7141-2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m40.069 34.396 2.7141 2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
</g>
</svg>
</div>

<div id="arrow_right" style="border-width: 1px; border-style:solid; float:right; height:32px;">
<svg width="8.7464mm" height="8.7464mm" version="1.1" viewBox="0 0 8.7464 8.7464" xmlns="http://www.w3.org/2000/svg" xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
<metadata>
<rdf:RDF>
<cc:Work rdf:about="">
<dc:format>image/svg+xml</dc:format>
<dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
<dc:title/>
</cc:Work>
</rdf:RDF>
</metadata>
<g transform="translate(-38.564 -29.908)">
<rect transform="scale(-1,1)" x="-47.31" y="29.908" width="8.7464" height="8.7464" fill-opacity=".16425" opacity=".97" stroke-miterlimit="10.433" stroke-width="0"/>
<path d="m40.078 34.331h5.8931" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m45.806 34.267-2.7141-2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
<path d="m45.805 34.396-2.7141 2.4238" fill="none" stroke="#fff" stroke-opacity=".98068" stroke-width=".5"/>
</g>
</svg>
</div>

</div>

<style>
#arrow_left:hover{color:blue;}
#arrow_right:hover{color:blue;}
</style>

<script  type="text/javascript">
//var slides = ["slide_1", "slide_2", "slide_3"];

var container = document.getElementById("all_slides");
var menu_conn = document.createElement("div");
menu_conn.style.height = "90px";
menu_conn.id = "menu_div";
container.prepend(menu_conn);

// crutches
var slides = [];
var tmp = container.getElementsByTagName("div");
for (var i = 0; i < tmp.length; ++i)
  if (!tmp[i].id || tmp[i].id != "menu_div")
  {
    tmp[i].classList.add('slide_style');
    slides.push(tmp[i]);
  }


var left_btn_id = "arrow_left";
var right_btn_id = "arrow_right";
var current_slide = 0;
var menu = [];

function change_slide_to(new_slide_idx)
{
  menu[current_slide].style.borderWidth = "0px";
  var old_slide = slides[current_slide]; //document.getElementById(slides[current_slide]);
  current_slide = new_slide_idx;
  menu[current_slide].style.borderWidth = "2px";
  var new_slide = slides[current_slide]; //document.getElementById(slides[current_slide]);
  old_slide.style.display='none';
  new_slide.style.display='block';
}

function slide_left()
{
  var new_idx = current_slide - 1;
  if (new_idx < 0) {new_idx = 0;}
  change_slide_to(new_idx);
}

function slide_right()
{
  var new_idx = current_slide + 1;
  if (new_idx >= slides.length) {new_idx = slides.length - 1;}
  change_slide_to(new_idx);
}

function change(obj, is_correct)
{
//   alert(obj.parentNode.rowIndex);
    var rowId = obj.parentNode.rowIndex;
    var table = obj.parentNode.parentNode.parentNode;
    var rowsNotSelected = table.getElementsByTagName('tr');
    for (var row = 0; row < rowsNotSelected.length; row++)
    {
        rowsNotSelected[row].cells[0].style.backgroundColor = "white";
    }
    var rowSelected = table.getElementsByTagName('tr')[rowId];
    if (is_correct > 0)
    {
        rowSelected.cells[0].style.backgroundColor = "#66bb6aa9";
        menu[current_slide].style.backgroundColor = "#66bb6aa9";
    }
    else
    {
        rowSelected.cells[0].style.backgroundColor = "#ff3a3981";
        menu[current_slide].style.backgroundColor = "#ff3a3981";
    }
}

function make_callback(obj, is_correct)
{
  return function() { change(obj, is_correct); }
}

function change_callback(new_idx)
{
  return function() { change_slide_to(new_idx); }
}

document.getElementById(left_btn_id).addEventListener("click", slide_left);
document.getElementById(right_btn_id).addEventListener("click", slide_right);
slides[current_slide].style.display='block'; //document.getElementById(slides[current_slide]).style.display='block';

// create upper menu
upper_menu = document.getElementById("menu_div");

var tbl      = document.createElement("table");
var tbl_body = document.createElement("tbody");
var tbl_row  = document.createElement("tr");
for (idx = 0; idx < slides.length; idx++)
{
    var tbl_cell = document.createElement("td");
    var cell_text = document.createTextNode(idx+1);
    tbl_cell.appendChild(cell_text);
    tbl_cell.onclick = change_callback(idx);
    tbl_row.appendChild(tbl_cell);
    menu.push(tbl_cell);
    tbl_cell.style.borderWidth = "0px";

    var slide = slides[idx]; //document.getElementById(slides[idx]);
    var all_tables = slide.getElementsByTagName("table");
    for (t_i = 0; t_i < all_tables.length; t_i++)
    {
      var table = all_tables[t_i];
      if (!table.classList.contains("question_style"))
        continue;
      var rows = table.getElementsByTagName('tr');
      for (r_i = 0; r_i < rows.length; r_i++)
      {
        var question_cell = rows[r_i].cells[0];
        question_cell.classList.add("highlight");
        if (question_cell.classList.contains("ok"))
        {
          question_cell.onclick = make_callback(question_cell, 1);
        } else {
          question_cell.onclick = make_callback(question_cell, 0);
        }


        var cell = rows[r_i].insertCell(0);
        cell.width = "50px";
      }
    }
}
tbl_body.appendChild(tbl_row);
tbl.appendChild(tbl_body);
upper_menu.appendChild(tbl);
tbl.classList.add('menu_style');
menu[current_slide].style.borderWidth = "2px";

</script>

<style>
    .slide_style {
      max-width:750px;
      display:none;
      font: 14pt/18pt sans-serif;
      position: static;
      top: 80px;
      left: 0px;
    }

    .question_style {
        width:600px;
        font: 16pt/14pt sans-serif bold;
        text-align:left;
        cursor: default;
    }
    .question_style td{
        padding:7px;
        height: 50px;
        border:#4e95f4 0px solid;
        text-align:left;
        font: 13pt/16pt sans-serif;
    }
    .highlight:hover{
        background-color: #00000019
    }
    .menu_style {
        height:50px;
        font: 16pt/14pt sans-serif bold;
        text-align:left;
        cursor: default;
    }
    .menu_style td{
        width:50px;
        padding:7px;
        border:#787878ff solid;
        text-align:center;
        font: 16pt/14pt sans-serif;
        color: #606060ff;
    }
</style>
# Out:
# <script src='https://www.gstatic.com/external_hosted/mathjax/latest/MathJax.js?config=default'></script>
#
# <div id="all_slides">
#
# <div>
# <list>
# <li> Linear model
# </list>
# <br>
# The mean trained model is
# $$
# \bar{g}(x) = \frac{x}{3} + \frac{1}{4}
# $$
# Expected squared bias is
# $$
# \mathbb{B}ias^2[f] = \mathbb{E}_x [(f(x) - \bar{g}(x))^2] = \frac{1}{80} \approx 0.0125
# $$
# The expected variance is
# $$
# \mathbb{V}ar[f] =
# \mathbb{E}_{x} [\mathbb{E}_{x_1;x_2}[(\bar{g}(x) - g(x|x_1;x_2))^2] ] =
# \frac{1}{48} \approx 0.02
# $$
# It is easy to check that
# $$
# \mathbb{V}ar[f] + \mathbb{B}ias^2[f] =
# \frac{1}{30} \approx 0.03
# $$
# as it should be according to bias-variance decomposition.
# </div>
#
# <div>
# Proof:<br>
# From previous results we know that for
# $$
# f(x) = a - (x-b)^2
# $$
# we can write \(g(x|x_1;x_2)\) as
# $$
# g(x|x_1;x_2) = f(x) + (x-x_1)(x-x_2).
# $$
# One may double-check this by
# <ul>
# <li> expanding to see that the function is Linear
# ...

# %%
#@title bias and variance

# %%html


<svg
   xmlns:ns0="http://www.iki.fi/pav/software/textext/"
   xmlns:dc="http://purl.org/dc/elements/1.1/"
   xmlns:cc="http://creativecommons.org/ns#"
   xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
   xmlns:svg="http://www.w3.org/2000/svg"
   xmlns="http://www.w3.org/2000/svg"
   xmlns:sodipodi="http://sodipodi.sourceforge.net/DTD/sodipodi-0.dtd"
   xmlns:inkscape="http://www.inkscape.org/namespaces/inkscape"
   width="180mm"
   height="150mm"
   viewBox="0 0 124.9906 89.426496"
   version="1.1"
   id="svg8"
   inkscape:export-filename="D:\nice1.png"
   inkscape:export-xdpi="101.87865"
   inkscape:export-ydpi="101.87865"
   inkscape:version="0.92.2 (5c3e80d, 2017-08-06)"
   sodipodi:docname="lecrt_1.svg">
  <sodipodi:namedview
     id="base"
     pagecolor="#ffffff"
     bordercolor="#666666"
     borderopacity="1.0"
     inkscape:pageopacity="0.0"
     inkscape:pageshadow="2"
     inkscape:zoom="1.8101934"
     inkscape:cx="142.43739"
     inkscape:cy="161.11081"
     inkscape:document-units="mm"
     inkscape:current-layer="g2530"
     showgrid="false"
     inkscape:window-width="1920"
     inkscape:window-height="1017"
     inkscape:window-x="1912"
     inkscape:window-y="-8"
     inkscape:window-maximized="1"
     fit-margin-top="0"
     fit-margin-left="0"
     fit-margin-right="0"
     fit-margin-bottom="0" />
  <defs
     id="defs2">
    <marker
       inkscape:stockid="Arrow1Mstart"
       orient="auto"
       refY="0"
       refX="0"
       id="marker19600"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         inkscape:connector-curvature="0"
         id="path19598"
         d="M 0,0 5,-5 -12.5,0 5,5 Z"
         style="fill:#000000;fill-opacity:0.42512081;fill-rule:evenodd;stroke:#000000;stroke-width:1.00000003pt;stroke-opacity:0.42512081"
         transform="matrix(0.4,0,0,0.4,4,0)" />
    </marker>
    <marker
       inkscape:isstock="true"
       style="overflow:visible"
       id="marker19404"
       refX="0"
       refY="0"
       orient="auto"
       inkscape:stockid="Arrow1Mend">
      <path
         transform="matrix(-0.4,0,0,-0.4,-4,0)"
         style="fill:#000000;fill-opacity:1;fill-rule:evenodd;stroke:#000000;stroke-width:1.00000003pt;stroke-opacity:1"
         d="M 0,0 5,-5 -12.5,0 5,5 Z"
         id="path19402"
         inkscape:connector-curvature="0" />
    </marker>
    <marker
       inkscape:isstock="true"
       style="overflow:visible"
       id="marker19394"
       refX="0"
       refY="0"
       orient="auto"
       inkscape:stockid="Arrow1Mend">
      <path
         transform="matrix(-0.4,0,0,-0.4,-4,0)"
         style="fill:#000000;fill-opacity:0.57971012;fill-rule:evenodd;stroke:#000000;stroke-width:1.00000003pt;stroke-opacity:0.57971012"
         d="M 0,0 5,-5 -12.5,0 5,5 Z"
         id="path19392"
         inkscape:connector-curvature="0" />
    </marker>
    <marker
       inkscape:stockid="Arrow2Send"
       orient="auto"
       refY="0"
       refX="0"
       id="marker19208"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         inkscape:connector-curvature="0"
         id="path19206"
         style="fill:#000000;fill-opacity:1;fill-rule:evenodd;stroke:#000000;stroke-width:0.625;stroke-linejoin:round;stroke-opacity:1"
         d="M 8.7185878,4.0337352 -2.2072895,0.01601326 8.7185884,-4.0017078 c -1.7454984,2.3720609 -1.7354408,5.6174519 -6e-7,8.035443 z"
         transform="matrix(-0.3,0,0,-0.3,0.69,0)" />
    </marker>
    <marker
       inkscape:stockid="Arrow1Mend"
       orient="auto"
       refY="0"
       refX="0"
       id="marker15374"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         inkscape:connector-curvature="0"
         id="path15372"
         d="M 0,0 5,-5 -12.5,0 5,5 Z"
         style="fill:#006000;fill-opacity:0.46376815;fill-rule:evenodd;stroke:#006000;stroke-width:1.00000003pt;stroke-opacity:0.46376815"
         transform="matrix(-0.4,0,0,-0.4,-4,0)" />
    </marker>
    <marker
       inkscape:stockid="Arrow1Mend"
       orient="auto"
       refY="0"
       refX="0"
       id="marker15364"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         inkscape:connector-curvature="0"
         id="path15362"
         d="M 0,0 5,-5 -12.5,0 5,5 Z"
         style="fill:#009900;fill-opacity:0.46376815;fill-rule:evenodd;stroke:#009900;stroke-width:1.00000003pt;stroke-opacity:0.46376815"
         transform="matrix(-0.4,0,0,-0.4,-4,0)" />
    </marker>
    <marker
       inkscape:stockid="Arrow1Mend"
       orient="auto"
       refY="0"
       refX="0"
       id="marker15001"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         inkscape:connector-curvature="0"
         id="path14999"
         d="M 0,0 5,-5 -12.5,0 5,5 Z"
         style="fill:#000000;fill-opacity:0.42512081;fill-rule:evenodd;stroke:#000000;stroke-width:1.00000003pt;stroke-opacity:0.42512081"
         transform="matrix(-0.4,0,0,-0.4,-4,0)" />
    </marker>
    <marker
       inkscape:stockid="Arrow1Mend"
       orient="auto"
       refY="0"
       refX="0"
       id="marker14991"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         inkscape:connector-curvature="0"
         id="path14989"
         d="M 0,0 5,-5 -12.5,0 5,5 Z"
         style="fill:#000000;fill-opacity:0.51690823;fill-rule:evenodd;stroke:#000000;stroke-width:1.00000003pt;stroke-opacity:0.51690823"
         transform="matrix(-0.4,0,0,-0.4,-4,0)" />
    </marker>
    <marker
       inkscape:stockid="Arrow1Mend"
       orient="auto"
       refY="0"
       refX="0"
       id="marker7628"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         inkscape:connector-curvature="0"
         id="path7626"
         d="M 0,0 5,-5 -12.5,0 5,5 Z"
         style="fill:#000000;fill-opacity:0.40096621;fill-rule:evenodd;stroke:#000000;stroke-width:1.00000003pt;stroke-opacity:0.40096621"
         transform="matrix(-0.4,0,0,-0.4,-4,0)" />
    </marker>
    <marker
       inkscape:stockid="Arrow1Mend"
       orient="auto"
       refY="0"
       refX="0"
       id

         d="M 0,0 5,-5 -12.5,0 5,5 Z"
         id="path890-6-7-9"
         inkscape:connector-curvature="0" />
    </marker>
    <marker
       inkscape:isstock="true"
       style="overflow:visible"
       id="Arrow1Mend-49-1"
       refX="0"
       refY="0"
       orient="auto"
       inkscape:stockid="Arrow1Mend">
      <path
         inkscape:connector-curvature="0"
         transform="matrix(-0.4,0,0,-0.4,-4,0)"
         style="fill:#000000;fill-opacity:0.56521738;fill-rule:evenodd;stroke:#000000;stroke-width:1.00000003pt;stroke-opacity:0.52173911"
         d="M 0,0 5,-5 -12.5,0 5,5 Z"
         id="path890-1-5" />
    </marker>
    <filter
       id="filter14967"
       style="color-interpolation-filters:sRGB"
       inkscape:menu-tooltip="Sharpen edges and boundaries within the object, force=0.15"
       inkscape:menu="Image Effects"
       inkscape:label="Sharpen">
      <feConvolveMatrix
         id="feConvolveMatrix14965"
         targetY="1"
         targetX="1"
         in="SourceGraphic"
         divisor="1"
         kernelMatrix="0 -0.15 0 -0.15 1.6 -0.15 0 -0.15 0"
         order="3 3" />
    </filter>
    <marker
       inkscape:stockid="Arrow1Mend"
       orient="auto"
       refY="0"
       refX="0"
       id="marker14991-0"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         inkscape:connector-curvature="0"
         id="path14989-0"
         d="M 0,0 5,-5 -12.5,0 5,5 Z"
         style="fill:#000000;fill-opacity:1;fill-rule:evenodd;stroke:#000000;stroke-width:1.00000003pt;stroke-opacity:1"
         transform="matrix(-0.4,0,0,-0.4,-4,0)" />
    </marker>
    <marker
       inkscape:stockid="Arrow1Mend"
       orient="auto"
       refY="0"
       refX="0"
       id="marker15384-0"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         inkscape:connector-curvature="0"
         id="path15382-0"
         d="M 0,0 5,-5 -12.5,0 5,5 Z"
         style="fill:#840000;fill-opacity:0.6714976;fill-rule:evenodd;stroke:#840000;stroke-width:1.00000003pt;stroke-opacity:0.6714976"
         transform="matrix(-0.4,0,0,-0.4,-4,0)" />
    </marker>
    <marker
       inkscape:stockid="Arrow1Mend"
       orient="auto"
       refY="0"
       refX="0"
       id="marker15364-5"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         inkscape:connector-curvature="0"
         id="path15362-5"
         d="M 0,0 5,-5 -12.5,0 5,5 Z"
         style="fill:#ff0000;fill-opacity:0.35748794;fill-rule:evenodd;stroke:#ff0000;stroke-width:1.00000003pt;stroke-opacity:0.35748794"
         transform="matrix(-0.4,0,0,-0.4,-4,0)" />
    </marker>
    <marker
       inkscape:stockid="Arrow1Mend"
       orient="auto"
       refY="0"
       refX="0"
       id="marker15374-3"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         inkscape:connector-curvature="0"
         id="path15372-9"
         d="M 0,0 5,-5 -12.5,0 5,5 Z"
         style="fill:#ff0000;fill-opacity:0.35748794;fill-rule:evenodd;stroke:#ff0000;stroke-width:1.00000003pt;stroke-opacity:0.35748794"
         transform="matrix(-0.4,0,0,-0.4,-4,0)" />
    </marker>
    <marker
       inkscape:stockid="Arrow1Mend"
       orient="auto"
       refY="0"
       refX="0"
       id="marker15001-9"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         inkscape:connector-curvature="0"
         id="path14999-0"
         d="M 0,0 5,-5 -12.5,0 5,5 Z"
         style="fill:#000000;fill-opacity:0.51690823;fill-rule:evenodd;stroke:#000000;stroke-width:1.00000003pt;stroke-opacity:0.51690823"
         transform="matrix(-0.4,0,0,-0.4,-4,0)" />
    </marker>
    <marker
       inkscape:stockid="Arrow1Mend"
       orient="auto"
       refY="0"
       refX="0"
       id="marker14991-2"
       style="overflow:visible"
       inkscape:isstock="true">
      <path
         inkscape:connector-curvature="0"
         id="path14989-4"
         d="M 0,0 5,-5 -12.5,0 5,5 Z"
         style="fill:#000000;fill-opacity:0.51690823;fill-rule:evenodd;stroke:#000000;stroke-width:1.00000003pt;stroke-opacity:0.51690823"
         transform="matrix(-0.4,0,0,-0.4,-4,0)" />
    </marker>
  </defs>
  <metadata
     id="metadata5">
    <rdf:RDF>
      <cc:Work
         rdf:about="">
        <dc:format>image/svg+xml</dc:format>
        <dc:type
           rdf:resource="http://purl.org/dc/dcmitype/StillImage" />
        <dc:title />
      </cc:Work>
    </rdf:RDF>
  </metadata>
  <g
     transform="translate(114.71725,-8.2601332)"
     id="layer1"
     inkscape:groupmode="layer"
     inkscape:label="Layer 1">
    <text
       id="text1426"
       y="42.149555"
       x="35.246281"
       style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;font-size:10.58333302px;line-height:1.25;font-family:Verdana;-inkscape-font-specification:Verdana;letter-spacing:0px;word-spacing:0px;fill:#000000;fill-opacity:1;stroke:none;stroke-width:0.26458332"
       xml:space="preserve"><tspan
         style="stroke-width:0.26458332"
         y="51.80505"
         x="35.246281"
         id="tspan1424"
         sodipodi:role="line" /></text>
    <text
       xml:space="preserve"
       style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;font-size:10.58333302px;line-height:1.25;font-family:Verdana;-inkscape-font-specification:Verdana;letter-spacing:0px;word-spacing:0px;fill:#000000;fill-opacity:1;stroke:none;stroke-width:0.26458332"
       x="76.906807"
       y="21.511925"
       id="text1476"><tspan
         sodipodi:role="line"
         id="tspan1474"
         x="76.906807"
         y="31.167419"
         style="stroke-width:0.26458332" /></text>
    <g
       style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;letter-spacing:normal;word-spacing:normal;text-anchor:start;fill:#000000;fill-opacity:1;fill-rule:evenodd;stroke:#000000;stroke-width:1.19880784;stroke-linecap:butt;stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:1"
       id="g1983"
       transform="matrix(1.2512431,0,0,-1.2512431,-160.51273,876.57255)"
       xml:space="preserve"
       stroke-miterlimit="10.433"
       font-style="normal"
       font-variant="normal"
       font-weight="normal"
       font-stretch="normal"
       font-size-adjust="none"
       letter-spacing="normal"
       word-spacing="normal"
       ns0:text="$p q$\n"
       ns0:preamble="default_packages.tex"><g
         ns0:preamble="default_packages.tex"
         ns0:text="$\\text{delete readjust}$\n"
         word-spacing="normal"
         letter-spacing="normal"
         font-size-adjust="none"
         font-stretch="normal"
         font-weight="normal"
         font-variant="normal"
         font-style="normal"
         stroke-miterlimit="10.433"
         xml:space="preserve"
         transform="matrix(1.5,0,0,-1.5,-165.9,1212.8325)"
         id="g2079"
         style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;letter-spacing:normal;word-spacing:normal;text-anchor:start;fill:#000000;fill-opacity:1;fill-rule:evenodd;stroke:#000000;stroke-linecap:butt;stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:1"><g
           id="g3320"
           transform="matrix(1.5,0,0,-1.5,-165.5925,1212.8325)"
           xml:space="preserve"
           stroke-miterlimit="10.433"
           font-style="normal"
           font-variant="normal"
           font-weight="normal"
           font-stretch="normal"
           font-size-adjust="none"
           letter-spacing="normal"
           word-spacing="normal"
           ns0:text="$delete readjust$\n"
           ns0:preamble="default_packages.tex"
           style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;letter-spacing:normal;word-spacing:normal;text-anchor:start;fill:#000000;fill-opacity:1;fill-rule:evenodd;stroke:#000000;stroke-linecap:butt;stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:1"><flowRoot
             xml:space="preserve"
             id="flowRoot5311"
             style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;font-size:40px;line-height:1.25;font-family:Verdana;-inkscape-font-specification:Verdana;letter-spacing:0px;word-spacing:0px;fill:#000000;fill-opacity:1;stroke:none"><flowRegion
               id="flowRegion5313"><rect
                 id="rect5315"
                 width="60"
                 height="76.428574"
                 x="78.928574"
                 y="457.16251" /></flowRegion><flowPara
               id="flowPara5317" /></flowRoot><path
             sodipodi:nodetypes="cccccc"
             inkscape:connector-curvature="0"
             id="path21850"
             d="m 232.85586,573.72586 c -11.04536,5.40663 -17.00766,5.11205 -21.44191,1.66136 -7.16093,-5.64292 -11.79372,-7.87132 -10.85073,-16.35399 1.37103,-13.97946 12.35634,-13.03128 20.66313,-12.61594 11.25788,0.62687 23.31564,7.33543 23.5186,14.74455 -0.0487,7.65726 -6.17888,9.41704 -11.88909,12.56402 z"
             style="fill:none;stroke:#000000;stroke-width:0.20068931;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:0.36231884;stroke-miterlimit:10.43299961;stroke-dasharray:none" /><g
             ns0:preamble="default_packages.tex"
             ns0:text="$f bias variance All functions Learnable functions$\n"
             word-spacing="normal"
             letter-spacing="normal"
             font-size-adjust="none"
             font-stretch="normal"
             font-weight="normal"
             font-variant="normal"
             font-style="normal"
             stroke-miterlimit="10.433"
             xml:space="preserve"
             transform="matrix(0.20006332,0,0,0.20006326,165.85422,418.79014)"
             id="g25067"
             style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;letter-spacing:normal;word-spacing:normal;text-anchor:start;fill:#000000;fill-opacity:1;fill-rule:evenodd;stroke:#000000;stroke-width:8.98821449;stroke-linecap:butt;stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:1"><path
               style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;letter-spacing:normal;word-spacing:normal;text-anchor:start;fill:#0069a0;fill-opacity:0.28985506;fill-rule:evenodd;stroke:none;stroke-width:0.4697544px;stroke-linecap:butt;stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:1"
stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:2.82296494, 0.47049415999999999;stroke-dashoffset:0;stroke-opacity:0.43961355"
               id="path22620-8-5-2"
               cx="302.77057"
               cy="-767.96289" /><g
               ns0:preamble="default_packages.tex"
               ns0:text="$\\{$\n"
               word-spacing="normal"
               letter-spacing="normal"
               font-size-adjust="none"
               font-stretch="normal"
               font-weight="normal"
               font-variant="normal"
               font-style="normal"
               stroke-miterlimit="10.433"
               xml:space="preserve"
               transform="matrix(1.5091633,0,0,-2.8406591,-20.080176,2733.8163)"
               id="g32469"
               style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;letter-spacing:normal;word-spacing:normal;text-anchor:start;fill:#000000;fill-opacity:0.50724637;fill-rule:evenodd;stroke:#000000;stroke-width:6.51159;stroke-linecap:butt;stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:0.69082121"><path
                 id="path32467"
                 d="m 151.53,713.25 v 0.04 l 0.01,0.04 v 0.04 l 0.01,0.04 0.01,0.04 0.01,0.05 0.01,0.04 0.01,0.04 0.02,0.05 0.02,0.04 0.02,0.05 0.02,0.04 0.03,0.04 0.03,0.04 0.03,0.05 0.04,0.04 0.04,0.04 0.04,0.04 0.05,0.04 0.05,0.03 0.05,0.04 0.06,0.03 0.06,0.03 0.06,0.03 0.07,0.03 0.07,0.02 0.08,0.03 0.08,0.02 h 0.04 l 0.05,0.01 0.04,0.01 0.05,0.01 h 0.04 l 0.05,0.01 h 0.05 l 0.05,0.01 c 0.05,0.01 0.09,0.05 0.09,0.11 0,0.11 -0.08,0.11 -0.19,0.11 -1,0 -1.9,-0.51 -1.91,-1.25 v -2.26 c 0,-0.39 0,-0.71 -0.4,-1.03 -0.35,-0.29 -0.73,-0.31 -0.95,-0.32 -0.05,-0.01 -0.09,-0.05 -0.09,-0.11 0,-0.1 0.06,-0.1 0.16,-0.11 0.66,-0.04 1.14,-0.4 1.25,-0.89 0.03,-0.1 0.03,-0.12 0.03,-0.48 v -1.97 c 0,-0.42 0,-0.73 0.48,-1.11 0.38,-0.3 1.04,-0.41 1.43,-0.41 0.11,0 0.19,0 0.19,0.11 0,0.1 -0.06,0.1 -0.16,0.11 -0.63,0.04 -1.12,0.36 -1.25,0.86 -0.03,0.09 -0.03,0.11 -0.03,0.47 v 2.09 c 0,0.45 -0.08,0.62 -0.4,0.94 -0.2,0.21 -0.49,0.31 -0.77,0.39 0.82,0.23 1.17,0.68 1.17,1.26 z"
                 inkscape:connector-curvature="0"
                 style="fill:#000000;fill-opacity:0.50724637;stroke:#000000;stroke-width:0;stroke-opacity:0.69082121" /></g><path
               style="fill:none;stroke:#000000;stroke-width:0.47049418;stroke-linecap:butt;stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:none;stroke-opacity:0.5362319"
               d="m 246.41264,732.03704 -33.86707,0.0324"
               id="path33607"
               inkscape:connector-curvature="0"
               sodipodi:nodetypes="cc" /><path
               style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;letter-spacing:normal;word-spacing:normal;text-anchor:start;fill:none;fill-opacity:1;fill-rule:evenodd;stroke:#000000;stroke-width:0.47049421;stroke-linecap:butt;stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:0.5362319"
               d="m 241.85041,704.02893 -30.1431,0.0324"
               id="path33607-3"
               inkscape:connector-curvature="0"
               sodipodi:nodetypes="cc" /><path
               sodipodi:nodetypes="cc"
               inkscape:connector-curvature="0"
               id="path35908"
               d="m 237.98076,721.20541 63.25538,45.72864"
               style="fill:#0069a0;stroke:#000000;stroke-width:0.64803915;stroke-linecap:butt;stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:none;stroke-opacity:0.42512077;marker-start:url(#marker19600);marker-end:url(#marker15001);fill-opacity:0.23188406" /><g
               ns0:preamble="default_packages.tex"
               ns0:text="$bias variance$\n"
               word-spacing="normal"
               letter-spacing="normal"
               font-size-adjust="none"
               font-stretch="normal"
               font-weight="normal"
               font-variant="normal"
               font-style="normal"
               stroke-miterlimit="10.433"
               xml:space="preserve"
               transform="matrix(1.5,0,0,1.5,-134.52536,-279.92002)"
               id="g1871"
               style="font-style:normal;font-variant:normal;font-weight:normal;font-stretch:normal;letter-spacing:normal;word-spacing:normal;text-anchor:start;fill:#000000;fill-opacity:1;fill-rule:evenodd;stroke:#000000;stroke-linecap:butt;stroke-linejoin:miter;stroke-miterlimit:10.43299961;stroke-dasharray:none;stroke-dashoffset:0;stroke-opacity:1
#    xmlns:dc="http://purl.org/dc/elements/1.1/"
#    xmlns:cc="http://creativecommons.org/ns#"
#    xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#    xmlns:svg="http://www.w3.org/2000/svg"
#    xmlns="http://www.w3.org/2000/svg"
#    xmlns:sodipodi="http://sodipodi.sourceforge.net/DTD/sodipodi-0.dtd"
#    xmlns:inkscape="http://www.inkscape.org/namespaces/inkscape"
#    width="180mm"
#    height="150mm"
#    viewBox="0 0 124.9906 89.426496"
#    version="1.1"
#    id="svg8"
#    inkscape:export-filename="D:\nice1.png"
#    inkscape:export-xdpi="101.87865"
#    inkscape:export-ydpi="101.87865"
#    inkscape:version="0.92.2 (5c3e80d, 2017-08-06)"
#    sodipodi:docname="lecrt_1.svg">
#   <sodipodi:namedview
#      id="base"
#      pagecolor="#ffffff"
#      bordercolor="#666666"
#      borderopacity="1.0"
#      inkscape:pageopacity="0.0"
#      inkscape:pageshadow="2"
#      inkscape:zoom="1.8101934"
# ...

# %% [markdown]
# #Lies, damned lies, and statistics

# %% [markdown]
# **"Lies, damned lies, and statistics"** is a phrase describing the persuasive power of numbers, particularly the use of statistics to bolster weak arguments. It is also sometimes colloquially used to doubt statistics used to prove an opponent's point.
#
# The phrase was popularized in the United States by Mark Twain (among others), who attributed it to the British prime minister Benjamin Disraeli:
# $$
# \def\q{\unicode{x201C}}
# \def\Q{\unicode{x201D}}
# \q There \,\,  are \,\, three \,\, kinds \,\,  of \,\, lies: \,\, lies, \,\, damn \,\, lies \,\, and \,\, statistics.\Q
# $$
#
#
# Few common "lies" of statistics include:
# * results inferred from unrepresentative (biased) samples.
#
# As an example consider recent fail of data collection and data analysis that overlooked Trump win in the USA presidential elections.
#
# Biased sample can be seen as **garbage in, garbage out (GIGO)** problem: unreliable ("bad") input data render erroneous results.
#
#
# The researcher may also deliberately choose only sample that support his claim (it's called **cherry picking** and **p-hacking**).
#
# * grouping mistakes (Simpson's paradox)
#
# <img src="https://raw.githubusercontent.com/fbeilstein/machine_learning/master/lecture_08_statistics/simpsons_paradox.gif" width="550px" />

# %%
#@title ##How statistics can be misleading - Mark Liddell (Video)

from IPython.display import YouTubeVideo
YouTubeVideo('sxYrzzy3cq8', width=600, height=400, start=286, end=379)

# %%
#@title Visualization code

import IPython
from google.colab import output

main_str = '''
  <script type="application/javascript">

    var active_pt = null;
    var all_pts = [];
    var classAbtn = [650, 100];
    var classBbtn = [650, 200];
    var ptR = 9.0;
    var params = null;
    var debug_txt = "";
    var bg_image = new Image();

    function is_close(pt1, pt2) {
      return   (pt1[0] - pt2[0])*(pt1[0] - pt2[0])
            +  (pt1[1] - pt2[1])*(pt1[1] - pt2[1])
            <= ptR*ptR;
    }

    function circ(ctx, pos, cls) {
      ctx.beginPath();
      ctx.arc(pos[0], pos[1], ptR, 0.0, 2.0 * Math.PI, 0);
      ctx.fillStyle = (cls == 0 ? 'rgba(200, 0, 0, 0.5)' : 'rgba(0, 0, 200, 0.5)');
      ctx.fill();
    }

    function in_rect(pos, rect) {
      if (pos[0] < rect[0] || pos[0] > (rect[0] + rect[2]))
        return false;
      if (pos[1] < rect[1] || pos[1] > (rect[1] + rect[3]))
        return false;
      return true;
    }

    function get_survivals() {
      var g1A = [0, 0];
      var g1B = [0, 0];
      var g2A = [0, 0];
      var g2B = [0, 0];
      all_pts.forEach(function (item, index) {
        if (in_rect(item, [0, 100, 200, 250]))
          g1A[item[2]] += 1;
        if (in_rect(item, [400, 100, 200, 250]))
          g1B[item[2]] += 1;
        if (in_rect(item, [0, 350, 200, 250]))
          g2A[item[2]] += 1;
        if (in_rect(item, [400, 350, 200, 250]))
          g2B[item[2]] += 1;
      });
        if (active_pt && in_rect(active_pt, [0, 100, 200, 250]))
          g1A[active_pt[2]] += 1;
        if (active_pt && in_rect(active_pt, [400, 100, 200, 250]))
          g1B[active_pt[2]] += 1;
        if (active_pt && in_rect(active_pt, [0, 350, 200, 250]))
          g2A[active_pt[2]] += 1;
        if (active_pt && in_rect(active_pt, [400, 350, 200, 250]))
          g2B[active_pt[2]] += 1;
      return [g1A[0]/(g1A[0]+g1A[1]),
              g1B[0]/(g1B[0]+g1B[1]),
              g2A[0]/(g2A[0]+g2A[1]),
              g2B[0]/(g2B[0]+g2B[1]),
              (g1A[0] + g2A[0])/(g1A[0]+g1A[1]+g2A[0]+g2A[1]),
              (g1B[0] + g2B[0])/(g1B[0]+g1B[1]+g2B[0]+g2B[1])];
    }

    function draw() {
      var canvas = document.getElementById('canvas');
      if (canvas.getContext) {
        var ctx = canvas.getContext('2d');

        ctx.clearRect(0, 0, canvas.width, canvas.height); // cleanup before start
        ctx.strokeRect(0, 0, 600, 600); // field
        ctx.strokeRect(0, 100, 200, 250);
        ctx.strokeRect(400, 100, 200, 250);
        ctx.strokeRect(0, 350, 200, 250);
        ctx.strokeRect(400, 350, 200, 250);


        ctx.font = '20px serif';
        ctx.fillStyle = 'black';
        ctx.fillText('Group 1', 50, 150);
        ctx.fillText('Group 2', 50, 400);
        ctx.fillText('Group 1', 450, 150);
        ctx.fillText('Group 2', 450, 400);
        ctx.fillText('Alive', 670, 105);
        ctx.fillText('Dead', 670, 206);
        ctx.fillText('Survival', 210, 200);
        ctx.fillText('Survival', 320, 200);
        ctx.fillText('Survival', 210, 450);
        ctx.fillText('Survival', 320, 450);

        var s = get_survivals();
        ctx.fillText((s[0]*100.0).toFixed(1) + '%', 210, 220);
        ctx.fillText((s[2]*100.0).toFixed(1) + '%', 210, 470);
        ctx.fillText((s[1]*100.0).toFixed(1) + '%', 320, 220);
        ctx.fillText((s[3]*100.0).toFixed(1) + '%', 320, 470);
        ctx.fillText('Hospital A, Survival:'+(s[4]*100.0).toFixed(1) + '%', 50, 50);
        ctx.fillText('Hospital B, Survival:'+(s[5]*100.0).toFixed(1) + '%', 350, 50);

        ctx.font = '40px serif';
        ctx.fillStyle = 'black';
        if (s[0] > s[1])
        	ctx.fillText('>', 290, 220);
        if (s[0] < s[1])
        	ctx.fillText('<', 290, 220);
        if (s[0] == s[1])
        	ctx.fillText('=', 290, 220);
        if (s[2] > s[3])
        	ctx.fillText('>', 290, 470);
        if (s[2] < s[3])
        	ctx.fillText('<', 290, 470);
        if (s[2] == s[3])
        	ctx.fillText('=', 290, 470);
        if (s[4] > s[5])
        	ctx.fillText('>', 290, 50);
        if (s[4] < s[5])
        	ctx.fillText('<', 290, 50);
        if (s[4] == s[5])
        	ctx.fillText('=', 290, 50);

        ctx.fillText(debug_txt, 200, 200);
        circ(ctx, classAbtn, 0);
        circ(ctx, classBbtn, 1);
        ctx.strokeRect(625, 75, 150, 50);
        ctx.strokeRect(625, 175, 150, 50);

        if (active_pt) {
          circ(ctx, [active_pt[0], active_pt[1]], active_pt[2]);
        }
        all_pts.forEach(function (item, index) {
          circ(ctx, [item[0], item[1]], item[2]);
        });

      }
    }

    var timer
    function init() {
      timer = setInterval(draw, 10);
    }

    function mdown_handle(evt) {
      x = evt.offsetX;
      y = evt.offsetY;
      if (is_close([x,y], classAbtn)) {
        active_pt = [x, y, 0]
      }
      if (is_close([x,y], classBbtn)) {
        active_pt = [x, y, 1]
      }
      idx = -1;
      all_pts.forEach(function (item, index) {
        if (is_close([x,y], [item[0], item[1]])) {
          idx = index;
        }
      });
      if (idx > -1) {
        active_pt = all_pts[idx];
        all_pts.splice(idx, 1);
      }
    }

    function mmove_handle(evt) {
      x = evt.offsetX;
      y = evt.offsetY;
      if (active_pt) {
        active_pt[0] = x;
        active_pt[1] = y;
      }
    }

    function mup_handle(evt) {
      x = evt.offsetX;
      y = evt.offsetY;
      if (!in_rect([x,y], [0, 100, 200, 500]) && !in_rect([x,y], [400, 100, 200, 500])) {
        active_pt = null;
      }
      if (active_pt) {
        all_pts.push(active_pt);
        active_pt = null;
      }
    }

  </script>
  <canvas id="canvas" width="800" height="600"
    onmousedown="mdown_handle(event)"
    onmousemove="mmove_handle(event)"
    onmouseup="mup_handle(event)"></canvas>
  <script> init();</script>
'''


display(IPython.display.HTML(main_str))
# Out:
#   <script type="application/javascript">
#
#     var active_pt = null;
#     var all_pts = [];
#     var classAbtn = [650, 100];
#     var classBbtn = [650, 200];
#     var ptR = 9.0;
#     var params = null;
#     var debug_txt = "";
#     var bg_image = new Image();
#
#     function is_close(pt1, pt2) {
#       return   (pt1[0] - pt2[0])*(pt1[0] - pt2[0])
#             +  (pt1[1] - pt2[1])*(pt1[1] - pt2[1])
#             <= ptR*ptR;
#     }
#
#     function circ(ctx, pos, cls) {
#       ctx.beginPath();
#       ctx.arc(pos[0], pos[1], ptR, 0.0, 2.0 * Math.PI, 0);
#       ctx.fillStyle = (cls == 0 ? 'rgba(200, 0, 0, 0.5)' : 'rgba(0, 0, 200, 0.5)');
#       ctx.fill();
#     }
#
#     function in_rect(pos, rect) {
#       if (pos[0] < rect[0] || pos[0] > (rect[0] + rect[2]))
#         return false;
#       if (pos[1] < rect[1] || pos[1] > (rect[1] + rect[3]))
#         return false;
#       return true;
#     }
#
#     function get_survivals() {
#       var g1A = [0, 0];
# ...

# %% [markdown]
# * false causality (correlation implies causation) research.
# How often do we read that medical study suggests that __ increases chances of __ decease without explaining the mechanism of such influence! Such results are suspicious.
#
# * manipulative infographics and data presentation (used in propaganda).
